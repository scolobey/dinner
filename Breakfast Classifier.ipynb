# %%
# %matplotlib inline

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import time
import rec_parse

# %% [markdown]
# # Collect Data
# To obtain data, a recipe is parsed to identify dictionary matches. Each dictionary entry corresponds to an index in recipe space. So, each recipe is represented as a vector in recipe space of dimension 4060. Beginnning with a set of 15768 recipe vectors. 10% of those vectors, at equal intervals are reserved as test data. The result should be 4 matrices, trainX representing 14191 recipe vectors, trainY representing binary labels for each of those recipes, testX representing 1577 recipe vectors on which to test, and testY reresenting labels for the test data. For the label matrices, a 1 in column 0 represents 'dinner', while a 1 in column 1 represents 'non-dinner'.

# %%
rec_parse.clear_data()

dinner_count = rec_parse.initialize_csv("rec_dinner_tag.csv")
breakfast_count = rec_parse.initialize_csv("breakfast_revision.csv")
dessert_count = rec_parse.initialize_csv("rec_modified_dessert_tag.csv")

data = rec_parse.generate_training_data()

dinner_labels = np.zeros((dinner_count, 2), dtype=np.int)
breakfast_labels = np.zeros((breakfast_count, 2), dtype=np.int)
dessert_labels = np.zeros((dessert_count, 2), dtype=np.int)
                          
for label in dinner_labels:
    label[1] = 1
                          
for label in breakfast_labels:
    label[0] = 1
                          
for label in dessert_labels:
    label[1] = 1
    
labels = np.concatenate((dinner_labels, breakfast_labels), axis=0)
labels = np.concatenate((labels, dessert_labels), axis=0)

trainX, testX = rec_parse.split(data)
trainY, testY = rec_parse.split(labels)
                          
# # data = rec_parse.parse_recipes()
                          
# # trainX, testX = rec_parse.split(data)

# # trainY = np.zeros((len(data)-1577, 2), dtype=np.int)
# # testY = np.zeros([1577, 2], dtype=np.int)

# # for ind, row in enumerate(trainY):
# #     if ind > 1500:
# #         trainY[ind][1] = 1
# #     else:
# #         trainY[ind][0] = 1

# # for ind, row in enumerate(testY):
# #     if ind > 150:
# #         testY[ind][1] = 1
# #     else:
# #         testY[ind][0] = 1
        
print("Your data is ready.")
print("trainX shape =", trainX.shape)
print("trainY shape =", trainY.shape)
print("testX shape =", testX.shape)
print("testY shape =", testY.shape)

print(len(data))
# Out:
# Your data is ready.
# trainX shape = (14427, 4378)
# trainY shape = (14427, 2)
# testX shape = (1604, 4378)
# testY shape = (1604, 2)
# 16031

# %% [markdown]
# # Initialize graph features
#
# At line 4, numEpochs is set very low at 100. This low number of epochs results in a model that builds quickly, but has low accuracy. to experiment with a more accurate model, increase numEpochs to at least 2000. To train a production model, you would likely run close to 30k, and probably continue running until cost no longer changes, or does so minimally from epoch to epoch.

# %%
numFeatures = trainX.shape[1]
numLabels = trainY.shape[1]

numEpochs = 20000

tf.reset_default_graph()

learningRate = tf.train.exponential_decay(learning_rate=0.0008,
                                          global_step= 1,
                                          decay_steps=trainX.shape[0],
                                          decay_rate= 0.95,
                                          staircase=True)

X = tf.placeholder(tf.float32, [None, numFeatures])
yGold = tf.placeholder(tf.float32, [None, numLabels])

# %% [markdown]
# # Initialize variables

# %%
weights = tf.Variable(tf.random_normal([numFeatures,numLabels],
                                       mean=0,
                                       stddev=(np.sqrt(6/numFeatures+
                                                         numLabels+1)),
                                       name="weights"))

bias = tf.Variable(tf.random_normal([1,numLabels],
                                    mean=0,
                                    stddev=(np.sqrt(6/numFeatures+numLabels+1)),
                                    name="bias"))

init_OP = tf.global_variables_initializer()

for i in tf.global_variables():
    print(i)
# Out:
# Tensor("Variable/read:0", shape=(4378, 2), dtype=float32)
# Tensor("Variable_1/read:0", shape=(1, 2), dtype=float32)

# %% [markdown]
# # The algorithm
# Multiply trainX(14191, 4060) by weights(4060, 2), resulting in apply_weights_OP(14191, 2).
# And add the bias(1, 2), resulting in add_bias_OP(14191, 2)
#
# Activate using rectified linear:
# f(x) = max(0, x)
#
# Calculate loss using Mean Squared Error:
# $\frac{1}{n}\sum_{i=0}^n ({y}_{estimated}-{y}_{real})^2$
#
# Optimize using gradient descent.

# %%
# FEEDFORWARD ALGORITHM
apply_weights_OP = tf.matmul(X, weights, name="apply_weights")
add_bias_OP = tf.add(apply_weights_OP, bias, name="add_bias")
activation_OP = tf.nn.sigmoid(add_bias_OP, name="activation")

# COST FUNCTION i.e. MEAN SQUARED ERROR
cost_OP = tf.nn.l2_loss(activation_OP-yGold, name="squared_error_cost")

# OPTIMIZATION ALGORITHM i.e. GRADIENT DESCENT
training_OP = tf.train.GradientDescentOptimizer(learningRate).minimize(cost_OP)

# %% [markdown]
# #  Run training

# %%
# Training epochs
with tf.Session() as sess:
    sess.run(init_OP)

    ###########################
    ### GRAPH LIVE UPDATING ###
    ###########################

    epoch_values=[]
    accuracy_values=[]
    cost_values=[]
    
    # Turn on interactive plotting
    plt.ion()
    # Create the main, super plot
    fig = plt.figure()
    # Create two subplots on their own axes and give titles
    ax1 = plt.subplot("211")
    ax1.set_title("TRAINING ACCURACY", fontsize=10)
    ax2 = plt.subplot("212")
    ax2.set_title("TRAINING COST", fontsize=10)
    plt.tight_layout()


    #####################
    ### RUN THE GRAPH ###
    #####################

    ## Ops for vizualization
    # argmax(activation_OP, 1) gives the label our model thought was most likely
    # argmax(yGold, 1) is the correct label
    correct_predictions_OP = tf.equal(tf.argmax(activation_OP,1),tf.argmax(yGold,1))
    # False is 0 and True is 1, what was our average?
    accuracy_OP = tf.reduce_mean(tf.cast(correct_predictions_OP, "float"))
    # Summary op for regression output
    activation_summary_OP = tf.summary.histogram("output", activation_OP)
    # Summary op for accuracy
    accuracy_summary_OP = tf.summary.scalar("accuracy", accuracy_OP)
    # Summary op for cost
    cost_summary_OP = tf.summary.scalar("cost", cost_OP)
    # Summary ops to check how variables (W, b) are updating after each iteration
    weightSummary = tf.summary.histogram("weights", weights.eval(session=sess))
    biasSummary = tf.summary.histogram("biases", bias.eval(session=sess))
    # Merge all summaries
    all_summary_OPS = tf.summary.merge_all()
    # Summary writer
    writer = tf.summary.FileWriter("summary_logs", sess.graph)

    # Initialize reporting variables
    cost = 0
    diff = 1

    for i in range(numEpochs): 
        if i > 1 and diff < .0001:
            print("change in cost %g; convergence."%diff)
            break
        else:
            # Run training step
            step = sess.run(training_OP, feed_dict={X: trainX, yGold: trainY})
            
            # Report occasional stats
            if i % 10 == 0:
                # Add epoch to epoch_values
                epoch_values.append(i)
                # Generate accuracy stats on test data
                summary_results, train_accuracy, newCost = sess.run(
                    [all_summary_OPS, accuracy_OP, cost_OP],
                    feed_dict={X: trainX, yGold: trainY}
                )
                # Add accuracy to live graphing variable
                accuracy_values.append(train_accuracy)
                # Add cost to live graphing variable
                cost_values.append(newCost)
                # Write summary stats to writer
                writer.add_summary(summary_results, i)
                # Re-assign values for variables
                diff = abs(newCost - cost)
                cost = newCost

                #generate print statements
                print("step %d, training accuracy %g"%(i, train_accuracy))
                print("step %d, cost %g"%(i, newCost))
                print("step %d, change in cost %g"%(i, diff))

                # Plot progress to our two subplots
                accuracyLine, = ax1.plot(epoch_values, accuracy_values)
                costLine, = ax2.plot(epoch_values, cost_values)
                fig.canvas.draw()
                time.sleep(1)
    
    # Create Saver
    saver = tf.train.Saver()   
    saver.save(sess, '/tmp/breakfast-model')

    # How well do we perform on held-out test data?
    print("final accuracy on test set: %s" %str(sess.run(accuracy_OP,
                                                         feed_dict={X: testX,
                                                                    yGold: testY})))
# Out:
# step 0, training accuracy 0.418452
# step 0, cost 7500.97
# step 0, change in cost 7500.97
# step 10, training accuracy 0.900256
# step 10, cost 1808.7
# step 10, change in cost 5692.26
# step 20, training accuracy 0.916684
# step 20, cost 1410.53
# step 20, change in cost 398.175
# step 30, training accuracy 0.921952
# step 30, cost 1267.64
# step 30, change in cost 142.891
# step 40, training accuracy 0.924447
# step 40, cost 1197.63
# step 40, change in cost 70.0107
# step 50, training accuracy 0.926388
# step 50, cost 1156.97
# step 50, change in cost 40.655
# step 60, training accuracy 0.927081
# step 60, cost 1130.78
# step 60, change in cost 26.191
# step 70, training accuracy 0.928537
# step 70, cost 1110.57
# step 70, change in cost 20.2128
# step 80, training accuracy 0.929161
# step 80, cost 1091.01
# step 80, change in cost 19.5619
# step 90, training accuracy 0.929992
# step 90, cost 1074.66
# step 90, change in cost 16.3527
# step 100, training accuracy 0.930478
# step 100, cost 1062.02
# step 100, change in cost 12.6379
# step 110, training accuracy 0.930963
# step 110, cost 1051.73
# step 110, change in cost 10.2852
# step 120, training accuracy 0.931517
# step 120, cost 1043.39
# step 120, change in cost 8.33997
# step 130, training accuracy 0.931656
# step 130, cost 1036.85
# step 130, change in cost 6.53857
# step 140, training accuracy 0.931725
# step 140, cost 1031.34
# step 140, change in cost 5.51013
# step 150, training accuracy 0.931864
# step 150, cost 1026.39
# step 150, change in cost 4.95703
# step 160, training accuracy 0.93221
# step 160, cost 1022.2
# step 160, change in cost 4.18268
# step 170, training accuracy 0.93221
# step 170, cost 1018.59
# step 170, change in cost 3.61017
# step 180, training accuracy 0.93228
# step 180, cost 1015.53
# step 180, change in cost 3.06494
# step 190, training accuracy 0.932349
# step 190, cost 1012.94
# step 190, change in cost 2.58911
# step 200, training accuracy 0.932349
# step 200, cost 1010.67
# step 200, change in cost 2.27301
# step 210, training accuracy 0.932488
# step 210, cost 1008.56
# step 210, change in cost 2.11108
# step 220, training accuracy 0.932626
# step 220, cost 1006.54
# step 220, change in cost 2.01581
# step 230, training accuracy 0.932626
# step 230, cost 1004.61
# step 230, change in cost 1.93372
# step 240, training accuracy 0.932696
# step 240, cost 1002.71
# step 240, change in cost 1.90063
# step 250, training accuracy 0.932696
# step 250, cost 1000.83
# step 250, change in cost 1.87878
# step 260, training accuracy 0.932696
# step 260, cost 999.014
# step 260, change in cost 1.8125
# step 270, training accuracy 0.932765
# step 270, cost 997.311
# step 270, change in cost 1.70233
# step 280, training accuracy 0.932904
# step 280, cost 995.733
# step 280, change in cost 1.57825
# step 290, training accuracy 0.932904
# step 290, cost 994.27
# step 290, change in cost 1.46301
# step 300, training accuracy 0.932904
# step 300, cost 992.896
# step 300, change in cost 1.37433
# step 310, training accuracy 0.932973
# step 310, cost 991.586
# step 310, change in cost 1.30981
# step 320, training accuracy 0.933112
# step 320, cost 990.396
# step 320, change in cost 1.1897
# step 330, training accuracy 0.933112
# step 330, cost 989.359
# step 330, change in cost 1.03723
# step 340, training accuracy 0.933181
# step 340, cost 988.42
# step 340, change in cost 0.939453
# step 350, training accuracy 0.933181
# step 350, cost 987.53
# step 350, change in cost 0.889282
# step 360, training accuracy 0.933112
# step 360, cost 986.665
# step 360, change in cost 0.864929
# step 370, training accuracy 0.933181
# step 370, cost 985.812
# step 370, change in cost 0.853333
# step 380, training accuracy 0.933181
# step 380, cost 984.963
# step 380, change in cost 0.848816
# step 390, training accuracy 0.933112
# step 390, cost 984.117
# step 390, change in cost 0.84668
# step 400, training accuracy 0.933112
# step 400, cost 983.282
# step 400, change in cost 0.834167
# step 410, training accuracy 0.933181
# step 410, cost 982.485
# step 410, change in cost 0.797302
# step 420, training accuracy 0.933181
# step 420, cost 981.747
# step 420, change in cost 0.738098
# step 430, training accuracy 0.933181
# step 430, cost 981.075
# step 430, change in cost 0.671753
# step 440, training accuracy 0.933181
# step 440, cost 980.461
# step 440, change in cost 0.613892
# step 450, training accuracy 0.933181
# step 450, cost 979.89
# step 450, change in cost 0.571899
# step 460, training accuracy 0.933181
# step 460, cost 979.344
# step 460, change in cost 0.545166
# step 470, training accuracy 0.933181
# step 470, cost 978.814
# step 470, change in cost 0.53064
# step 480, training accuracy 0.933181
# step 480, cost 978.29
# step 480, change in cost 0.523254
# step 490, training accuracy 0.933181
# step 490, cost 977.773
# step 490, change in cost 0.517456
# step 500, training accuracy 0.933181
# step 500, cost 977.266
# step 500, change in cost 0.506897
# step 510, training accuracy 0.933181
# step 510, cost 976.777
# step 510, change in cost 0.489258
# step 520, training accuracy 0.933181
# step 520, cost 976.309
# step 520, change in cost 0.467529
# step 530, training accuracy 0.933319
# step 530, cost 975.862
# step 530, change in cost 0.44751
# step 540, training accuracy 0.933389
# step 540, cost 975.428
# step 540, change in cost 0.43396
# step 550, training accuracy 0.933389
# step 550, cost 975.001
# step 550, change in cost 0.427124
# step 560, training accuracy 0.933389
# step 560, cost 974.576
# step 560, change in cost 0.424805
# step 570, training accuracy 0.933458
# step 570, cost 974.152
# step 570, change in cost 0.423889
# step 580, training accuracy 0.933458
# step 580, cost 973.732
# step 580, change in cost 0.420105
# step 590, training accuracy 0.933458
# step 590, cost 973.319
# step 590, change in cost 0.413086
# step 600, training accuracy 0.933458
# step 600, cost 972.915
# step 600, change in cost 0.404175
# step 610, training accuracy 0.933458
# step 610, cost 972.517
# step 610, change in cost 0.397949
# step 620, training accuracy 0.933458
# step 620, cost 972.118
# step 620, change in cost 0.398926
# step 630, training accuracy 0.933458
# step 630, cost 971.71
# step 630, change in cost 0.407654
# step 640, training accuracy 0.933458
# step 640, cost 971.295
# step 640, change in cost 0.415405
# step 650, training accuracy 0.933458
# step 650, cost 970.887
# step 650, change in cost 0.408081
# step 660, training accuracy 0.933458
# step 660, cost 970.51
# step 660, change in cost 0.37677
# step 670, training accuracy 0.933458
# step 670, cost 970.18
# step 670, change in cost 0.330139
# step 680, training accuracy 0.933527
# step 680, cost 969.893
# step 680, change in cost 0.286316
# step 690, training accuracy 0.933527
# step 690, cost 969.638
# step 690, change in cost 0.255127
# step 700, training accuracy 0.933527
# step 700, cost 969.404
# step 700, change in cost 0.234253
# step 710, training accuracy 0.933527
# step 710, cost 969.184
# step 710, change in cost 0.219727
# step 720, training accuracy 0.933527
# step 720, cost 968.976
# step 720, change in cost 0.20874
# step 730, training accuracy 0.933527
# step 730, cost 968.775
# step 730, change in cost 0.200256
# step 740, training accuracy 0.933527
# step 740, cost 968.582
# step 740, change in cost 0.193359
# step 750, training accuracy 0.933527
# step 750, cost 968.394
# step 750, change in cost 0.187805
# step 760, training accuracy 0.933597
# step 760, cost 968.211
# step 760, change in cost 0.183105
# step 770, training accuracy 0.933597
# step 770, cost 968.032
# step 770, change in cost 0.179321
# step 780, training accuracy 0.933597
# step 780, cost 967.856
# step 780, change in cost 0.175781
# step 790, training accuracy 0.933597
# step 790, cost 967.683
# step 790, change in cost 0.172729
# step 800, training accuracy 0.933597
# step 800, cost 967.513
# step 800, change in cost 0.170349
# step 810, training accuracy 0.933597
# step 810, cost 967.345
# step 810, change in cost 0.167908
# step 820, training accuracy 0.933597
# step 820, cost 967.18
# step 820, change in cost 0.165405
# step 830, training accuracy 0.933597
# step 830, cost 967.016
# step 830, change in cost 0.163818
# step 840, training accuracy 0.933597
# step 840, cost 966.854
# step 840, change in cost 0.161865
# step 850, training accuracy 0.933597
# step 850, cost 966.693
# step 850, change in cost 0.160889
# step 860, training accuracy 0.933597
# step 860, cost 966.533
# step 860, change in cost 0.160034
# step 870, training accuracy 0.933597
# step 870, cost 966.372
# step 870, change in cost 0.160522
# step 880, training accuracy 0.933666
# step 880, cost 966.211
# step 880, change in cost 0.161438
# step 890, training accuracy 0.933666
# step 890, cost 966.048
# step 890, change in cost 0.163452
# step 900, training accuracy 0.933666
# step 900, cost 965.881
# step 900, change in cost 0.166077
# step 910, training accuracy 0.933735
# step 910, cost 965.712
# step 910, change in cost 0.169556
# step 920, training accuracy 0.933735
# step 920, cost 965.538
# step 920, change in cost 0.173645
# step 930, training accuracy 0.933735
# step 930, cost 965.361
# step 930, change in cost 0.177612
# step 940, training accuracy 0.933735
# step 940, cost 965.179
# step 940, change in cost 0.181213
# step 950, training accuracy 0.933735
# step 950, cost 964.997
# step 950, change in cost 0.182861
# step 960, training accuracy 0.933735
# step 960, cost 964.813
# step 960, change in cost 0.183472
# step 970, training accuracy 0.933735
# step 970, cost 964.631
# step 970, change in cost 0.182373
# step 980, training accuracy 0.933735
# step 980, cost 964.45
# step 980, change in cost 0.180786
# step 990, training accuracy 0.933735
# step 990, cost 964.271
# step 990, change in cost 0.179382
# step 1000, training accuracy 0.933735
# step 1000, cost 964.092
# step 1000, change in cost 0.178589
# step 1010, training accuracy 0.933735
# step 1010, cost 963.913
# step 1010, change in cost 0.178772
# step 1020, training accuracy 0.933735
# step 1020, cost 963.733
# step 1020, change in cost 0.17981
# step 1030, training accuracy 0.933735
# step 1030, cost 963.552
# step 1030, change in cost 0.181641
# step 1040, training accuracy 0.933735
# step 1040, cost 963.369
# step 1040, change in cost 0.183228
# step 1050, training accuracy 0.933735
# step 1050, cost 963.184
# step 1050, change in cost 0.184326
# step 1060, training accuracy 0.933735
# step 1060, cost 963
# step 1060, change in cost 0.18396
# step 1070, training accuracy 0.933735
# step 1070, cost 962.818
# step 1070, change in cost 0.182068
# step 1080, training accuracy 0.933735
# step 1080, cost 962.64
# step 1080, change in cost 0.178467
# step 1090, training accuracy 0.933735
# step 1090, cost 962.466
# step 1090, change in cost 0.173767
# step 1100, training accuracy 0.933735
# step 1100, cost 962.298
# step 1100, change in cost 0.168274
# step 1110, training accuracy 0.933735
# step 1110, cost 962.135
# step 1110, change in cost 0.162537
# step 1120, training accuracy 0.933735
# step 1120, cost 961.978
# step 1120, change in cost 0.156738
# step 1130, training accuracy 0.933735
# step 1130, cost 961.828
# step 1130, change in cost 0.150879
# step 1140, training accuracy 0.933735
# step 1140, cost 961.682
# step 1140, change in cost 0.14502
# step 1150, training accuracy 0.933735
# step 1150, cost 961.543
# step 1150, change in cost 0.139465
# step 1160, training accuracy 0.933735
# step 1160, cost 961.409
# step 1160, change in cost 0.133545
# step 1170, training accuracy 0.933735
# step 1170, cost 961.281
# step 1170, change in cost 0.128357
# step 1180, training accuracy 0.933735
# step 1180, cost 961.158
# step 1180, change in cost 0.123108
# step 1190, training accuracy 0.933735
# step 1190, cost 961.04
# step 1190, change in cost 0.117981
# step 1200, training accuracy 0.933735
# step 1200, cost 960.926
# step 1200, change in cost 0.113831
# step 1210, training accuracy 0.933735
# step 1210, cost 960.817
# step 1210, change in cost 0.109558
# step 1220, training accuracy 0.933735
# step 1220, cost 960.711
# step 1220, change in cost 0.105957
# step 1230, training accuracy 0.933735
# step 1230, cost 960.608
# step 1230, change in cost 0.102539
# step 1240, training accuracy 0.933735
# step 1240, cost 960.508
# step 1240, change in cost 0.0998535
# step 1250, training accuracy 0.933735
# step 1250, cost 960.411
# step 1250, change in cost 0.0974121
# step 1260, training accuracy 0.933735
# step 1260, cost 960.315
# step 1260, change in cost 0.0953979
# step 1270, training accuracy 0.933735
# step 1270, cost 960.222
# step 1270, change in cost 0.093811
# step 1280, training accuracy 0.933735
# step 1280, cost 960.129
# step 1280, change in cost 0.0925903
# step 1290, training accuracy 0.933735
# step 1290, cost 960.037
# step 1290, change in cost 0.0916138
# step 1300, training accuracy 0.933735
# step 1300, cost 959.947
# step 1300, change in cost 0.0909424
# step 1310, training accuracy 0.933735
# step 1310, cost 959.856
# step 1310, change in cost 0.0906372
# step 1320, training accuracy 0.933735
# step 1320, cost 959.766
# step 1320, change in cost 0.090332
# step 1330, training accuracy 0.933735
# step 1330, cost 959.675
# step 1330, change in cost 0.0907593
# step 1340, training accuracy 0.933735
# step 1340, cost 959.584
# step 1340, change in cost 0.0911255
# step 1350, training accuracy 0.933735
# step 1350, cost 959.492
# step 1350, change in cost 0.0921021
# step 1360, training accuracy 0.933735
# step 1360, cost 959.399
# step 1360, change in cost 0.0928345
# step 1370, training accuracy 0.933735
# step 1370, cost 959.304
# step 1370, change in cost 0.0947266
# step 1380, training accuracy 0.933735
# step 1380, cost 959.207
# step 1380, change in cost 0.0968628
# step 1390, training accuracy 0.933735
# step 1390, cost 959.107
# step 1390, change in cost 0.0997314
# step 1400, training accuracy 0.933735
# step 1400, cost 959.004
# step 1400, change in cost 0.103271
# step 1410, training accuracy 0.933735
# step 1410, cost 958.897
# step 1410, change in cost 0.106934
# step 1420, training accuracy 0.933735
# step 1420, cost 958.787
# step 1420, change in cost 0.110535
# step 1430, training accuracy 0.933735
# step 1430, cost 958.674
# step 1430, change in cost 0.112732
# step 1440, training accuracy 0.933735
# step 1440, cost 958.562
# step 1440, change in cost 0.112244
# step 1450, training accuracy 0.933735
# step 1450, cost 958.453
# step 1450, change in cost 0.109009
# step 1460, training accuracy 0.933735
# step 1460, cost 958.349
# step 1460, change in cost 0.103699
# step 1470, training accuracy 0.933735
# step 1470, cost 958.251
# step 1470, change in cost 0.0977783
# step 1480, training accuracy 0.933735
# step 1480, cost 958.159
# step 1480, change in cost 0.0921631
# step 1490, training accuracy 0.933735
# step 1490, cost 958.072
# step 1490, change in cost 0.0875244
# step 1500, training accuracy 0.933735
# step 1500, cost 957.987
# step 1500, change in cost 0.0841064
# step 1510, training accuracy 0.933735
# step 1510, cost 957.906
# step 1510, change in cost 0.081665
# step 1520, training accuracy 0.933735
# step 1520, cost 957.826
# step 1520, change in cost 0.0800171
# step 1530, training accuracy 0.933735
# step 1530, cost 957.747
# step 1530, change in cost 0.0786743
# step 1540, training accuracy 0.933735
# step 1540, cost 957.669
# step 1540, change in cost 0.0778809
# step 1550, training accuracy 0.933735
# step 1550, cost 957.592
# step 1550, change in cost 0.0774536
# step 1560, training accuracy 0.933735
# step 1560, cost 957.515
# step 1560, change in cost 0.0769653
# step 1570, training accuracy 0.933735
# step 1570, cost 957.438
# step 1570, change in cost 0.0767822
# step 1580, training accuracy 0.933735
# step 1580, cost 957.361
# step 1580, change in cost 0.0765381
# step 1590, training accuracy 0.933666
# step 1590, cost 957.285
# step 1590, change in cost 0.0765991
# step 1600, training accuracy 0.933666
# step 1600, cost 957.208
# step 1600, change in cost 0.076355
# step 1610, training accuracy 0.933666
# step 1610, cost 957.132
# step 1610, change in cost 0.076416
# step 1620, training accuracy 0.933666
# step 1620, cost 957.056
# step 1620, change in cost 0.0762939
# step 1630, training accuracy 0.933666
# step 1630, cost 956.979
# step 1630, change in cost 0.076355
# step 1640, training accuracy 0.933666
# step 1640, cost 956.903
# step 1640, change in cost 0.076416
# step 1650, training accuracy 0.933666
# step 1650, cost 956.827
# step 1650, change in cost 0.0764771
# step 1660, training accuracy 0.933666
# step 1660, cost 956.75
# step 1660, change in cost 0.0767822
# step 1670, training accuracy 0.933666
# step 1670, cost 956.673
# step 1670, change in cost 0.0770264
# step 1680, training accuracy 0.933666
# step 1680, cost 956.595
# step 1680, change in cost 0.0772705
# step 1690, training accuracy 0.933666
# step 1690, cost 956.518
# step 1690, change in cost 0.0778809
# step 1700, training accuracy 0.933666
# step 1700, cost 956.439
# step 1700, change in cost 0.0783081
# step 1710, training accuracy 0.933666
# step 1710, cost 956.36
# step 1710, change in cost 0.0789795
# step 1720, training accuracy 0.933666
# step 1720, cost 956.281
# step 1720, change in cost 0.0797729
# step 1730, training accuracy 0.933666
# step 1730, cost 956.2
# step 1730, change in cost 0.0802612
# step 1740, training accuracy 0.933666
# step 1740, cost 956.119
# step 1740, change in cost 0.0811768
# step 1750, training accuracy 0.933666
# step 1750, cost 956.037
# step 1750, change in cost 0.0819092
# step 1760, training accuracy 0.933666
# step 1760, cost 955.955
# step 1760, change in cost 0.0825806
# step 1770, training accuracy 0.933666
# step 1770, cost 955.871
# step 1770, change in cost 0.0834351
# step 1780, training accuracy 0.933666
# step 1780, cost 955.787
# step 1780, change in cost 0.0843506
# step 1790, training accuracy 0.933666
# step 1790, cost 955.702
# step 1790, change in cost 0.085022
# step 1800, training accuracy 0.933666
# step 1800, cost 955.616
# step 1800, change in cost 0.0859375
# step 1810, training accuracy 0.933666
# step 1810, cost 955.529
# step 1810, change in cost 0.0866089
# step 1820, training accuracy 0.933666
# step 1820, cost 955.442
# step 1820, change in cost 0.0875244
# step 1830, training accuracy 0.933666
# step 1830, cost 955.353
# step 1830, change in cost 0.0883179
# step 1840, training accuracy 0.933666
# step 1840, cost 955.265
# step 1840, change in cost 0.0886841
# step 1850, training accuracy 0.933666
# step 1850, cost 955.175
# step 1850, change in cost 0.0892334
# step 1860, training accuracy 0.933666
# step 1860, cost 955.086
# step 1860, change in cost 0.0892334
# step 1870, training accuracy 0.933666
# step 1870, cost 954.997
# step 1870, change in cost 0.0888672
# step 1880, training accuracy 0.933666
# step 1880, cost 954.909
# step 1880, change in cost 0.0880127
# step 1890, training accuracy 0.933666
# step 1890, cost 954.823
# step 1890, change in cost 0.086853
# step 1900, training accuracy 0.933666
# step 1900, cost 954.737
# step 1900, change in cost 0.085083
# step 1910, training accuracy 0.933666
# step 1910, cost 954.654
# step 1910, change in cost 0.083252
# step 1920, training accuracy 0.933666
# step 1920, cost 954.573
# step 1920, change in cost 0.0810547
# step 1930, training accuracy 0.933666
# step 1930, cost 954.494
# step 1930, change in cost 0.0789795
# step 1940, training accuracy 0.933666
# step 1940, cost 954.417
# step 1940, change in cost 0.0767822
# step 1950, training accuracy 0.933666
# step 1950, cost 954.342
# step 1950, change in cost 0.0750122
# step 1960, training accuracy 0.933666
# step 1960, cost 954.269
# step 1960, change in cost 0.072937
# step 1970, training accuracy 0.933666
# step 1970, cost 954.198
# step 1970, change in cost 0.0713501
# step 1980, training accuracy 0.933666
# step 1980, cost 954.128
# step 1980, change in cost 0.0698242
# step 1990, training accuracy 0.933666
# step 1990, cost 954.06
# step 1990, change in cost 0.0682983
# step 2000, training accuracy 0.933666
# step 2000, cost 953.993
# step 2000, change in cost 0.0670166
# step 2010, training accuracy 0.933666
# step 2010, cost 953.927
# step 2010, change in cost 0.0657349
# step 2020, training accuracy 0.933666
# step 2020, cost 953.863
# step 2020, change in cost 0.0645142
# step 2030, training accuracy 0.933666
# step 2030, cost 953.799
# step 2030, change in cost 0.0636597
# step 2040, training accuracy 0.933666
# step 2040, cost 953.737
# step 2040, change in cost 0.0623779
# step 2050, training accuracy 0.933666
# step 2050, cost 953.675
# step 2050, change in cost 0.0613403
# step 2060, training accuracy 0.933666
# step 2060, cost 953.615
# step 2060, change in cost 0.0606689
# step 2070, training accuracy 0.933666
# step 2070, cost 953.555
# step 2070, change in cost 0.0595703
# step 2080, training accuracy 0.933666
# step 2080, cost 953.496
# step 2080, change in cost 0.059021
# step 2090, training accuracy 0.933666
# step 2090, cost 953.438
# step 2090, change in cost 0.0579834
# step 2100, training accuracy 0.933666
# step 2100, cost 953.38
# step 2100, change in cost 0.0575562
# step 2110, training accuracy 0.933666
# step 2110, cost 953.324
# step 2110, change in cost 0.0567627
# step 2120, training accuracy 0.933666
# step 2120, cost 953.267
# step 2120, change in cost 0.0563965
# step 2130, training accuracy 0.933666
# step 2130, cost 953.212
# step 2130, change in cost 0.0557861
# step 2140, training accuracy 0.933666
# step 2140, cost 953.156
# step 2140, change in cost 0.0552979
# step 2150, training accuracy 0.933735
# step 2150, cost 953.101
# step 2150, change in cost 0.0550537
# step 2160, training accuracy 0.933735
# step 2160, cost 953.046
# step 2160, change in cost 0.0548096
# step 2170, training accuracy 0.933735
# step 2170, cost 952.992
# step 2170, change in cost 0.0543213
# step 2180, training accuracy 0.933735
# step 2180, cost 952.938
# step 2180, change in cost 0.0543213
# step 2190, training accuracy 0.933735
# step 2190, cost 952.884
# step 2190, change in cost 0.0541382
# step 2200, training accuracy 0.933735
# step 2200, cost 952.83
# step 2200, change in cost 0.0540161
# step 2210, training accuracy 0.933735
# step 2210, cost 952.775
# step 2210, change in cost 0.0541992
# step 2220, training accuracy 0.933735
# step 2220, cost 952.721
# step 2220, change in cost 0.0539551
# step 2230, training accuracy 0.933735
# step 2230, cost 952.667
# step 2230, change in cost 0.0543213
# step 2240, training accuracy 0.933735
# step 2240, cost 952.613
# step 2240, change in cost 0.0541992
# step 2250, training accuracy 0.933805
# step 2250, cost 952.558
# step 2250, change in cost 0.0545044
# step 2260, training accuracy 0.933805
# step 2260, cost 952.504
# step 2260, change in cost 0.0548706
# step 2270, training accuracy 0.933805
# step 2270, cost 952.449
# step 2270, change in cost 0.0548706
# step 2280, training accuracy 0.933805
# step 2280, cost 952.393
# step 2280, change in cost 0.055481
# step 2290, training accuracy 0.933805
# step 2290, cost 952.337
# step 2290, change in cost 0.0557861
# step 2300, training accuracy 0.933805
# step 2300, cost 952.281
# step 2300, change in cost 0.0562744
# step 2310, training accuracy 0.933805
# step 2310, cost 952.224
# step 2310, change in cost 0.0568848
# step 2320, training accuracy 0.933805
# step 2320, cost 952.167
# step 2320, change in cost 0.057312
# step 2330, training accuracy 0.933805
# step 2330, cost 952.109
# step 2330, change in cost 0.0578003
# step 2340, training accuracy 0.933805
# step 2340, cost 952.05
# step 2340, change in cost 0.0587769
# step 2350, training accuracy 0.933805
# step 2350, cost 951.991
# step 2350, change in cost 0.0593872
# step 2360, training accuracy 0.933805
# step 2360, cost 951.931
# step 2360, change in cost 0.0604248
# step 2370, training accuracy 0.933805
# step 2370, cost 951.869
# step 2370, change in cost 0.0612183
# step 2380, training accuracy 0.933805
# step 2380, cost 951.807
# step 2380, change in cost 0.0625
# step 2390, training accuracy 0.933805
# step 2390, cost 951.743
# step 2390, change in cost 0.0635376
# step 2400, training accuracy 0.933805
# step 2400, cost 951.678
# step 2400, change in cost 0.0649414
# step 2410, training accuracy 0.933805
# step 2410, cost 951.612
# step 2410, change in cost 0.0664062
# step 2420, training accuracy 0.933805
# step 2420, cost 951.544
# step 2420, change in cost 0.0679321
# step 2430, training accuracy 0.933805
# step 2430, cost 951.474
# step 2430, change in cost 0.0698853
# step 2440, training accuracy 0.933805
# step 2440, cost 951.403
# step 2440, change in cost 0.0715332
# step 2450, training accuracy 0.933805
# step 2450, cost 951.329
# step 2450, change in cost 0.0739746
# step 2460, training accuracy 0.933805
# step 2460, cost 951.253
# step 2460, change in cost 0.0758667
# step 2470, training accuracy 0.933805
# step 2470, cost 951.174
# step 2470, change in cost 0.0786743
# step 2480, training accuracy 0.933805
# step 2480, cost 951.093
# step 2480, change in cost 0.0808105
# step 2490, training accuracy 0.933805
# step 2490, cost 951.01
# step 2490, change in cost 0.0837402
# step 2500, training accuracy 0.933805
# step 2500, cost 950.923
# step 2500, change in cost 0.0861206
# step 2510, training accuracy 0.933805
# step 2510, cost 950.835
# step 2510, change in cost 0.088562
# step 2520, training accuracy 0.933805
# step 2520, cost 950.744
# step 2520, change in cost 0.0906982
# step 2530, training accuracy 0.933805
# step 2530, cost 950.651
# step 2530, change in cost 0.0928955
# step 2540, training accuracy 0.933805
# step 2540, cost 950.557
# step 2540, change in cost 0.0942993
# step 2550, training accuracy 0.933805
# step 2550, cost 950.461
# step 2550, change in cost 0.0956421
# step 2560, training accuracy 0.933805
# step 2560, cost 950.365
# step 2560, change in cost 0.0964355
# step 2570, training accuracy 0.933805
# step 2570, cost 950.268
# step 2570, change in cost 0.09729
# step 2580, training accuracy 0.933805
# step 2580, cost 950.17
# step 2580, change in cost 0.0977783
# step 2590, training accuracy 0.933805
# step 2590, cost 950.072
# step 2590, change in cost 0.0982056
# step 2600, training accuracy 0.933805
# step 2600, cost 949.973
# step 2600, change in cost 0.0986938
# step 2610, training accuracy 0.933805
# step 2610, cost 949.874
# step 2610, change in cost 0.0991211
# step 2620, training accuracy 0.933874
# step 2620, cost 949.774
# step 2620, change in cost 0.0995483
# step 2630, training accuracy 0.933874
# step 2630, cost 949.674
# step 2630, change in cost 0.100159
# step 2640, training accuracy 0.933874
# step 2640, cost 949.573
# step 2640, change in cost 0.100891
# step 2650, training accuracy 0.933874
# step 2650, cost 949.472
# step 2650, change in cost 0.101562
# step 2660, training accuracy 0.933874
# step 2660, cost 949.369
# step 2660, change in cost 0.102234
# step 2670, training accuracy 0.933874
# step 2670, cost 949.266
# step 2670, change in cost 0.102905
# step 2680, training accuracy 0.933874
# step 2680, cost 949.163
# step 2680, change in cost 0.103638
# step 2690, training accuracy 0.933874
# step 2690, cost 949.059
# step 2690, change in cost 0.104065
# step 2700, training accuracy 0.933874
# step 2700, cost 948.954
# step 2700, change in cost 0.104797
# step 2710, training accuracy 0.933874
# step 2710, cost 948.849
# step 2710, change in cost 0.105469
# step 2720, training accuracy 0.933874
# step 2720, cost 948.743
# step 2720, change in cost 0.105713
# step 2730, training accuracy 0.933943
# step 2730, cost 948.636
# step 2730, change in cost 0.106506
# step 2740, training accuracy 0.933943
# step 2740, cost 948.53
# step 2740, change in cost 0.106689
# step 2750, training accuracy 0.934013
# step 2750, cost 948.422
# step 2750, change in cost 0.107361
# step 2760, training accuracy 0.934013
# step 2760, cost 948.314
# step 2760, change in cost 0.107788
# step 2770, training accuracy 0.934013
# step 2770, cost 948.206
# step 2770, change in cost 0.108154
# step 2780, training accuracy 0.934013
# step 2780, cost 948.098
# step 2780, change in cost 0.108765
# step 2790, training accuracy 0.934082
# step 2790, cost 947.989
# step 2790, change in cost 0.108887
# step 2800, training accuracy 0.934082
# step 2800, cost 947.88
# step 2800, change in cost 0.10907
# step 2810, training accuracy 0.934082
# step 2810, cost 947.771
# step 2810, change in cost 0.108948
# step 2820, training accuracy 0.934082
# step 2820, cost 947.662
# step 2820, change in cost 0.108887
# step 2830, training accuracy 0.934082
# step 2830, cost 947.554
# step 2830, change in cost 0.108154
# step 2840, training accuracy 0.934082
# step 2840, cost 947.446
# step 2840, change in cost 0.107544
# step 2850, training accuracy 0.934082
# step 2850, cost 947.34
# step 2850, change in cost 0.106323
# step 2860, training accuracy 0.934082
# step 2860, cost 947.234
# step 2860, change in cost 0.105469
# step 2870, training accuracy 0.934082
# step 2870, cost 947.13
# step 2870, change in cost 0.10376
# step 2880, training accuracy 0.934082
# step 2880, cost 947.028
# step 2880, change in cost 0.102417
# step 2890, training accuracy 0.934082
# step 2890, cost 946.928
# step 2890, change in cost 0.100464
# step 2900, training accuracy 0.934082
# step 2900, cost 946.829
# step 2900, change in cost 0.0985107
# step 2910, training accuracy 0.934082
# step 2910, cost 946.732
# step 2910, change in cost 0.0967407
# step 2920, training accuracy 0.934082
# step 2920, cost 946.637
# step 2920, change in cost 0.0950317
# step 2930, training accuracy 0.934082
# step 2930, cost 946.544
# step 2930, change in cost 0.0931396
# step 2940, training accuracy 0.934082
# step 2940, cost 946.453
# step 2940, change in cost 0.0914307
# step 2950, training accuracy 0.934082
# step 2950, cost 946.363
# step 2950, change in cost 0.0899658
# step 2960, training accuracy 0.934082
# step 2960, cost 946.274
# step 2960, change in cost 0.088623
# step 2970, training accuracy 0.934082
# step 2970, cost 946.186
# step 2970, change in cost 0.0877686
# step 2980, training accuracy 0.934082
# step 2980, cost 946.1
# step 2980, change in cost 0.0864258
# step 2990, training accuracy 0.934082
# step 2990, cost 946.014
# step 2990, change in cost 0.0858154
# step 3000, training accuracy 0.934082
# step 3000, cost 945.929
# step 3000, change in cost 0.0849609
# step 3010, training accuracy 0.934082
# step 3010, cost 945.845
# step 3010, change in cost 0.0842896
# step 3020, training accuracy 0.934082
# step 3020, cost 945.761
# step 3020, change in cost 0.0838013
# step 3030, training accuracy 0.934082
# step 3030, cost 945.678
# step 3030, change in cost 0.083252
# step 3040, training accuracy 0.934082
# step 3040, cost 945.595
# step 3040, change in cost 0.0830078
# step 3050, training accuracy 0.934082
# step 3050, cost 945.512
# step 3050, change in cost 0.0825806
# step 3060, training accuracy 0.934082
# step 3060, cost 945.43
# step 3060, change in cost 0.0823364
# step 3070, training accuracy 0.934082
# step 3070, cost 945.348
# step 3070, change in cost 0.0820312
# step 3080, training accuracy 0.934082
# step 3080, cost 945.266
# step 3080, change in cost 0.081665
# step 3090, training accuracy 0.934082
# step 3090, cost 945.185
# step 3090, change in cost 0.081604
# step 3100, training accuracy 0.934082
# step 3100, cost 945.104
# step 3100, change in cost 0.0811157
# step 3110, training accuracy 0.934082
# step 3110, cost 945.023
# step 3110, change in cost 0.0808105
# step 3120, training accuracy 0.934082
# step 3120, cost 944.942
# step 3120, change in cost 0.0806274
# step 3130, training accuracy 0.934082
# step 3130, cost 944.862
# step 3130, change in cost 0.0800781
# step 3140, training accuracy 0.934082
# step 3140, cost 944.782
# step 3140, change in cost 0.0797729
# step 3150, training accuracy 0.934082
# step 3150, cost 944.703
# step 3150, change in cost 0.0794678
# step 3160, training accuracy 0.934082
# step 3160, cost 944.624
# step 3160, change in cost 0.0788574
# step 3170, training accuracy 0.934082
# step 3170, cost 944.545
# step 3170, change in cost 0.0784302
# step 3180, training accuracy 0.934082
# step 3180, cost 944.467
# step 3180, change in cost 0.0782471
# step 3190, training accuracy 0.934082
# step 3190, cost 944.39
# step 3190, change in cost 0.0775146
# step 3200, training accuracy 0.934082
# step 3200, cost 944.313
# step 3200, change in cost 0.0769653
# step 3210, training accuracy 0.934082
# step 3210, cost 944.236
# step 3210, change in cost 0.0762939
# step 3220, training accuracy 0.934082
# step 3220, cost 944.16
# step 3220, change in cost 0.0761108
# step 3230, training accuracy 0.934082
# step 3230, cost 944.085
# step 3230, change in cost 0.0755005
# step 3240, training accuracy 0.934082
# step 3240, cost 944.01
# step 3240, change in cost 0.0749512
# step 3250, training accuracy 0.934082
# step 3250, cost 943.935
# step 3250, change in cost 0.0744629
# step 3260, training accuracy 0.934082
# step 3260, cost 943.862
# step 3260, change in cost 0.0737305
# step 3270, training accuracy 0.934082
# step 3270, cost 943.788
# step 3270, change in cost 0.0733643
# step 3280, training accuracy 0.934082
# step 3280, cost 943.716
# step 3280, change in cost 0.0725098
# step 3290, training accuracy 0.934082
# step 3290, cost 943.643
# step 3290, change in cost 0.0723267
# step 3300, training accuracy 0.934082
# step 3300, cost 943.572
# step 3300, change in cost 0.0716553
# step 3310, training accuracy 0.934082
# step 3310, cost 943.501
# step 3310, change in cost 0.0709229
# step 3320, training accuracy 0.934082
# step 3320, cost 943.43
# step 3320, change in cost 0.0707397
# step 3330, training accuracy 0.934082
# step 3330, cost 943.36
# step 3330, change in cost 0.0698853
# step 3340, training accuracy 0.934082
# step 3340, cost 943.291
# step 3340, change in cost 0.069519
# step 3350, training accuracy 0.934082
# step 3350, cost 943.222
# step 3350, change in cost 0.0690308
# step 3360, training accuracy 0.934082
# step 3360, cost 943.153
# step 3360, change in cost 0.0685425
# step 3370, training accuracy 0.934082
# step 3370, cost 943.085
# step 3370, change in cost 0.0680542
# step 3380, training accuracy 0.934082
# step 3380, cost 943.018
# step 3380, change in cost 0.0675659
# step 3390, training accuracy 0.934082
# step 3390, cost 942.95
# step 3390, change in cost 0.0671997
# step 3400, training accuracy 0.934082
# step 3400, cost 942.884
# step 3400, change in cost 0.0666504
# step 3410, training accuracy 0.934082
# step 3410, cost 942.817
# step 3410, change in cost 0.0664062
# step 3420, training accuracy 0.934082
# step 3420, cost 942.751
# step 3420, change in cost 0.0658569
# step 3430, training accuracy 0.934082
# step 3430, cost 942.686
# step 3430, change in cost 0.0653687
# step 3440, training accuracy 0.934082
# step 3440, cost 942.621
# step 3440, change in cost 0.0650024
# step 3450, training accuracy 0.934082
# step 3450, cost 942.556
# step 3450, change in cost 0.0648804
# step 3460, training accuracy 0.934082
# step 3460, cost 942.492
# step 3460, change in cost 0.0643311
# step 3470, training accuracy 0.934082
# step 3470, cost 942.428
# step 3470, change in cost 0.0639648
# step 3480, training accuracy 0.934082
# step 3480, cost 942.364
# step 3480, change in cost 0.0635986
# step 3490, training accuracy 0.934082
# step 3490, cost 942.301
# step 3490, change in cost 0.0632935
# step 3500, training accuracy 0.934082
# step 3500, cost 942.238
# step 3500, change in cost 0.0628662
# step 3510, training accuracy 0.934082
# step 3510, cost 942.175
# step 3510, change in cost 0.0627441
# step 3520, training accuracy 0.934082
# step 3520, cost 942.113
# step 3520, change in cost 0.0621948
# step 3530, training accuracy 0.934082
# step 3530, cost 942.051
# step 3530, change in cost 0.0619507
# step 3540, training accuracy 0.934082
# step 3540, cost 941.989
# step 3540, change in cost 0.0620728
# step 3550, training accuracy 0.934082
# step 3550, cost 941.928
# step 3550, change in cost 0.0613403
# step 3560, training accuracy 0.934082
# step 3560, cost 941.867
# step 3560, change in cost 0.0612793
# step 3570, training accuracy 0.934082
# step 3570, cost 941.806
# step 3570, change in cost 0.060791
# step 3580, training accuracy 0.934082
# step 3580, cost 941.745
# step 3580, change in cost 0.060791
# step 3590, training accuracy 0.934082
# step 3590, cost 941.685
# step 3590, change in cost 0.0604248
# step 3600, training accuracy 0.934082
# step 3600, cost 941.624
# step 3600, change in cost 0.0603027
# step 3610, training accuracy 0.934082
# step 3610, cost 941.564
# step 3610, change in cost 0.0599365
# step 3620, training accuracy 0.934082
# step 3620, cost 941.504
# step 3620, change in cost 0.0599365
# step 3630, training accuracy 0.934082
# step 3630, cost 941.445
# step 3630, change in cost 0.0594482
# step 3640, training accuracy 0.934082
# step 3640, cost 941.385
# step 3640, change in cost 0.0595703
# step 3650, training accuracy 0.934082
# step 3650, cost 941.326
# step 3650, change in cost 0.059082
# step 3660, training accuracy 0.934082
# step 3660, cost 941.267
# step 3660, change in cost 0.059082
# step 3670, training accuracy 0.934082
# step 3670, cost 941.208
# step 3670, change in cost 0.0588379
# step 3680, training accuracy 0.934082
# step 3680, cost 941.15
# step 3680, change in cost 0.0588379
# step 3690, training accuracy 0.934082
# step 3690, cost 941.091
# step 3690, change in cost 0.0585938
# step 3700, training accuracy 0.934082
# step 3700, cost 941.033
# step 3700, change in cost 0.0583496
# step 3710, training accuracy 0.934082
# step 3710, cost 940.974
# step 3710, change in cost 0.0583496
# step 3720, training accuracy 0.934082
# step 3720, cost 940.916
# step 3720, change in cost 0.0582275
# step 3730, training accuracy 0.934082
# step 3730, cost 940.858
# step 3730, change in cost 0.0578003
# step 3740, training accuracy 0.934082
# step 3740, cost 940.8
# step 3740, change in cost 0.0579224
# step 3750, training accuracy 0.934082
# step 3750, cost 940.743
# step 3750, change in cost 0.0576172
# step 3760, training accuracy 0.934082
# step 3760, cost 940.685
# step 3760, change in cost 0.0577393
# step 3770, training accuracy 0.934082
# step 3770, cost 940.628
# step 3770, change in cost 0.0574341
# step 3780, training accuracy 0.934082
# step 3780, cost 940.57
# step 3780, change in cost 0.057312
# step 3790, training accuracy 0.934082
# step 3790, cost 940.513
# step 3790, change in cost 0.057312
# step 3800, training accuracy 0.934082
# step 3800, cost 940.456
# step 3800, change in cost 0.0571289
# step 3810, training accuracy 0.934082
# step 3810, cost 940.399
# step 3810, change in cost 0.0569458
# step 3820, training accuracy 0.934082
# step 3820, cost 940.342
# step 3820, change in cost 0.0569458
# step 3830, training accuracy 0.934082
# step 3830, cost 940.285
# step 3830, change in cost 0.0567017
# step 3840, training accuracy 0.934082
# step 3840, cost 940.228
# step 3840, change in cost 0.0567017
# step 3850, training accuracy 0.934082
# step 3850, cost 940.172
# step 3850, change in cost 0.0563965
# step 3860, training accuracy 0.934082
# step 3860, cost 940.116
# step 3860, change in cost 0.0563965
# step 3870, training accuracy 0.934082
# step 3870, cost 940.06
# step 3870, change in cost 0.0559692
# step 3880, training accuracy 0.934082
# step 3880, cost 940.004
# step 3880, change in cost 0.0560913
# step 3890, training accuracy 0.934151
# step 3890, cost 939.948
# step 3890, change in cost 0.0557861
# step 3900, training accuracy 0.934221
# step 3900, cost 939.892
# step 3900, change in cost 0.0558472
# step 3910, training accuracy 0.934221
# step 3910, cost 939.837
# step 3910, change in cost 0.0552979
# step 3920, training accuracy 0.934221
# step 3920, cost 939.781
# step 3920, change in cost 0.0551758
# step 3930, training accuracy 0.934221
# step 3930, cost 939.726
# step 3930, change in cost 0.0551758
# step 3940, training accuracy 0.934221
# step 3940, cost 939.672
# step 3940, change in cost 0.0548096
# step 3950, training accuracy 0.934221
# step 3950, cost 939.617
# step 3950, change in cost 0.0544434
# step 3960, training accuracy 0.934221
# step 3960, cost 939.563
# step 3960, change in cost 0.0544434
# step 3970, training accuracy 0.934221
# step 3970, cost 939.509
# step 3970, change in cost 0.053772
# step 3980, training accuracy 0.934221
# step 3980, cost 939.455
# step 3980, change in cost 0.053833
# step 3990, training accuracy 0.934221
# step 3990, cost 939.402
# step 3990, change in cost 0.0532837
# step 4000, training accuracy 0.934221
# step 4000, cost 939.349
# step 4000, change in cost 0.0531006
# step 4010, training accuracy 0.934221
# step 4010, cost 939.296
# step 4010, change in cost 0.0526123
# step 4020, training accuracy 0.934221
# step 4020, cost 939.244
# step 4020, change in cost 0.0523682
# step 4030, training accuracy 0.934221
# step 4030, cost 939.192
# step 4030, change in cost 0.0518799
# step 4040, training accuracy 0.934221
# step 4040, cost 939.14
# step 4040, change in cost 0.0513916
# step 4050, training accuracy 0.934221
# step 4050, cost 939.089
# step 4050, change in cost 0.0512695
# step 4060, training accuracy 0.934221
# step 4060, cost 939.038
# step 4060, change in cost 0.0506592
# step 4070, training accuracy 0.934221
# step 4070, cost 938.988
# step 4070, change in cost 0.0501709
# step 4080, training accuracy 0.934221
# step 4080, cost 938.939
# step 4080, change in cost 0.0497437
# step 4090, training accuracy 0.934221
# step 4090, cost 938.889
# step 4090, change in cost 0.0491943
# step 4100, training accuracy 0.934221
# step 4100, cost 938.84
# step 4100, change in cost 0.0488892
# step 4110, training accuracy 0.934221
# step 4110, cost 938.792
# step 4110, change in cost 0.0482178
# step 4120, training accuracy 0.934221
# step 4120, cost 938.744
# step 4120, change in cost 0.0478516
# step 4130, training accuracy 0.934221
# step 4130, cost 938.697
# step 4130, change in cost 0.0474243
# step 4140, training accuracy 0.934221
# step 4140, cost 938.65
# step 4140, change in cost 0.0466919
# step 4150, training accuracy 0.934221
# step 4150, cost 938.604
# step 4150, change in cost 0.0463867
# step 4160, training accuracy 0.934221
# step 4160, cost 938.558
# step 4160, change in cost 0.0458374
# step 4170, training accuracy 0.934221
# step 4170, cost 938.513
# step 4170, change in cost 0.0454102
# step 4180, training accuracy 0.934221
# step 4180, cost 938.468
# step 4180, change in cost 0.0449829
# step 4190, training accuracy 0.934221
# step 4190, cost 938.423
# step 4190, change in cost 0.0444946
# step 4200, training accuracy 0.934221
# step 4200, cost 938.379
# step 4200, change in cost 0.0438232
# step 4210, training accuracy 0.934221
# step 4210, cost 938.336
# step 4210, change in cost 0.0435181
# step 4220, training accuracy 0.93429
# step 4220, cost 938.293
# step 4220, change in cost 0.0429688
# step 4230, training accuracy 0.93429
# step 4230, cost 938.25
# step 4230, change in cost 0.0428467
# step 4240, training accuracy 0.93429
# step 4240, cost 938.208
# step 4240, change in cost 0.0419922
# step 4250, training accuracy 0.93429
# step 4250, cost 938.166
# step 4250, change in cost 0.041748
# step 4260, training accuracy 0.93429
# step 4260, cost 938.125
# step 4260, change in cost 0.0412598
# step 4270, training accuracy 0.93429
# step 4270, cost 938.084
# step 4270, change in cost 0.0410156
# step 4280, training accuracy 0.93429
# step 4280, cost 938.044
# step 4280, change in cost 0.0404053
# step 4290, training accuracy 0.93429
# step 4290, cost 938.003
# step 4290, change in cost 0.0401611
# step 4300, training accuracy 0.93429
# step 4300, cost 937.964
# step 4300, change in cost 0.0395508
# step 4310, training accuracy 0.93429
# step 4310, cost 937.924
# step 4310, change in cost 0.0394897
# step 4320, training accuracy 0.93429
# step 4320, cost 937.885
# step 4320, change in cost 0.0391846
# step 4330, training accuracy 0.93429
# step 4330, cost 937.847
# step 4330, change in cost 0.0386353
# step 4340, training accuracy 0.93429
# step 4340, cost 937.808
# step 4340, change in cost 0.0383301
# step 4350, training accuracy 0.93429
# step 4350, cost 937.77
# step 4350, change in cost 0.0380859
# step 4360, training accuracy 0.93429
# step 4360, cost 937.732
# step 4360, change in cost 0.0378418
# step 4370, training accuracy 0.93429
# step 4370, cost 937.695
# step 4370, change in cost 0.0374756
# step 4380, training accuracy 0.93429
# step 4380, cost 937.657
# step 4380, change in cost 0.0373535
# step 4390, training accuracy 0.93429
# step 4390, cost 937.62
# step 4390, change in cost 0.0369873
# step 4400, training accuracy 0.93429
# step 4400, cost 937.584
# step 4400, change in cost 0.0366211
# step 4410, training accuracy 0.93429
# step 4410, cost 937.547
# step 4410, change in cost 0.0365601
# step 4420, training accuracy 0.93429
# step 4420, cost 937.511
# step 4420, change in cost 0.036438
# step 4430, training accuracy 0.93429
# step 4430, cost 937.475
# step 4430, change in cost 0.0360107
# step 4440, training accuracy 0.93429
# step 4440, cost 937.439
# step 4440, change in cost 0.0360107
# step 4450, training accuracy 0.93429
# step 4450, cost 937.403
# step 4450, change in cost 0.0358887
# step 4460, training accuracy 0.93429
# step 4460, cost 937.367
# step 4460, change in cost 0.0355225
# step 4470, training accuracy 0.93429
# step 4470, cost 937.332
# step 4470, change in cost 0.0352783
# step 4480, training accuracy 0.93429
# step 4480, cost 937.297
# step 4480, change in cost 0.0352783
# step 4490, training accuracy 0.93429
# step 4490, cost 937.262
# step 4490, change in cost 0.0351562
# step 4500, training accuracy 0.93429
# step 4500, cost 937.227
# step 4500, change in cost 0.0350342
# step 4510, training accuracy 0.93429
# step 4510, cost 937.192
# step 4510, change in cost 0.0350342
# step 4520, training accuracy 0.93429
# step 4520, cost 937.157
# step 4520, change in cost 0.0349121
# step 4530, training accuracy 0.93429
# step 4530, cost 937.122
# step 4530, change in cost 0.0345459
# step 4540, training accuracy 0.93429
# step 4540, cost 937.087
# step 4540, change in cost 0.03479
# step 4550, training accuracy 0.93429
# step 4550, cost 937.053
# step 4550, change in cost 0.0345459
# step 4560, training accuracy 0.93429
# step 4560, cost 937.018
# step 4560, change in cost 0.0344238
# step 4570, training accuracy 0.93429
# step 4570, cost 936.984
# step 4570, change in cost 0.0345459
# step 4580, training accuracy 0.934359
# step 4580, cost 936.949
# step 4580, change in cost 0.0344238
# step 4590, training accuracy 0.934359
# step 4590, cost 936.915
# step 4590, change in cost 0.0344238
# step 4600, training accuracy 0.934359
# step 4600, cost 936.881
# step 4600, change in cost 0.0344849
# step 4610, training accuracy 0.934359
# step 4610, cost 936.846
# step 4610, change in cost 0.0343018
# step 4620, training accuracy 0.934359
# step 4620, cost 936.812
# step 4620, change in cost 0.0346069
# step 4630, training accuracy 0.934359
# step 4630, cost 936.777
# step 4630, change in cost 0.0344849
# step 4640, training accuracy 0.934359
# step 4640, cost 936.743
# step 4640, change in cost 0.0343628
# step 4650, training accuracy 0.934359
# step 4650, cost 936.708
# step 4650, change in cost 0.0346069
# step 4660, training accuracy 0.934359
# step 4660, cost 936.673
# step 4660, change in cost 0.034729
# step 4670, training accuracy 0.934359
# step 4670, cost 936.639
# step 4670, change in cost 0.0344849
# step 4680, training accuracy 0.934359
# step 4680, cost 936.604
# step 4680, change in cost 0.0348511
# step 4690, training accuracy 0.934359
# step 4690, cost 936.569
# step 4690, change in cost 0.03479
# step 4700, training accuracy 0.934359
# step 4700, cost 936.535
# step 4700, change in cost 0.03479
# step 4710, training accuracy 0.934359
# step 4710, cost 936.5
# step 4710, change in cost 0.0350342
# step 4720, training accuracy 0.934359
# step 4720, cost 936.464
# step 4720, change in cost 0.0350342
# step 4730, training accuracy 0.934359
# step 4730, cost 936.429
# step 4730, change in cost 0.0351562
# step 4740, training accuracy 0.934359
# step 4740, cost 936.394
# step 4740, change in cost 0.0352783
# step 4750, training accuracy 0.934359
# step 4750, cost 936.358
# step 4750, change in cost 0.0356445
# step 4760, training accuracy 0.934359
# step 4760, cost 936.323
# step 4760, change in cost 0.0354614
# step 4770, training accuracy 0.934359
# step 4770, cost 936.287
# step 4770, change in cost 0.0355835
# step 4780, training accuracy 0.934359
# step 4780, cost 936.251
# step 4780, change in cost 0.0358887
# step 4790, training accuracy 0.934359
# step 4790, cost 936.215
# step 4790, change in cost 0.0360107
# step 4800, training accuracy 0.934359
# step 4800, cost 936.179
# step 4800, change in cost 0.0362549
# step 4810, training accuracy 0.934359
# step 4810, cost 936.143
# step 4810, change in cost 0.0361328
# step 4820, training accuracy 0.934359
# step 4820, cost 936.106
# step 4820, change in cost 0.0366821
# step 4830, training accuracy 0.934359
# step 4830, cost 936.07
# step 4830, change in cost 0.0365601
# step 4840, training accuracy 0.934359
# step 4840, cost 936.033
# step 4840, change in cost 0.0365601
# step 4850, training accuracy 0.934359
# step 4850, cost 935.996
# step 4850, change in cost 0.0370483
# step 4860, training accuracy 0.934359
# step 4860, cost 935.959
# step 4860, change in cost 0.0369263
# step 4870, training accuracy 0.934359
# step 4870, cost 935.922
# step 4870, change in cost 0.0373535
# step 4880, training accuracy 0.934359
# step 4880, cost 935.885
# step 4880, change in cost 0.0373535
# step 4890, training accuracy 0.934359
# step 4890, cost 935.847
# step 4890, change in cost 0.0375977
# step 4900, training accuracy 0.934359
# step 4900, cost 935.809
# step 4900, change in cost 0.0375366
# step 4910, training accuracy 0.934359
# step 4910, cost 935.771
# step 4910, change in cost 0.0379639
# step 4920, training accuracy 0.934359
# step 4920, cost 935.733
# step 4920, change in cost 0.0380859
# step 4930, training accuracy 0.934359
# step 4930, cost 935.695
# step 4930, change in cost 0.0380859
# step 4940, training accuracy 0.934359
# step 4940, cost 935.657
# step 4940, change in cost 0.0383301
# step 4950, training accuracy 0.934359
# step 4950, cost 935.619
# step 4950, change in cost 0.038269
# step 4960, training accuracy 0.934359
# step 4960, cost 935.58
# ...
# step 18400, cost 314.036
# step 18400, change in cost 0.141937
# step 18410, training accuracy 0.975255
# step 18410, cost 313.894
# step 18410, change in cost 0.141937
# step 18420, training accuracy 0.975255
# step 18420, cost 313.752
# step 18420, change in cost 0.141724
# step 18430, training accuracy 0.975255
# step 18430, cost 313.611
# step 18430, change in cost 0.141266
# step 18440, training accuracy 0.975255
# step 18440, cost 313.47
# step 18440, change in cost 0.140472
# step 18450, training accuracy 0.975255
# step 18450, cost 313.331
# step 18450, change in cost 0.139648
# step 18460, training accuracy 0.975255
# step 18460, cost 313.192
# step 18460, change in cost 0.138367
# step 18470, training accuracy 0.975255
# step 18470, cost 313.055
# step 18470, change in cost 0.137024
# step 18480, training accuracy 0.975255
# step 18480, cost 312.92
# step 18480, change in cost 0.135559
# step 18490, training accuracy 0.975255
# step 18490, cost 312.786
# step 18490, change in cost 0.133881
# step 18500, training accuracy 0.975255
# step 18500, cost 312.654
# step 18500, change in cost 0.132294
# step 18510, training accuracy 0.975255
# step 18510, cost 312.523
# step 18510, change in cost 0.130615
# step 18520, training accuracy 0.975255
# step 18520, cost 312.394
# step 18520, change in cost 0.128967
# step 18530, training accuracy 0.975255
# step 18530, cost 312.267
# step 18530, change in cost 0.127533
# step 18540, training accuracy 0.975255
# step 18540, cost 312.141
# step 18540, change in cost 0.125977
# step 18550, training accuracy 0.975255
# step 18550, cost 312.016
# step 18550, change in cost 0.124359
# step 18560, training accuracy 0.975255
# step 18560, cost 311.893
# step 18560, change in cost 0.122864
# step 18570, training accuracy 0.975255
# step 18570, cost 311.772
# step 18570, change in cost 0.121277
# step 18580, training accuracy 0.975255
# step 18580, cost 311.652
# step 18580, change in cost 0.11969
# step 18590, training accuracy 0.975255
# step 18590, cost 311.534
# step 18590, change in cost 0.118134
# step 18600, training accuracy 0.975324
# step 18600, cost 311.418
# step 18600, change in cost 0.11618
# step 18610, training accuracy 0.975324
# step 18610, cost 311.304
# step 18610, change in cost 0.114502
# step 18620, training accuracy 0.975324
# step 18620, cost 311.191
# step 18620, change in cost 0.112335
# step 18630, training accuracy 0.975324
# step 18630, cost 311.081
# step 18630, change in cost 0.110504
# step 18640, training accuracy 0.975324
# step 18640, cost 310.972
# step 18640, change in cost 0.108429
# step 18650, training accuracy 0.975324
# step 18650, cost 310.866
# step 18650, change in cost 0.106476
# step 18660, training accuracy 0.975324
# step 18660, cost 310.761
# step 18660, change in cost 0.10437
# step 18670, training accuracy 0.975324
# step 18670, cost 310.659
# step 18670, change in cost 0.102478
# step 18680, training accuracy 0.975324
# step 18680, cost 310.558
# step 18680, change in cost 0.100647
# step 18690, training accuracy 0.975324
# step 18690, cost 310.459
# step 18690, change in cost 0.0989685
# step 18700, training accuracy 0.975324
# step 18700, cost 310.362
# step 18700, change in cost 0.097229
# step 18710, training accuracy 0.975324
# step 18710, cost 310.266
# step 18710, change in cost 0.0957947
# step 18720, training accuracy 0.975324
# step 18720, cost 310.172
# step 18720, change in cost 0.0942383
# step 18730, training accuracy 0.975324
# step 18730, cost 310.079
# step 18730, change in cost 0.0930176
# step 18740, training accuracy 0.975324
# step 18740, cost 309.987
# step 18740, change in cost 0.0916443
# step 18750, training accuracy 0.975324
# step 18750, cost 309.897
# step 18750, change in cost 0.0906982
# step 18760, training accuracy 0.975324
# step 18760, cost 309.807
# step 18760, change in cost 0.0895691
# step 18770, training accuracy 0.975324
# step 18770, cost 309.719
# step 18770, change in cost 0.0884094
# step 18780, training accuracy 0.975393
# step 18780, cost 309.631
# step 18780, change in cost 0.0874329
# step 18790, training accuracy 0.975463
# step 18790, cost 309.545
# step 18790, change in cost 0.086731
# step 18800, training accuracy 0.975463
# step 18800, cost 309.459
# step 18800, change in cost 0.0858154
# step 18810, training accuracy 0.975463
# step 18810, cost 309.374
# step 18810, change in cost 0.085083
# step 18820, training accuracy 0.975463
# step 18820, cost 309.289
# step 18820, change in cost 0.0843506
# step 18830, training accuracy 0.975463
# step 18830, cost 309.206
# step 18830, change in cost 0.0837402
# step 18840, training accuracy 0.975463
# step 18840, cost 309.122
# step 18840, change in cost 0.0831909
# step 18850, training accuracy 0.975463
# step 18850, cost 309.04
# step 18850, change in cost 0.08255
# step 18860, training accuracy 0.975463
# step 18860, cost 308.958
# step 18860, change in cost 0.0819702
# step 18870, training accuracy 0.975463
# step 18870, cost 308.876
# step 18870, change in cost 0.0816345
# step 18880, training accuracy 0.975463
# step 18880, cost 308.795
# step 18880, change in cost 0.0811768
# step 18890, training accuracy 0.975463
# step 18890, cost 308.714
# step 18890, change in cost 0.0808105
# step 18900, training accuracy 0.975463
# step 18900, cost 308.634
# step 18900, change in cost 0.0805054
# step 18910, training accuracy 0.975463
# step 18910, cost 308.553
# step 18910, change in cost 0.0803223
# step 18920, training accuracy 0.975463
# step 18920, cost 308.473
# step 18920, change in cost 0.0800171
# step 18930, training accuracy 0.975463
# step 18930, cost 308.393
# step 18930, change in cost 0.0799866
# step 18940, training accuracy 0.975463
# step 18940, cost 308.314
# step 18940, change in cost 0.0798645
# step 18950, training accuracy 0.975463
# step 18950, cost 308.234
# step 18950, change in cost 0.0800171
# step 18960, training accuracy 0.975463
# step 18960, cost 308.154
# step 18960, change in cost 0.0800171
# step 18970, training accuracy 0.975463
# step 18970, cost 308.073
# step 18970, change in cost 0.0801392
# step 18980, training accuracy 0.975532
# step 18980, cost 307.993
# step 18980, change in cost 0.0804138
# step 18990, training accuracy 0.975532
# step 18990, cost 307.912
# step 18990, change in cost 0.0808411
# step 19000, training accuracy 0.975532
# step 19000, cost 307.831
# step 19000, change in cost 0.0814209
# step 19010, training accuracy 0.975532
# step 19010, cost 307.749
# step 19010, change in cost 0.0819702
# step 19020, training accuracy 0.975532
# step 19020, cost 307.666
# step 19020, change in cost 0.0826416
# step 19030, training accuracy 0.975532
# step 19030, cost 307.582
# step 19030, change in cost 0.0836792
# step 19040, training accuracy 0.975601
# step 19040, cost 307.498
# step 19040, change in cost 0.0846863
# step 19050, training accuracy 0.975601
# step 19050, cost 307.412
# step 19050, change in cost 0.0860291
# step 19060, training accuracy 0.975601
# step 19060, cost 307.324
# step 19060, change in cost 0.0873413
# step 19070, training accuracy 0.975601
# step 19070, cost 307.235
# step 19070, change in cost 0.0891113
# step 19080, training accuracy 0.975601
# step 19080, cost 307.144
# step 19080, change in cost 0.091156
# step 19090, training accuracy 0.975601
# step 19090, cost 307.051
# step 19090, change in cost 0.0931702
# step 19100, training accuracy 0.975601
# step 19100, cost 306.956
# step 19100, change in cost 0.095459
# step 19110, training accuracy 0.975601
# step 19110, cost 306.857
# step 19110, change in cost 0.0980225
# step 19120, training accuracy 0.975601
# step 19120, cost 306.757
# step 19120, change in cost 0.100647
# step 19130, training accuracy 0.975601
# step 19130, cost 306.654
# step 19130, change in cost 0.10318
# step 19140, training accuracy 0.975601
# step 19140, cost 306.548
# step 19140, change in cost 0.105743
# step 19150, training accuracy 0.975601
# step 19150, cost 306.44
# step 19150, change in cost 0.10791
# step 19160, training accuracy 0.97574
# step 19160, cost 306.33
# step 19160, change in cost 0.109863
# step 19170, training accuracy 0.97574
# step 19170, cost 306.219
# step 19170, change in cost 0.111328
# step 19180, training accuracy 0.97574
# step 19180, cost 306.106
# step 19180, change in cost 0.112671
# step 19190, training accuracy 0.97574
# step 19190, cost 305.992
# step 19190, change in cost 0.114044
# step 19200, training accuracy 0.97574
# step 19200, cost 305.877
# step 19200, change in cost 0.115265
# step 19210, training accuracy 0.97574
# step 19210, cost 305.76
# step 19210, change in cost 0.116974
# step 19220, training accuracy 0.97574
# step 19220, cost 305.641
# step 19220, change in cost 0.119293
# step 19230, training accuracy 0.97574
# step 19230, cost 305.519
# step 19230, change in cost 0.121948
# step 19240, training accuracy 0.97574
# step 19240, cost 305.393
# step 19240, change in cost 0.12561
# step 19250, training accuracy 0.97574
# step 19250, cost 305.263
# step 19250, change in cost 0.130005
# step 19260, training accuracy 0.97574
# step 19260, cost 305.128
# step 19260, change in cost 0.135498
# step 19270, training accuracy 0.97574
# step 19270, cost 304.986
# step 19270, change in cost 0.141724
# step 19280, training accuracy 0.975809
# step 19280, cost 304.837
# step 19280, change in cost 0.148743
# step 19290, training accuracy 0.975809
# step 19290, cost 304.681
# step 19290, change in cost 0.156311
# step 19300, training accuracy 0.975809
# step 19300, cost 304.517
# step 19300, change in cost 0.163574
# step 19310, training accuracy 0.975809
# step 19310, cost 304.347
# step 19310, change in cost 0.1698
# step 19320, training accuracy 0.975809
# step 19320, cost 304.173
# step 19320, change in cost 0.174774
# step 19330, training accuracy 0.975809
# step 19330, cost 303.994
# step 19330, change in cost 0.178711
# step 19340, training accuracy 0.975809
# step 19340, cost 303.812
# step 19340, change in cost 0.181793
# step 19350, training accuracy 0.975809
# step 19350, cost 303.626
# step 19350, change in cost 0.185638
# step 19360, training accuracy 0.975809
# step 19360, cost 303.437
# step 19360, change in cost 0.189423
# step 19370, training accuracy 0.975879
# step 19370, cost 303.243
# step 19370, change in cost 0.193726
# step 19380, training accuracy 0.975879
# step 19380, cost 303.046
# step 19380, change in cost 0.197754
# step 19390, training accuracy 0.975948
# step 19390, cost 302.845
# step 19390, change in cost 0.200989
# step 19400, training accuracy 0.976017
# step 19400, cost 302.641
# step 19400, change in cost 0.203217
# step 19410, training accuracy 0.976086
# step 19410, cost 302.438
# step 19410, change in cost 0.203644
# step 19420, training accuracy 0.976086
# step 19420, cost 302.235
# step 19420, change in cost 0.202515
# step 19430, training accuracy 0.976156
# step 19430, cost 302.035
# step 19430, change in cost 0.200195
# step 19440, training accuracy 0.976156
# step 19440, cost 301.838
# step 19440, change in cost 0.197357
# step 19450, training accuracy 0.976156
# step 19450, cost 301.643
# step 19450, change in cost 0.194122
# step 19460, training accuracy 0.976156
# step 19460, cost 301.452
# step 19460, change in cost 0.191406
# step 19470, training accuracy 0.976156
# step 19470, cost 301.263
# step 19470, change in cost 0.189026
# step 19480, training accuracy 0.976156
# step 19480, cost 301.076
# step 19480, change in cost 0.187439
# step 19490, training accuracy 0.976156
# step 19490, cost 300.89
# step 19490, change in cost 0.186096
# step 19500, training accuracy 0.976156
# step 19500, cost 300.705
# step 19500, change in cost 0.184509
# step 19510, training accuracy 0.976156
# step 19510, cost 300.524
# step 19510, change in cost 0.181335
# step 19520, training accuracy 0.976156
# step 19520, cost 300.347
# step 19520, change in cost 0.177002
# step 19530, training accuracy 0.976225
# step 19530, cost 300.176
# step 19530, change in cost 0.171021
# step 19540, training accuracy 0.976225
# step 19540, cost 300.011
# step 19540, change in cost 0.164642
# step 19550, training accuracy 0.976225
# step 19550, cost 299.852
# step 19550, change in cost 0.158722
# step 19560, training accuracy 0.976225
# step 19560, cost 299.699
# step 19560, change in cost 0.153534
# step 19570, training accuracy 0.976294
# step 19570, cost 299.549
# step 19570, change in cost 0.149597
# step 19580, training accuracy 0.976294
# step 19580, cost 299.402
# step 19580, change in cost 0.146912
# step 19590, training accuracy 0.976294
# step 19590, cost 299.257
# step 19590, change in cost 0.14505
# step 19600, training accuracy 0.976294
# step 19600, cost 299.113
# step 19600, change in cost 0.144226
# step 19610, training accuracy 0.976294
# step 19610, cost 298.969
# step 19610, change in cost 0.143829
# step 19620, training accuracy 0.976294
# step 19620, cost 298.825
# step 19620, change in cost 0.144073
# step 19630, training accuracy 0.976294
# step 19630, cost 298.681
# step 19630, change in cost 0.144409
# step 19640, training accuracy 0.976294
# step 19640, cost 298.536
# step 19640, change in cost 0.14447
# step 19650, training accuracy 0.976364
# step 19650, cost 298.392
# step 19650, change in cost 0.144043
# step 19660, training accuracy 0.976364
# step 19660, cost 298.249
# step 19660, change in cost 0.143372
# step 19670, training accuracy 0.976433
# step 19670, cost 298.107
# step 19670, change in cost 0.141663
# step 19680, training accuracy 0.976433
# step 19680, cost 297.967
# step 19680, change in cost 0.140076
# step 19690, training accuracy 0.976502
# step 19690, cost 297.829
# step 19690, change in cost 0.138123
# step 19700, training accuracy 0.976502
# step 19700, cost 297.693
# step 19700, change in cost 0.13623
# step 19710, training accuracy 0.976502
# step 19710, cost 297.558
# step 19710, change in cost 0.134735
# step 19720, training accuracy 0.976502
# step 19720, cost 297.424
# step 19720, change in cost 0.133545
# step 19730, training accuracy 0.976572
# step 19730, cost 297.292
# step 19730, change in cost 0.132538
# step 19740, training accuracy 0.976572
# step 19740, cost 297.16
# step 19740, change in cost 0.132294
# step 19750, training accuracy 0.976572
# step 19750, cost 297.028
# step 19750, change in cost 0.131927
# step 19760, training accuracy 0.976572
# step 19760, cost 296.896
# step 19760, change in cost 0.131927
# step 19770, training accuracy 0.976572
# step 19770, cost 296.764
# step 19770, change in cost 0.13205
# step 19780, training accuracy 0.976572
# step 19780, cost 296.631
# step 19780, change in cost 0.132568
# step 19790, training accuracy 0.976572
# step 19790, cost 296.498
# step 19790, change in cost 0.132751
# step 19800, training accuracy 0.976572
# step 19800, cost 296.365
# step 19800, change in cost 0.133484
# step 19810, training accuracy 0.976572
# step 19810, cost 296.231
# step 19810, change in cost 0.134155
# step 19820, training accuracy 0.976572
# step 19820, cost 296.096
# step 19820, change in cost 0.134521
# step 19830, training accuracy 0.976572
# step 19830, cost 295.961
# step 19830, change in cost 0.135315
# step 19840, training accuracy 0.976572
# step 19840, cost 295.825
# step 19840, change in cost 0.136139
# step 19850, training accuracy 0.976641
# step 19850, cost 295.688
# step 19850, change in cost 0.13678
# step 19860, training accuracy 0.976641
# step 19860, cost 295.55
# step 19860, change in cost 0.137756
# step 19870, training accuracy 0.976641
# step 19870, cost 295.412
# step 19870, change in cost 0.138397
# step 19880, training accuracy 0.976641
# step 19880, cost 295.273
# step 19880, change in cost 0.139099
# step 19890, training accuracy 0.976641
# step 19890, cost 295.133
# step 19890, change in cost 0.139832
# step 19900, training accuracy 0.976641
# step 19900, cost 294.992
# step 19900, change in cost 0.140381
# step 19910, training accuracy 0.976641
# step 19910, cost 294.852
# step 19910, change in cost 0.140869
# step 19920, training accuracy 0.976641
# step 19920, cost 294.711
# step 19920, change in cost 0.141083
# step 19930, training accuracy 0.976641
# step 19930, cost 294.569
# step 19930, change in cost 0.141205
# step 19940, training accuracy 0.976641
# step 19940, cost 294.428
# step 19940, change in cost 0.141327
# step 19950, training accuracy 0.97671
# step 19950, cost 294.286
# step 19950, change in cost 0.14151
# step 19960, training accuracy 0.97671
# step 19960, cost 294.144
# step 19960, change in cost 0.142029
# step 19970, training accuracy 0.97671
# step 19970, cost 294.002
# step 19970, change in cost 0.142517
# step 19980, training accuracy 0.97671
# step 19980, cost 293.859
# step 19980, change in cost 0.143372
# step 19990, training accuracy 0.97671
# step 19990, cost 293.714
# step 19990, change in cost 0.144684
# final accuracy on test set: 0.971945

# %% [markdown]
# # Import new set
# Now we'll bring in the 1000 most recent recipes published to Cookpad and return those which are identified by the algorithm as 'dinner' so that we can subject them to human analysis.

# %%
data = rec_parse.parse_newest_recipes() 
print("data shape =", data.shape)
# Out:
# data shape = (1000, 4378)

# %%
import csv
with tf.Session() as lolo:
    saver.restore(lolo, '/tmp/breakfast-model')
    print("Model restored.")
    print("Checking ", len(data), "recipes.")
    
    predictions = lolo.run(activation_OP, feed_dict={X: data})
    
    id_set = []
    
    for index, i in enumerate(predictions):
        if i[0] > .95:
            id_set.append(index)
    
    for n in rec_parse.convert_to_id(id_set):  
        print('cookpad.com/us/recipes/' + n[1])
        
    print(len(id_set), "breakfast recipes detected")
# Out:
# Model restored.
# Checking  1000 recipes.
# cookpad.com/us/recipes/1779522
# cookpad.com/us/recipes/1899864
# cookpad.com/us/recipes/1900467
# cookpad.com/us/recipes/1894843
# cookpad.com/us/recipes/1894512
# cookpad.com/us/recipes/1893053
# cookpad.com/us/recipes/1888008
# cookpad.com/us/recipes/1886983
# cookpad.com/us/recipes/1886674
# cookpad.com/us/recipes/1883439
# cookpad.com/us/recipes/1880220
# cookpad.com/us/recipes/1875302
# cookpad.com/us/recipes/1873509
# cookpad.com/us/recipes/1871970
# cookpad.com/us/recipes/1867451
# cookpad.com/us/recipes/1866264
# cookpad.com/us/recipes/1866162
# cookpad.com/us/recipes/1866061
# cookpad.com/us/recipes/1866113
# cookpad.com/us/recipes/1860672
# cookpad.com/us/recipes/1858178
# cookpad.com/us/recipes/1855746
# cookpad.com/us/recipes/1850382
# cookpad.com/us/recipes/1850602
# cookpad.com/us/recipes/1845801
# cookpad.com/us/recipes/1842471
# cookpad.com/us/recipes/1840354
# cookpad.com/us/recipes/1663415
# cookpad.com/us/recipes/1441823
# cookpad.com/us/recipes/1836881
# cookpad.com/us/recipes/1836106
# cookpad.com/us/recipes/1825458
# cookpad.com/us/recipes/1822292
# cookpad.com/us/recipes/1818799
# cookpad.com/us/recipes/1817997
# cookpad.com/us/recipes/1817726
# cookpad.com/us/recipes/1812913
# cookpad.com/us/recipes/1812181
# cookpad.com/us/recipes/1811196
# cookpad.com/us/recipes/1799371
# cookpad.com/us/recipes/1802858
# cookpad.com/us/recipes/1799093
# cookpad.com/us/recipes/1797667
# cookpad.com/us/recipes/1795088
# cookpad.com/us/recipes/1795060
# cookpad.com/us/recipes/492252
# cookpad.com/us/recipes/1790188
# cookpad.com/us/recipes/1788000
# cookpad.com/us/recipes/1784243
# cookpad.com/us/recipes/1779491
# cookpad.com/us/recipes/1774453
# cookpad.com/us/recipes/1778808
# cookpad.com/us/recipes/1777392
# cookpad.com/us/recipes/1774606
# cookpad.com/us/recipes/1774472
# 55 breakfast recipes detected
