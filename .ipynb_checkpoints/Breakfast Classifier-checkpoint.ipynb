# %%
# %matplotlib inline

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import time
import rec_parse

# %% [markdown]
# # Collect Data
# To obtain data, a recipe is parsed to identify dictionary matches. Each dictionary entry corresponds to an index in recipe space. So, each recipe is represented as a vector in recipe space of dimension 4060. Beginnning with a set of 15768 recipe vectors. 10% of those vectors, at equal intervals are reserved as test data. The result should be 4 matrices, trainX representing 14191 recipe vectors, trainY representing binary labels for each of those recipes, testX representing 1577 recipe vectors on which to test, and testY reresenting labels for the test data. For the label matrices, a 1 in column 0 represents 'dinner', while a 1 in column 1 represents 'non-dinner'.

# %%
rec_parse.clear_data()

dinner_count = rec_parse.initialize_csv("rec_dinner_tag.csv")
breakfast_count = rec_parse.initialize_csv("breakfast_revision.csv")
dessert_count = rec_parse.initialize_csv("rec_modified_dessert_tag.csv")

data = rec_parse.generate_training_data()

dinner_labels = np.zeros((dinner_count, 2), dtype=np.int)
breakfast_labels = np.zeros((breakfast_count, 2), dtype=np.int)
dessert_labels = np.zeros((dessert_count, 2), dtype=np.int)
                          
for label in dinner_labels:
    label[1] = 1
                          
for label in breakfast_labels:
    label[] = 1
                          
for label in dessert_labels:
    label[1] = 1
    
labels = np.concatenate((dinner_labels, breakfast_labels), axis=0)
labels = np.concatenate((labels, dessert_labels), axis=0)

trainX, testX = rec_parse.split(data)
trainY, testY = rec_parse.split(labels)
                          
# # data = rec_parse.parse_recipes()
                          
# # trainX, testX = rec_parse.split(data)

# # trainY = np.zeros((len(data)-1577, 2), dtype=np.int)
# # testY = np.zeros([1577, 2], dtype=np.int)

# # for ind, row in enumerate(trainY):
# #     if ind > 1500:
# #         trainY[ind][1] = 1
# #     else:
# #         trainY[ind][0] = 1

# # for ind, row in enumerate(testY):
# #     if ind > 150:
# #         testY[ind][1] = 1
# #     else:
# #         testY[ind][0] = 1
        
print("Your data is ready.")
print("trainX shape =", trainX.shape)
print("trainY shape =", trainY.shape)
print("testX shape =", testX.shape)
print("testY shape =", testY.shape)

print(len(data))
# Out:
# Your data is ready.
# trainX shape = (14427, 4378)
# trainY shape = (14427, 2)
# testX shape = (1604, 4378)
# testY shape = (1604, 2)
# 16031

# %% [markdown]
# # Initialize graph features
#
# At line 4, numEpochs is set very low at 100. This low number of epochs results in a model that builds quickly, but has low accuracy. to experiment with a more accurate model, increase numEpochs to at least 2000. To train a production model, you would likely run close to 30k, and probably continue running until cost no longer changes, or does so minimally from epoch to epoch.

# %%
numFeatures = trainX.shape[1]
numLabels = trainY.shape[1]

numEpochs = 20000

tf.reset_default_graph()

learningRate = tf.train.exponential_decay(learning_rate=0.0008,
                                          global_step= 1,
                                          decay_steps=trainX.shape[0],
                                          decay_rate= 0.95,
                                          staircase=True)

X = tf.placeholder(tf.float32, [None, numFeatures])
yGold = tf.placeholder(tf.float32, [None, numLabels])

# %% [markdown]
# # Initialize variables

# %%
weights = tf.Variable(tf.random_normal([numFeatures,numLabels],
                                       mean=0,
                                       stddev=(np.sqrt(6/numFeatures+
                                                         numLabels+1)),
                                       name="weights"))

bias = tf.Variable(tf.random_normal([1,numLabels],
                                    mean=0,
                                    stddev=(np.sqrt(6/numFeatures+numLabels+1)),
                                    name="bias"))

init_OP = tf.global_variables_initializer()

for i in tf.global_variables():
    print(i)
# Out:
# Tensor("Variable/read:0", shape=(4378, 2), dtype=float32)
# Tensor("Variable_1/read:0", shape=(1, 2), dtype=float32)

# %% [markdown]
# # The algorithm
# Multiply trainX(14191, 4060) by weights(4060, 2), resulting in apply_weights_OP(14191, 2).
# And add the bias(1, 2), resulting in add_bias_OP(14191, 2)
#
# Activate using rectified linear:
# f(x) = max(0, x)
#
# Calculate loss using Mean Squared Error:
# $\frac{1}{n}\sum_{i=0}^n ({y}_{estimated}-{y}_{real})^2$
#
# Optimize using gradient descent.

# %%
# FEEDFORWARD ALGORITHM
apply_weights_OP = tf.matmul(X, weights, name="apply_weights")
add_bias_OP = tf.add(apply_weights_OP, bias, name="add_bias")
activation_OP = tf.nn.sigmoid(add_bias_OP, name="activation")

# COST FUNCTION i.e. MEAN SQUARED ERROR
cost_OP = tf.nn.l2_loss(activation_OP-yGold, name="squared_error_cost")

# OPTIMIZATION ALGORITHM i.e. GRADIENT DESCENT
training_OP = tf.train.GradientDescentOptimizer(learningRate).minimize(cost_OP)

# %% [markdown]
# #  Run training

# %%
# Training epochs
with tf.Session() as sess:
    sess.run(init_OP)

    ###########################
    ### GRAPH LIVE UPDATING ###
    ###########################

    epoch_values=[]
    accuracy_values=[]
    cost_values=[]
    
    # Turn on interactive plotting
    plt.ion()
    # Create the main, super plot
    fig = plt.figure()
    # Create two subplots on their own axes and give titles
    ax1 = plt.subplot("211")
    ax1.set_title("TRAINING ACCURACY", fontsize=10)
    ax2 = plt.subplot("212")
    ax2.set_title("TRAINING COST", fontsize=10)
    plt.tight_layout()


    #####################
    ### RUN THE GRAPH ###
    #####################

    ## Ops for vizualization
    # argmax(activation_OP, 1) gives the label our model thought was most likely
    # argmax(yGold, 1) is the correct label
    correct_predictions_OP = tf.equal(tf.argmax(activation_OP,1),tf.argmax(yGold,1))
    # False is 0 and True is 1, what was our average?
    accuracy_OP = tf.reduce_mean(tf.cast(correct_predictions_OP, "float"))
    # Summary op for regression output
    activation_summary_OP = tf.summary.histogram("output", activation_OP)
    # Summary op for accuracy
    accuracy_summary_OP = tf.summary.scalar("accuracy", accuracy_OP)
    # Summary op for cost
    cost_summary_OP = tf.summary.scalar("cost", cost_OP)
    # Summary ops to check how variables (W, b) are updating after each iteration
    weightSummary = tf.summary.histogram("weights", weights.eval(session=sess))
    biasSummary = tf.summary.histogram("biases", bias.eval(session=sess))
    # Merge all summaries
    all_summary_OPS = tf.summary.merge_all()
    # Summary writer
    writer = tf.summary.FileWriter("summary_logs", sess.graph)

    # Initialize reporting variables
    cost = 0
    diff = 1

    for i in range(numEpochs): 
        if i > 1 and diff < .0001:
            print("change in cost %g; convergence."%diff)
            break
        else:
            # Run training step
            step = sess.run(training_OP, feed_dict={X: trainX, yGold: trainY})
            
            # Report occasional stats
            if i % 10 == 0:
                # Add epoch to epoch_values
                epoch_values.append(i)
                # Generate accuracy stats on test data
                summary_results, train_accuracy, newCost = sess.run(
                    [all_summary_OPS, accuracy_OP, cost_OP],
                    feed_dict={X: trainX, yGold: trainY}
                )
                # Add accuracy to live graphing variable
                accuracy_values.append(train_accuracy)
                # Add cost to live graphing variable
                cost_values.append(newCost)
                # Write summary stats to writer
                writer.add_summary(summary_results, i)
                # Re-assign values for variables
                diff = abs(newCost - cost)
                cost = newCost

                #generate print statements
                print("step %d, training accuracy %g"%(i, train_accuracy))
                print("step %d, cost %g"%(i, newCost))
                print("step %d, change in cost %g"%(i, diff))

                # Plot progress to our two subplots
                accuracyLine, = ax1.plot(epoch_values, accuracy_values)
                costLine, = ax2.plot(epoch_values, cost_values)
                fig.canvas.draw()
                time.sleep(1)
    
    # Create Saver
    saver = tf.train.Saver()   
    saver.save(sess, '/tmp/breakfast-model')

    # How well do we perform on held-out test data?
    print("final accuracy on test set: %s" %str(sess.run(accuracy_OP,
                                                         feed_dict={X: testX,
                                                                    yGold: testY})))
# Out:
# step 0, training accuracy 0.793928
# step 0, cost 3363.19
# step 0, change in cost 3363.19
# step 10, training accuracy 0.879046
# step 10, cost 1990.1
# step 10, change in cost 1373.09
# step 20, training accuracy 0.901435
# step 20, cost 1641.73
# step 20, change in cost 348.368
# step 30, training accuracy 0.912664
# step 30, cost 1463.41
# step 30, change in cost 178.323
# step 40, training accuracy 0.918694
# step 40, cost 1343.9
# step 40, change in cost 119.517
# step 50, training accuracy 0.92216
# step 50, cost 1260.88
# step 50, change in cost 83.015
# step 60, training accuracy 0.924932
# step 60, cost 1199.07
# step 60, change in cost 61.8054
# step 70, training accuracy 0.926665
# step 70, cost 1153.75
# step 70, change in cost 45.3225
# step 80, training accuracy 0.927705
# step 80, cost 1125.51
# step 80, change in cost 28.2385
# step 90, training accuracy 0.928052
# step 90, cost 1105.2
# step 90, change in cost 20.3179
# step 100, training accuracy 0.928745
# step 100, cost 1089.01
# step 100, change in cost 16.1819
# step 110, training accuracy 0.929299
# step 110, cost 1076.3
# step 110, change in cost 12.7113
# step 120, training accuracy 0.929715
# step 120, cost 1066.62
# step 120, change in cost 9.68457
# step 130, training accuracy 0.929923
# step 130, cost 1058.57
# step 130, change in cost 8.05115
# step 140, training accuracy 0.930131
# step 140, cost 1051.61
# step 140, change in cost 6.95435
# step 150, training accuracy 0.930547
# step 150, cost 1045.46
# step 150, change in cost 6.1543
# step 160, training accuracy 0.930686
# step 160, cost 1039.74
# step 160, change in cost 5.72266
# step 170, training accuracy 0.930893
# step 170, cost 1034.23
# step 170, change in cost 5.50879
# step 180, training accuracy 0.93124
# step 180, cost 1028.93
# step 180, change in cost 5.297
# step 190, training accuracy 0.931448
# step 190, cost 1024.11
# step 190, change in cost 4.81555
# step 200, training accuracy 0.931725
# step 200, cost 1020.03
# step 200, change in cost 4.08472
# step 210, training accuracy 0.931795
# step 210, cost 1016.63
# step 210, change in cost 3.39844
# step 220, training accuracy 0.931933
# step 220, cost 1013.74
# step 220, change in cost 2.89264
# step 230, training accuracy 0.931933
# step 230, cost 1011.2
# step 230, change in cost 2.53998
# step 240, training accuracy 0.932002
# step 240, cost 1008.93
# step 240, change in cost 2.27356
# step 250, training accuracy 0.932002
# step 250, cost 1006.86
# step 250, change in cost 2.06287
# step 260, training accuracy 0.932141
# step 260, cost 1004.96
# step 260, change in cost 1.90295
# step 270, training accuracy 0.932072
# step 270, cost 1003.17
# step 270, change in cost 1.78821
# step 280, training accuracy 0.93221
# step 280, cost 1001.46
# step 280, change in cost 1.71002
# step 290, training accuracy 0.93221
# step 290, cost 999.803
# step 290, change in cost 1.65851
# step 300, training accuracy 0.93228
# step 300, cost 998.182
# step 300, change in cost 1.62109
# step 310, training accuracy 0.932349
# step 310, cost 996.599
# step 310, change in cost 1.58252
# step 320, training accuracy 0.932488
# step 320, cost 995.068
# step 320, change in cost 1.53131
# step 330, training accuracy 0.932557
# step 330, cost 993.603
# step 330, change in cost 1.4646
# step 340, training accuracy 0.932557
# step 340, cost 992.211
# step 340, change in cost 1.39258
# step 350, training accuracy 0.932557
# step 350, cost 990.885
# step 350, change in cost 1.32562
# step 360, training accuracy 0.932557
# step 360, cost 989.617
# step 360, change in cost 1.26746
# step 370, training accuracy 0.932557
# step 370, cost 988.399
# step 370, change in cost 1.21814
# step 380, training accuracy 0.932557
# step 380, cost 987.225
# step 380, change in cost 1.17456
# step 390, training accuracy 0.932557
# step 390, cost 986.089
# step 390, change in cost 1.13568
# step 400, training accuracy 0.932557
# step 400, cost 984.989
# step 400, change in cost 1.10004
# step 410, training accuracy 0.932557
# step 410, cost 983.921
# step 410, change in cost 1.06787
# step 420, training accuracy 0.932626
# step 420, cost 982.882
# step 420, change in cost 1.03894
# step 430, training accuracy 0.932626
# step 430, cost 981.867
# step 430, change in cost 1.01501
# step 440, training accuracy 0.932626
# step 440, cost 980.872
# step 440, change in cost 0.9953
# step 450, training accuracy 0.932626
# step 450, cost 979.891
# step 450, change in cost 0.980835
# step 460, training accuracy 0.932626
# step 460, cost 978.921
# step 460, change in cost 0.969788
# step 470, training accuracy 0.932765
# step 470, cost 977.961
# step 470, change in cost 0.960571
# step 480, training accuracy 0.932765
# step 480, cost 977.009
# step 480, change in cost 0.951904
# step 490, training accuracy 0.932834
# step 490, cost 976.066
# step 490, change in cost 0.942322
# step 500, training accuracy 0.932834
# step 500, cost 975.136
# step 500, change in cost 0.930237
# step 510, training accuracy 0.932834
# step 510, cost 974.221
# step 510, change in cost 0.9151
# step 520, training accuracy 0.932834
# step 520, cost 973.324
# step 520, change in cost 0.897156
# step 530, training accuracy 0.932904
# step 530, cost 972.445
# step 530, change in cost 0.878784
# step 540, training accuracy 0.932973
# step 540, cost 971.585
# step 540, change in cost 0.860657
# step 550, training accuracy 0.932973
# step 550, cost 970.741
# step 550, change in cost 0.843323
# step 560, training accuracy 0.932973
# step 560, cost 969.915
# step 560, change in cost 0.825928
# step 570, training accuracy 0.932973
# step 570, cost 969.108
# step 570, change in cost 0.807129
# step 580, training accuracy 0.932973
# step 580, cost 968.326
# step 580, change in cost 0.782288
# step 590, training accuracy 0.932973
# step 590, cost 967.576
# step 590, change in cost 0.749695
# step 600, training accuracy 0.932973
# step 600, cost 966.868
# step 600, change in cost 0.708496
# step 610, training accuracy 0.932973
# step 610, cost 966.204
# step 610, change in cost 0.663635
# step 620, training accuracy 0.932973
# step 620, cost 965.585
# step 620, change in cost 0.619019
# step 630, training accuracy 0.932973
# step 630, cost 965.007
# step 630, change in cost 0.57782
# step 640, training accuracy 0.933042
# step 640, cost 964.467
# step 640, change in cost 0.540161
# step 650, training accuracy 0.933042
# step 650, cost 963.962
# step 650, change in cost 0.505432
# step 660, training accuracy 0.933042
# step 660, cost 963.488
# step 660, change in cost 0.473389
# step 670, training accuracy 0.933042
# step 670, cost 963.045
# step 670, change in cost 0.443665
# step 680, training accuracy 0.933042
# step 680, cost 962.628
# step 680, change in cost 0.416077
# step 690, training accuracy 0.933042
# step 690, cost 962.237
# step 690, change in cost 0.390991
# step 700, training accuracy 0.933042
# step 700, cost 961.87
# step 700, change in cost 0.367859
# step 710, training accuracy 0.933042
# step 710, cost 961.523
# step 710, change in cost 0.347107
# step 720, training accuracy 0.933042
# step 720, cost 961.195
# step 720, change in cost 0.327576
# step 730, training accuracy 0.933042
# step 730, cost 960.885
# step 730, change in cost 0.309692
# step 740, training accuracy 0.933112
# step 740, cost 960.592
# step 740, change in cost 0.293335
# step 750, training accuracy 0.933112
# step 750, cost 960.314
# step 750, change in cost 0.278076
# step 760, training accuracy 0.933181
# step 760, cost 960.051
# step 760, change in cost 0.263306
# step 770, training accuracy 0.933181
# step 770, cost 959.801
# step 770, change in cost 0.249573
# step 780, training accuracy 0.933181
# step 780, cost 959.564
# step 780, change in cost 0.236877
# step 790, training accuracy 0.933181
# step 790, cost 959.34
# step 790, change in cost 0.224548
# step 800, training accuracy 0.933181
# step 800, cost 959.126
# step 800, change in cost 0.213562
# step 810, training accuracy 0.933181
# step 810, cost 958.923
# step 810, change in cost 0.202942
# step 820, training accuracy 0.933181
# step 820, cost 958.729
# step 820, change in cost 0.194153
# step 830, training accuracy 0.933181
# step 830, cost 958.543
# step 830, change in cost 0.18573
# step 840, training accuracy 0.933181
# step 840, cost 958.365
# step 840, change in cost 0.178467
# step 850, training accuracy 0.933181
# step 850, cost 958.193
# step 850, change in cost 0.171875
# step 860, training accuracy 0.933181
# step 860, cost 958.027
# step 860, change in cost 0.16626
# step 870, training accuracy 0.933181
# step 870, cost 957.866
# step 870, change in cost 0.160828
# step 880, training accuracy 0.933181
# step 880, cost 957.709
# step 880, change in cost 0.156372
# step 890, training accuracy 0.933181
# step 890, cost 957.557
# step 890, change in cost 0.1521
# step 900, training accuracy 0.933181
# step 900, cost 957.409
# step 900, change in cost 0.148499
# step 910, training accuracy 0.933181
# step 910, cost 957.264
# step 910, change in cost 0.145081
# step 920, training accuracy 0.933181
# step 920, cost 957.122
# step 920, change in cost 0.141907
# step 930, training accuracy 0.933181
# step 930, cost 956.982
# step 930, change in cost 0.139343
# step 940, training accuracy 0.933181
# step 940, cost 956.846
# step 940, change in cost 0.136719
# step 950, training accuracy 0.933181
# step 950, cost 956.711
# step 950, change in cost 0.134521
# step 960, training accuracy 0.933181
# step 960, cost 956.579
# step 960, change in cost 0.132324
# step 970, training accuracy 0.933181
# step 970, cost 956.448
# step 970, change in cost 0.130615
# step 980, training accuracy 0.933181
# step 980, cost 956.319
# step 980, change in cost 0.129089
# step 990, training accuracy 0.933181
# step 990, cost 956.192
# step 990, change in cost 0.127625
# step 1000, training accuracy 0.933181
# step 1000, cost 956.065
# step 1000, change in cost 0.126282
# step 1010, training accuracy 0.933181
# step 1010, cost 955.94
# step 1010, change in cost 0.12561
# step 1020, training accuracy 0.933181
# step 1020, cost 955.815
# step 1020, change in cost 0.125
# step 1030, training accuracy 0.933181
# step 1030, cost 955.69
# step 1030, change in cost 0.124634
# step 1040, training accuracy 0.933181
# step 1040, cost 955.565
# step 1040, change in cost 0.124695
# step 1050, training accuracy 0.933181
# step 1050, cost 955.44
# step 1050, change in cost 0.125427
# step 1060, training accuracy 0.933181
# step 1060, cost 955.314
# step 1060, change in cost 0.126038
# step 1070, training accuracy 0.933181
# step 1070, cost 955.186
# step 1070, change in cost 0.12738
# step 1080, training accuracy 0.933181
# step 1080, cost 955.057
# step 1080, change in cost 0.129333
# step 1090, training accuracy 0.933181
# step 1090, cost 954.925
# step 1090, change in cost 0.131836
# step 1100, training accuracy 0.933181
# step 1100, cost 954.79
# step 1100, change in cost 0.135376
# step 1110, training accuracy 0.933181
# step 1110, cost 954.651
# step 1110, change in cost 0.139404
# step 1120, training accuracy 0.933181
# step 1120, cost 954.506
# step 1120, change in cost 0.144775
# step 1130, training accuracy 0.933181
# step 1130, cost 954.355
# step 1130, change in cost 0.151001
# step 1140, training accuracy 0.933181
# step 1140, cost 954.196
# step 1140, change in cost 0.158569
# step 1150, training accuracy 0.933181
# step 1150, cost 954.029
# step 1150, change in cost 0.16687
# step 1160, training accuracy 0.933181
# step 1160, cost 953.853
# step 1160, change in cost 0.175903
# step 1170, training accuracy 0.933181
# step 1170, cost 953.669
# step 1170, change in cost 0.183899
# step 1180, training accuracy 0.933181
# step 1180, cost 953.479
# step 1180, change in cost 0.190247
# step 1190, training accuracy 0.933181
# step 1190, cost 953.285
# step 1190, change in cost 0.193848
# step 1200, training accuracy 0.933181
# step 1200, cost 953.09
# step 1200, change in cost 0.194946
# step 1210, training accuracy 0.933181
# step 1210, cost 952.895
# step 1210, change in cost 0.195251
# step 1220, training accuracy 0.933181
# step 1220, cost 952.701
# step 1220, change in cost 0.194641
# step 1230, training accuracy 0.933181
# step 1230, cost 952.507
# step 1230, change in cost 0.193909
# step 1240, training accuracy 0.933181
# step 1240, cost 952.314
# step 1240, change in cost 0.192444
# step 1250, training accuracy 0.933181
# step 1250, cost 952.123
# step 1250, change in cost 0.190796
# step 1260, training accuracy 0.933181
# step 1260, cost 951.935
# step 1260, change in cost 0.188843
# step 1270, training accuracy 0.933181
# step 1270, cost 951.748
# step 1270, change in cost 0.186584
# step 1280, training accuracy 0.933181
# step 1280, cost 951.563
# step 1280, change in cost 0.184998
# step 1290, training accuracy 0.933181
# step 1290, cost 951.379
# step 1290, change in cost 0.183594
# step 1300, training accuracy 0.933181
# step 1300, cost 951.196
# step 1300, change in cost 0.183289
# step 1310, training accuracy 0.933181
# step 1310, cost 951.013
# step 1310, change in cost 0.183044
# step 1320, training accuracy 0.933181
# step 1320, cost 950.829
# step 1320, change in cost 0.183716
# step 1330, training accuracy 0.933181
# step 1330, cost 950.646
# step 1330, change in cost 0.183472
# step 1340, training accuracy 0.933181
# step 1340, cost 950.463
# step 1340, change in cost 0.183105
# step 1350, training accuracy 0.933181
# step 1350, cost 950.281
# step 1350, change in cost 0.181396
# step 1360, training accuracy 0.933181
# step 1360, cost 950.103
# step 1360, change in cost 0.178833
# step 1370, training accuracy 0.933181
# step 1370, cost 949.927
# step 1370, change in cost 0.176025
# step 1380, training accuracy 0.93325
# step 1380, cost 949.753
# step 1380, change in cost 0.173218
# step 1390, training accuracy 0.93325
# step 1390, cost 949.582
# step 1390, change in cost 0.171021
# step 1400, training accuracy 0.93325
# step 1400, cost 949.413
# step 1400, change in cost 0.169189
# step 1410, training accuracy 0.93325
# step 1410, cost 949.246
# step 1410, change in cost 0.166931
# step 1420, training accuracy 0.93325
# step 1420, cost 949.082
# step 1420, change in cost 0.164368
# step 1430, training accuracy 0.93325
# step 1430, cost 948.921
# step 1430, change in cost 0.160583
# step 1440, training accuracy 0.93325
# step 1440, cost 948.765
# step 1440, change in cost 0.155945
# step 1450, training accuracy 0.93325
# step 1450, cost 948.614
# step 1450, change in cost 0.15155
# step 1460, training accuracy 0.93325
# step 1460, cost 948.467
# step 1460, change in cost 0.147156
# step 1470, training accuracy 0.93325
# step 1470, cost 948.323
# step 1470, change in cost 0.143677
# step 1480, training accuracy 0.93325
# step 1480, cost 948.181
# step 1480, change in cost 0.141541
# step 1490, training accuracy 0.93325
# step 1490, cost 948.04
# step 1490, change in cost 0.140991
# step 1500, training accuracy 0.93325
# step 1500, cost 947.899
# step 1500, change in cost 0.141418
# step 1510, training accuracy 0.93325
# step 1510, cost 947.755
# step 1510, change in cost 0.143799
# step 1520, training accuracy 0.93325
# step 1520, cost 947.608
# step 1520, change in cost 0.147583
# step 1530, training accuracy 0.93325
# step 1530, cost 947.454
# step 1530, change in cost 0.153809
# step 1540, training accuracy 0.93325
# step 1540, cost 947.292
# step 1540, change in cost 0.161499
# step 1550, training accuracy 0.93325
# step 1550, cost 947.121
# step 1550, change in cost 0.170898
# step 1560, training accuracy 0.93325
# step 1560, cost 946.941
# step 1560, change in cost 0.180664
# step 1570, training accuracy 0.93325
# step 1570, cost 946.752
# step 1570, change in cost 0.188477
# step 1580, training accuracy 0.933319
# step 1580, cost 946.559
# step 1580, change in cost 0.193115
# step 1590, training accuracy 0.933319
# step 1590, cost 946.363
# step 1590, change in cost 0.196167
# step 1600, training accuracy 0.933319
# step 1600, cost 946.158
# step 1600, change in cost 0.204468
# step 1610, training accuracy 0.933389
# step 1610, cost 945.929
# step 1610, change in cost 0.229431
# step 1620, training accuracy 0.933458
# step 1620, cost 945.661
# step 1620, change in cost 0.2677
# step 1630, training accuracy 0.933458
# step 1630, cost 945.407
# step 1630, change in cost 0.253845
# step 1640, training accuracy 0.933458
# step 1640, cost 945.216
# step 1640, change in cost 0.19104
# step 1650, training accuracy 0.933458
# step 1650, cost 945.064
# step 1650, change in cost 0.152222
# step 1660, training accuracy 0.933458
# step 1660, cost 944.93
# step 1660, change in cost 0.13385
# step 1670, training accuracy 0.933458
# step 1670, cost 944.806
# step 1670, change in cost 0.124268
# step 1680, training accuracy 0.933458
# step 1680, cost 944.688
# step 1680, change in cost 0.118347
# step 1690, training accuracy 0.933458
# step 1690, cost 944.573
# step 1690, change in cost 0.114258
# step 1700, training accuracy 0.933458
# step 1700, cost 944.462
# step 1700, change in cost 0.111145
# step 1710, training accuracy 0.933458
# step 1710, cost 944.354
# step 1710, change in cost 0.108826
# step 1720, training accuracy 0.933458
# step 1720, cost 944.247
# step 1720, change in cost 0.106995
# step 1730, training accuracy 0.933458
# step 1730, cost 944.141
# step 1730, change in cost 0.10553
# step 1740, training accuracy 0.933458
# step 1740, cost 944.037
# step 1740, change in cost 0.10437
# step 1750, training accuracy 0.933458
# step 1750, cost 943.933
# step 1750, change in cost 0.103516
# step 1760, training accuracy 0.933458
# step 1760, cost 943.83
# step 1760, change in cost 0.102783
# step 1770, training accuracy 0.933458
# step 1770, cost 943.728
# step 1770, change in cost 0.102356
# step 1780, training accuracy 0.933458
# step 1780, cost 943.626
# step 1780, change in cost 0.101868
# step 1790, training accuracy 0.933458
# step 1790, cost 943.525
# step 1790, change in cost 0.101562
# step 1800, training accuracy 0.933458
# step 1800, cost 943.423
# step 1800, change in cost 0.101196
# step 1810, training accuracy 0.933458
# step 1810, cost 943.323
# step 1810, change in cost 0.100586
# step 1820, training accuracy 0.933458
# step 1820, cost 943.223
# step 1820, change in cost 0.0999146
# step 1830, training accuracy 0.933458
# step 1830, cost 943.124
# step 1830, change in cost 0.0990601
# step 1840, training accuracy 0.933458
# step 1840, cost 943.026
# step 1840, change in cost 0.0975342
# step 1850, training accuracy 0.933458
# step 1850, cost 942.93
# step 1850, change in cost 0.0963135
# step 1860, training accuracy 0.933458
# step 1860, cost 942.836
# step 1860, change in cost 0.0944214
# step 1870, training accuracy 0.933458
# step 1870, cost 942.743
# step 1870, change in cost 0.0925903
# step 1880, training accuracy 0.933458
# step 1880, cost 942.652
# step 1880, change in cost 0.0908203
# step 1890, training accuracy 0.933458
# step 1890, cost 942.563
# step 1890, change in cost 0.0887451
# step 1900, training accuracy 0.933458
# step 1900, cost 942.476
# step 1900, change in cost 0.0870361
# step 1910, training accuracy 0.933458
# step 1910, cost 942.391
# step 1910, change in cost 0.085083
# step 1920, training accuracy 0.933458
# step 1920, cost 942.308
# step 1920, change in cost 0.083374
# step 1930, training accuracy 0.933458
# step 1930, cost 942.226
# step 1930, change in cost 0.081543
# step 1940, training accuracy 0.933458
# step 1940, cost 942.146
# step 1940, change in cost 0.0799561
# step 1950, training accuracy 0.933458
# step 1950, cost 942.068
# step 1950, change in cost 0.078125
# step 1960, training accuracy 0.933458
# step 1960, cost 941.991
# step 1960, change in cost 0.0767822
# step 1970, training accuracy 0.933458
# step 1970, cost 941.916
# step 1970, change in cost 0.0751953
# step 1980, training accuracy 0.933458
# step 1980, cost 941.842
# step 1980, change in cost 0.0739136
# step 1990, training accuracy 0.933458
# step 1990, cost 941.77
# step 1990, change in cost 0.0724487
# step 2000, training accuracy 0.933458
# step 2000, cost 941.699
# step 2000, change in cost 0.0713501
# step 2010, training accuracy 0.933458
# step 2010, cost 941.628
# step 2010, change in cost 0.0704346
# step 2020, training accuracy 0.933458
# step 2020, cost 941.559
# step 2020, change in cost 0.0693359
# step 2030, training accuracy 0.933458
# step 2030, cost 941.49
# step 2030, change in cost 0.0685425
# step 2040, training accuracy 0.933458
# step 2040, cost 941.422
# step 2040, change in cost 0.0679932
# step 2050, training accuracy 0.933458
# step 2050, cost 941.355
# step 2050, change in cost 0.0673828
# step 2060, training accuracy 0.933458
# step 2060, cost 941.288
# step 2060, change in cost 0.0668945
# step 2070, training accuracy 0.933458
# step 2070, cost 941.221
# step 2070, change in cost 0.0664673
# step 2080, training accuracy 0.933458
# step 2080, cost 941.155
# step 2080, change in cost 0.0662231
# step 2090, training accuracy 0.933458
# step 2090, cost 941.089
# step 2090, change in cost 0.06604
# step 2100, training accuracy 0.933458
# step 2100, cost 941.023
# step 2100, change in cost 0.0657959
# step 2110, training accuracy 0.933458
# step 2110, cost 940.958
# step 2110, change in cost 0.0658569
# step 2120, training accuracy 0.933458
# step 2120, cost 940.892
# step 2120, change in cost 0.065979
# step 2130, training accuracy 0.933458
# step 2130, cost 940.826
# step 2130, change in cost 0.065918
# step 2140, training accuracy 0.933458
# step 2140, cost 940.76
# step 2140, change in cost 0.06604
# step 2150, training accuracy 0.933458
# step 2150, cost 940.693
# step 2150, change in cost 0.0662842
# step 2160, training accuracy 0.933458
# step 2160, cost 940.627
# step 2160, change in cost 0.0665283
# step 2170, training accuracy 0.933458
# step 2170, cost 940.56
# step 2170, change in cost 0.0670166
# step 2180, training accuracy 0.933458
# step 2180, cost 940.492
# step 2180, change in cost 0.0674438
# step 2190, training accuracy 0.933458
# step 2190, cost 940.424
# step 2190, change in cost 0.0679321
# step 2200, training accuracy 0.933458
# step 2200, cost 940.356
# step 2200, change in cost 0.0682373
# step 2210, training accuracy 0.933458
# step 2210, cost 940.287
# step 2210, change in cost 0.0689697
# step 2220, training accuracy 0.933458
# step 2220, cost 940.218
# step 2220, change in cost 0.069458
# step 2230, training accuracy 0.933458
# step 2230, cost 940.147
# step 2230, change in cost 0.0703125
# step 2240, training accuracy 0.933458
# step 2240, cost 940.077
# step 2240, change in cost 0.0706787
# step 2250, training accuracy 0.933458
# step 2250, cost 940.005
# step 2250, change in cost 0.0713501
# step 2260, training accuracy 0.933458
# step 2260, cost 939.934
# step 2260, change in cost 0.0718384
# step 2270, training accuracy 0.933458
# step 2270, cost 939.861
# step 2270, change in cost 0.0723877
# step 2280, training accuracy 0.933458
# step 2280, cost 939.789
# step 2280, change in cost 0.0724487
# step 2290, training accuracy 0.933458
# step 2290, cost 939.716
# step 2290, change in cost 0.0728149
# step 2300, training accuracy 0.933527
# step 2300, cost 939.643
# step 2300, change in cost 0.072876
# step 2310, training accuracy 0.933527
# step 2310, cost 939.57
# step 2310, change in cost 0.0728149
# step 2320, training accuracy 0.933527
# step 2320, cost 939.498
# step 2320, change in cost 0.0725708
# step 2330, training accuracy 0.933527
# step 2330, cost 939.425
# step 2330, change in cost 0.0725708
# step 2340, training accuracy 0.933527
# step 2340, cost 939.353
# step 2340, change in cost 0.0723877
# step 2350, training accuracy 0.933527
# step 2350, cost 939.281
# step 2350, change in cost 0.0721436
# step 2360, training accuracy 0.933527
# step 2360, cost 939.209
# step 2360, change in cost 0.0718384
# step 2370, training accuracy 0.933527
# step 2370, cost 939.137
# step 2370, change in cost 0.0720215
# step 2380, training accuracy 0.933527
# step 2380, cost 939.065
# step 2380, change in cost 0.0718384
# step 2390, training accuracy 0.933527
# step 2390, cost 938.993
# step 2390, change in cost 0.0723267
# step 2400, training accuracy 0.933527
# step 2400, cost 938.92
# step 2400, change in cost 0.0725098
# step 2410, training accuracy 0.933527
# step 2410, cost 938.847
# step 2410, change in cost 0.0733032
# step 2420, training accuracy 0.933527
# step 2420, cost 938.772
# step 2420, change in cost 0.0742798
# step 2430, training accuracy 0.933527
# step 2430, cost 938.697
# step 2430, change in cost 0.0754395
# step 2440, training accuracy 0.933527
# step 2440, cost 938.62
# step 2440, change in cost 0.0773315
# step 2450, training accuracy 0.933527
# step 2450, cost 938.54
# step 2450, change in cost 0.0793457
# step 2460, training accuracy 0.933527
# step 2460, cost 938.458
# step 2460, change in cost 0.0820923
# step 2470, training accuracy 0.933527
# step 2470, cost 938.373
# step 2470, change in cost 0.0853882
# step 2480, training accuracy 0.933527
# step 2480, cost 938.284
# step 2480, change in cost 0.0888672
# step 2490, training accuracy 0.933527
# step 2490, cost 938.192
# step 2490, change in cost 0.0924683
# step 2500, training accuracy 0.933527
# step 2500, cost 938.096
# step 2500, change in cost 0.095459
# step 2510, training accuracy 0.933527
# step 2510, cost 937.999
# step 2510, change in cost 0.0971069
# step 2520, training accuracy 0.933527
# step 2520, cost 937.902
# step 2520, change in cost 0.0968628
# step 2530, training accuracy 0.933527
# step 2530, cost 937.807
# step 2530, change in cost 0.0946045
# step 2540, training accuracy 0.933527
# step 2540, cost 937.716
# step 2540, change in cost 0.0913086
# step 2550, training accuracy 0.933527
# step 2550, cost 937.629
# step 2550, change in cost 0.0876465
# step 2560, training accuracy 0.933527
# step 2560, cost 937.544
# step 2560, change in cost 0.0842285
# step 2570, training accuracy 0.933527
# step 2570, cost 937.463
# step 2570, change in cost 0.0811768
# step 2580, training accuracy 0.933527
# step 2580, cost 937.384
# step 2580, change in cost 0.0791016
# step 2590, training accuracy 0.933527
# step 2590, cost 937.306
# step 2590, change in cost 0.0777588
# step 2600, training accuracy 0.933527
# step 2600, cost 937.23
# step 2600, change in cost 0.0765991
# step 2610, training accuracy 0.933527
# step 2610, cost 937.154
# step 2610, change in cost 0.0759888
# step 2620, training accuracy 0.933527
# step 2620, cost 937.078
# step 2620, change in cost 0.0758057
# step 2630, training accuracy 0.933527
# step 2630, cost 937.002
# step 2630, change in cost 0.0756226
# step 2640, training accuracy 0.933527
# step 2640, cost 936.927
# step 2640, change in cost 0.0755005
# step 2650, training accuracy 0.933527
# step 2650, cost 936.851
# step 2650, change in cost 0.0756226
# step 2660, training accuracy 0.933527
# step 2660, cost 936.776
# step 2660, change in cost 0.0754395
# step 2670, training accuracy 0.933527
# step 2670, cost 936.7
# step 2670, change in cost 0.0753784
# step 2680, training accuracy 0.933527
# step 2680, cost 936.625
# step 2680, change in cost 0.0754395
# step 2690, training accuracy 0.933527
# step 2690, cost 936.55
# step 2690, change in cost 0.0753174
# step 2700, training accuracy 0.933527
# step 2700, cost 936.474
# step 2700, change in cost 0.0751953
# step 2710, training accuracy 0.933597
# step 2710, cost 936.399
# step 2710, change in cost 0.0751953
# step 2720, training accuracy 0.933597
# step 2720, cost 936.324
# step 2720, change in cost 0.0751953
# step 2730, training accuracy 0.933666
# step 2730, cost 936.249
# step 2730, change in cost 0.0753174
# step 2740, training accuracy 0.933666
# step 2740, cost 936.173
# step 2740, change in cost 0.0756836
# step 2750, training accuracy 0.933666
# step 2750, cost 936.097
# step 2750, change in cost 0.0759888
# step 2760, training accuracy 0.933666
# step 2760, cost 936.02
# step 2760, change in cost 0.0768433
# step 2770, training accuracy 0.933666
# step 2770, cost 935.943
# step 2770, change in cost 0.0774536
# step 2780, training accuracy 0.933666
# step 2780, cost 935.864
# step 2780, change in cost 0.0787964
# step 2790, training accuracy 0.933666
# step 2790, cost 935.784
# step 2790, change in cost 0.0799561
# step 2800, training accuracy 0.933666
# step 2800, cost 935.702
# step 2800, change in cost 0.0817871
# step 2810, training accuracy 0.933666
# step 2810, cost 935.619
# step 2810, change in cost 0.0834961
# step 2820, training accuracy 0.933666
# step 2820, cost 935.533
# step 2820, change in cost 0.0858154
# step 2830, training accuracy 0.933666
# step 2830, cost 935.445
# step 2830, change in cost 0.0880127
# step 2840, training accuracy 0.933666
# step 2840, cost 935.354
# step 2840, change in cost 0.0906982
# step 2850, training accuracy 0.933666
# step 2850, cost 935.261
# step 2850, change in cost 0.0931396
# step 2860, training accuracy 0.933735
# step 2860, cost 935.165
# step 2860, change in cost 0.0956421
# step 2870, training accuracy 0.933735
# step 2870, cost 935.068
# step 2870, change in cost 0.0977173
# step 2880, training accuracy 0.933735
# step 2880, cost 934.968
# step 2880, change in cost 0.0995483
# step 2890, training accuracy 0.933735
# step 2890, cost 934.867
# step 2890, change in cost 0.100952
# step 2900, training accuracy 0.933735
# step 2900, cost 934.766
# step 2900, change in cost 0.101379
# step 2910, training accuracy 0.933735
# step 2910, cost 934.664
# step 2910, change in cost 0.101685
# step 2920, training accuracy 0.933805
# step 2920, cost 934.563
# step 2920, change in cost 0.101074
# step 2930, training accuracy 0.933805
# step 2930, cost 934.463
# step 2930, change in cost 0.10022
# step 2940, training accuracy 0.933805
# step 2940, cost 934.364
# step 2940, change in cost 0.0991821
# step 2950, training accuracy 0.933805
# step 2950, cost 934.266
# step 2950, change in cost 0.0977783
# step 2960, training accuracy 0.933805
# step 2960, cost 934.169
# step 2960, change in cost 0.0964966
# step 2970, training accuracy 0.933805
# step 2970, cost 934.074
# step 2970, change in cost 0.0951538
# step 2980, training accuracy 0.933805
# step 2980, cost 933.98
# step 2980, change in cost 0.0941162
# step 2990, training accuracy 0.933805
# step 2990, cost 933.887
# step 2990, change in cost 0.0930786
# step 3000, training accuracy 0.933805
# step 3000, cost 933.795
# step 3000, change in cost 0.0922852
# step 3010, training accuracy 0.933874
# step 3010, cost 933.703
# step 3010, change in cost 0.0912476
# step 3020, training accuracy 0.933874
# step 3020, cost 933.613
# step 3020, change in cost 0.0904541
# step 3030, training accuracy 0.933874
# step 3030, cost 933.524
# step 3030, change in cost 0.0892944
# step 3040, training accuracy 0.933874
# step 3040, cost 933.436
# step 3040, change in cost 0.0879517
# step 3050, training accuracy 0.933874
# step 3050, cost 933.349
# step 3050, change in cost 0.0864258
# step 3060, training accuracy 0.933874
# step 3060, cost 933.264
# step 3060, change in cost 0.0848999
# step 3070, training accuracy 0.933874
# step 3070, cost 933.182
# step 3070, change in cost 0.0828857
# step 3080, training accuracy 0.933874
# step 3080, cost 933.101
# step 3080, change in cost 0.0809937
# step 3090, training accuracy 0.933874
# step 3090, cost 933.021
# step 3090, change in cost 0.0790405
# step 3100, training accuracy 0.933874
# step 3100, cost 932.944
# step 3100, change in cost 0.0773926
# step 3110, training accuracy 0.933874
# step 3110, cost 932.868
# step 3110, change in cost 0.0758057
# step 3120, training accuracy 0.933874
# step 3120, cost 932.794
# step 3120, change in cost 0.074585
# step 3130, training accuracy 0.933874
# step 3130, cost 932.72
# step 3130, change in cost 0.0736084
# step 3140, training accuracy 0.933874
# step 3140, cost 932.647
# step 3140, change in cost 0.072998
# step 3150, training accuracy 0.933874
# step 3150, cost 932.575
# step 3150, change in cost 0.0725708
# step 3160, training accuracy 0.933874
# step 3160, cost 932.502
# step 3160, change in cost 0.0726318
# step 3170, training accuracy 0.933943
# step 3170, cost 932.429
# step 3170, change in cost 0.0730591
# step 3180, training accuracy 0.933943
# step 3180, cost 932.355
# step 3180, change in cost 0.0738525
# step 3190, training accuracy 0.933943
# step 3190, cost 932.28
# step 3190, change in cost 0.0748901
# step 3200, training accuracy 0.933943
# step 3200, cost 932.204
# step 3200, change in cost 0.076416
# step 3210, training accuracy 0.933943
# step 3210, cost 932.125
# step 3210, change in cost 0.0783081
# step 3220, training accuracy 0.933943
# step 3220, cost 932.045
# step 3220, change in cost 0.0806885
# step 3230, training accuracy 0.933943
# step 3230, cost 931.961
# step 3230, change in cost 0.0836182
# step 3240, training accuracy 0.933943
# step 3240, cost 931.874
# step 3240, change in cost 0.0866699
# step 3250, training accuracy 0.934013
# step 3250, cost 931.784
# step 3250, change in cost 0.0904541
# step 3260, training accuracy 0.934013
# step 3260, cost 931.689
# step 3260, change in cost 0.0947266
# step 3270, training accuracy 0.934082
# step 3270, cost 931.59
# step 3270, change in cost 0.0993652
# step 3280, training accuracy 0.934082
# step 3280, cost 931.485
# step 3280, change in cost 0.104492
# step 3290, training accuracy 0.934082
# step 3290, cost 931.376
# step 3290, change in cost 0.109558
# step 3300, training accuracy 0.934082
# step 3300, cost 931.26
# step 3300, change in cost 0.11554
# step 3310, training accuracy 0.934082
# step 3310, cost 931.139
# step 3310, change in cost 0.121338
# step 3320, training accuracy 0.934082
# step 3320, cost 931.012
# step 3320, change in cost 0.127197
# step 3330, training accuracy 0.934082
# step 3330, cost 930.878
# step 3330, change in cost 0.13324
# step 3340, training accuracy 0.934082
# step 3340, cost 930.739
# step 3340, change in cost 0.139526
# step 3350, training accuracy 0.934082
# step 3350, cost 930.593
# step 3350, change in cost 0.145813
# step 3360, training accuracy 0.934082
# step 3360, cost 930.44
# step 3360, change in cost 0.152649
# step 3370, training accuracy 0.934151
# step 3370, cost 930.28
# step 3370, change in cost 0.160095
# step 3380, training accuracy 0.934151
# step 3380, cost 930.113
# step 3380, change in cost 0.167725
# step 3390, training accuracy 0.93429
# step 3390, cost 929.936
# step 3390, change in cost 0.176575
# step 3400, training accuracy 0.93429
# step 3400, cost 929.749
# step 3400, change in cost 0.187073
# step 3410, training accuracy 0.93429
# step 3410, cost 929.548
# step 3410, change in cost 0.200684
# step 3420, training accuracy 0.93429
# step 3420, cost 929.33
# step 3420, change in cost 0.21875
# step 3430, training accuracy 0.93429
# step 3430, cost 929.092
# step 3430, change in cost 0.237366
# step 3440, training accuracy 0.93429
# step 3440, cost 928.848
# step 3440, change in cost 0.244202
# step 3450, training accuracy 0.93429
# step 3450, cost 928.618
# step 3450, change in cost 0.22998
# step 3460, training accuracy 0.93429
# step 3460, cost 928.412
# step 3460, change in cost 0.206421
# step 3470, training accuracy 0.93429
# step 3470, cost 928.225
# step 3470, change in cost 0.186401
# step 3480, training accuracy 0.93429
# step 3480, cost 928.052
# step 3480, change in cost 0.17334
# step 3490, training accuracy 0.93429
# step 3490, cost 927.886
# step 3490, change in cost 0.165527
# step 3500, training accuracy 0.93429
# step 3500, cost 927.725
# step 3500, change in cost 0.16095
# step 3510, training accuracy 0.93429
# step 3510, cost 927.567
# step 3510, change in cost 0.158203
# step 3520, training accuracy 0.93429
# step 3520, cost 927.41
# step 3520, change in cost 0.156982
# step 3530, training accuracy 0.93429
# step 3530, cost 927.254
# step 3530, change in cost 0.156677
# step 3540, training accuracy 0.93429
# step 3540, cost 927.096
# step 3540, change in cost 0.157715
# step 3550, training accuracy 0.934359
# step 3550, cost 926.936
# step 3550, change in cost 0.15979
# step 3560, training accuracy 0.934359
# step 3560, cost 926.773
# step 3560, change in cost 0.163025
# step 3570, training accuracy 0.934359
# step 3570, cost 926.605
# step 3570, change in cost 0.168091
# step 3580, training accuracy 0.934359
# step 3580, cost 926.43
# step 3580, change in cost 0.174744
# step 3590, training accuracy 0.934359
# step 3590, cost 926.246
# step 3590, change in cost 0.183716
# step 3600, training accuracy 0.934359
# step 3600, cost 926.051
# step 3600, change in cost 0.195496
# step 3610, training accuracy 0.934359
# step 3610, cost 925.841
# step 3610, change in cost 0.210266
# step 3620, training accuracy 0.934359
# step 3620, cost 925.612
# step 3620, change in cost 0.228333
# step 3630, training accuracy 0.934359
# step 3630, cost 925.364
# step 3630, change in cost 0.24884
# step 3640, training accuracy 0.934359
# step 3640, cost 925.095
# step 3640, change in cost 0.26886
# step 3650, training accuracy 0.934359
# step 3650, cost 924.812
# step 3650, change in cost 0.282898
# step 3660, training accuracy 0.934359
# step 3660, cost 924.529
# step 3660, change in cost 0.282898
# step 3670, training accuracy 0.934359
# step 3670, cost 924.262
# step 3670, change in cost 0.266663
# step 3680, training accuracy 0.934359
# step 3680, cost 924.023
# step 3680, change in cost 0.239136
# step 3690, training accuracy 0.934359
# step 3690, cost 923.814
# step 3690, change in cost 0.209351
# step 3700, training accuracy 0.934359
# step 3700, cost 923.631
# step 3700, change in cost 0.182861
# step 3710, training accuracy 0.934429
# step 3710, cost 923.47
# step 3710, change in cost 0.161133
# step 3720, training accuracy 0.934429
# step 3720, cost 923.325
# step 3720, change in cost 0.144287
# step 3730, training accuracy 0.934429
# step 3730, cost 923.194
# step 3730, change in cost 0.130981
# step 3740, training accuracy 0.934429
# step 3740, cost 923.074
# step 3740, change in cost 0.120483
# step 3750, training accuracy 0.934429
# step 3750, cost 922.962
# step 3750, change in cost 0.112183
# step 3760, training accuracy 0.934429
# step 3760, cost 922.857
# step 3760, change in cost 0.105286
# step 3770, training accuracy 0.934429
# step 3770, cost 922.757
# step 3770, change in cost 0.0997925
# step 3780, training accuracy 0.934429
# step 3780, cost 922.662
# step 3780, change in cost 0.0951538
# step 3790, training accuracy 0.934429
# step 3790, cost 922.57
# step 3790, change in cost 0.0914307
# step 3800, training accuracy 0.934429
# step 3800, cost 922.482
# step 3800, change in cost 0.0878906
# step 3810, training accuracy 0.934429
# step 3810, cost 922.397
# step 3810, change in cost 0.085144
# step 3820, training accuracy 0.934429
# step 3820, cost 922.314
# step 3820, change in cost 0.0829468
# step 3830, training accuracy 0.934429
# step 3830, cost 922.234
# step 3830, change in cost 0.0805054
# step 3840, training accuracy 0.934429
# step 3840, cost 922.155
# step 3840, change in cost 0.0789795
# step 3850, training accuracy 0.934429
# step 3850, cost 922.077
# step 3850, change in cost 0.0773315
# step 3860, training accuracy 0.934429
# step 3860, cost 922.001
# step 3860, change in cost 0.0760498
# step 3870, training accuracy 0.934429
# step 3870, cost 921.927
# step 3870, change in cost 0.0747681
# step 3880, training accuracy 0.934429
# step 3880, cost 921.853
# step 3880, change in cost 0.0738525
# step 3890, training accuracy 0.934429
# step 3890, cost 921.78
# step 3890, change in cost 0.0731201
# step 3900, training accuracy 0.934429
# step 3900, cost 921.707
# step 3900, change in cost 0.0721436
# step 3910, training accuracy 0.934429
# step 3910, cost 921.635
# step 3910, change in cost 0.0718994
# step 3920, training accuracy 0.934429
# step 3920, cost 921.564
# step 3920, change in cost 0.0712891
# step 3930, training accuracy 0.934429
# step 3930, cost 921.493
# step 3930, change in cost 0.071106
# step 3940, training accuracy 0.934429
# step 3940, cost 921.422
# step 3940, change in cost 0.0707397
# step 3950, training accuracy 0.934429
# step 3950, cost 921.351
# step 3950, change in cost 0.0710449
# step 3960, training accuracy 0.934429
# step 3960, cost 921.28
# step 3960, change in cost 0.0709229
# step 3970, training accuracy 0.934429
# step 3970, cost 921.209
# step 3970, change in cost 0.0714111
# step 3980, training accuracy 0.934429
# step 3980, cost 921.137
# step 3980, change in cost 0.0717773
# step 3990, training accuracy 0.934498
# step 3990, cost 921.065
# step 3990, change in cost 0.0720215
# step 4000, training accuracy 0.934498
# step 4000, cost 920.992
# step 4000, change in cost 0.0732422
# step 4010, training accuracy 0.934498
# step 4010, cost 920.918
# step 4010, change in cost 0.0740356
# step 4020, training accuracy 0.934498
# step 4020, cost 920.843
# step 4020, change in cost 0.0753174
# step 4030, training accuracy 0.934498
# step 4030, cost 920.766
# step 4030, change in cost 0.0765381
# step 4040, training accuracy 0.934498
# step 4040, cost 920.688
# step 4040, change in cost 0.0783691
# step 4050, training accuracy 0.934498
# step 4050, cost 920.607
# step 4050, change in cost 0.0803833
# step 4060, training accuracy 0.934567
# step 4060, cost 920.525
# step 4060, change in cost 0.0826416
# step 4070, training accuracy 0.934567
# step 4070, cost 920.439
# step 4070, change in cost 0.0854492
# step 4080, training accuracy 0.934567
# step 4080, cost 920.351
# step 4080, change in cost 0.088501
# step 4090, training accuracy 0.934636
# step 4090, cost 920.259
# step 4090, change in cost 0.092041
# step 4100, training accuracy 0.934636
# step 4100, cost 920.163
# step 4100, change in cost 0.0958252
# step 4110, training accuracy 0.934636
# step 4110, cost 920.062
# step 4110, change in cost 0.100342
# step 4120, training accuracy 0.934636
# step 4120, cost 919.958
# step 4120, change in cost 0.104858
# step 4130, training accuracy 0.934636
# step 4130, cost 919.848
# step 4130, change in cost 0.109741
# step 4140, training accuracy 0.934636
# step 4140, cost 919.733
# step 4140, change in cost 0.114502
# step 4150, training accuracy 0.934636
# step 4150, cost 919.614
# step 4150, change in cost 0.119202
# step 4160, training accuracy 0.934636
# step 4160, cost 919.491
# step 4160, change in cost 0.123169
# step 4170, training accuracy 0.934636
# step 4170, cost 919.364
# step 4170, change in cost 0.126648
# step 4180, training accuracy 0.934636
# step 4180, cost 919.235
# step 4180, change in cost 0.128906
# step 4190, training accuracy 0.934636
# step 4190, cost 919.105
# step 4190, change in cost 0.130371
# step 4200, training accuracy 0.934636
# step 4200, cost 918.974
# step 4200, change in cost 0.131165
# step 4210, training accuracy 0.934636
# step 4210, cost 918.843
# step 4210, change in cost 0.131409
# step 4220, training accuracy 0.934636
# step 4220, cost 918.711
# step 4220, change in cost 0.131592
# step 4230, training accuracy 0.934636
# step 4230, cost 918.579
# step 4230, change in cost 0.131958
# step 4240, training accuracy 0.934636
# step 4240, cost 918.446
# step 4240, change in cost 0.132507
# step 4250, training accuracy 0.934706
# step 4250, cost 918.313
# step 4250, change in cost 0.133057
# step 4260, training accuracy 0.934706
# step 4260, cost 918.18
# step 4260, change in cost 0.133728
# step 4270, training accuracy 0.934706
# step 4270, cost 918.046
# step 4270, change in cost 0.134155
# step 4280, training accuracy 0.934706
# step 4280, cost 917.911
# step 4280, change in cost 0.134033
# step 4290, training accuracy 0.934706
# step 4290, cost 917.778
# step 4290, change in cost 0.133301
# step 4300, training accuracy 0.934706
# step 4300, cost 917.646
# step 4300, change in cost 0.132385
# step 4310, training accuracy 0.934706
# step 4310, cost 917.515
# step 4310, change in cost 0.131042
# step 4320, training accuracy 0.934706
# step 4320, cost 917.384
# step 4320, change in cost 0.130371
# step 4330, training accuracy 0.934706
# step 4330, cost 917.254
# step 4330, change in cost 0.130005
# step 4340, training accuracy 0.934775
# step 4340, cost 917.124
# step 4340, change in cost 0.130615
# step 4350, training accuracy 0.934844
# step 4350, cost 916.991
# step 4350, change in cost 0.132935
# step 4360, training accuracy 0.934844
# step 4360, cost 916.855
# step 4360, change in cost 0.135925
# step 4370, training accuracy 0.934844
# step 4370, cost 916.714
# step 4370, change in cost 0.140625
# step 4380, training accuracy 0.934844
# step 4380, cost 916.568
# step 4380, change in cost 0.146484
# step 4390, training accuracy 0.934844
# step 4390, cost 916.414
# step 4390, change in cost 0.153992
# step 4400, training accuracy 0.934844
# step 4400, cost 916.251
# step 4400, change in cost 0.162354
# step 4410, training accuracy 0.934844
# step 4410, cost 916.081
# step 4410, change in cost 0.170776
# step 4420, training accuracy 0.934844
# step 4420, cost 915.902
# step 4420, change in cost 0.179077
# step 4430, training accuracy 0.934844
# step 4430, cost 915.715
# step 4430, change in cost 0.186523
# step 4440, training accuracy 0.934844
# step 4440, cost 915.521
# step 4440, change in cost 0.193726
# step 4450, training accuracy 0.934844
# step 4450, cost 915.32
# step 4450, change in cost 0.200928
# step 4460, training accuracy 0.934844
# step 4460, cost 915.111
# step 4460, change in cost 0.209595
# step 4470, training accuracy 0.934844
# step 4470, cost 914.89
# step 4470, change in cost 0.220703
# step 4480, training accuracy 0.934844
# step 4480, cost 914.656
# step 4480, change in cost 0.233826
# step 4490, training accuracy 0.934914
# step 4490, cost 914.409
# step 4490, change in cost 0.247437
# step 4500, training accuracy 0.934914
# step 4500, cost 914.15
# step 4500, change in cost 0.259094
# step 4510, training accuracy 0.934914
# step 4510, cost 913.881
# step 4510, change in cost 0.269104
# step 4520, training accuracy 0.934914
# step 4520, cost 913.6
# step 4520, change in cost 0.280701
# step 4530, training accuracy 0.934914
# step 4530, cost 913.302
# step 4530, change in cost 0.297607
# step 4540, training accuracy 0.935052
# step 4540, cost 912.984
# step 4540, change in cost 0.318726
# step 4550, training accuracy 0.935052
# step 4550, cost 912.646
# step 4550, change in cost 0.337463
# step 4560, training accuracy 0.935052
# step 4560, cost 912.299
# step 4560, change in cost 0.347534
# step 4570, training accuracy 0.935052
# step 4570, cost 911.948
# step 4570, change in cost 0.350281
# step 4580, training accuracy 0.935052
# step 4580, cost 911.594
# step 4580, change in cost 0.353882
# step 4590, training accuracy 0.935052
# step 4590, cost 911.231
# step 4590, change in cost 0.363403
# step 4600, training accuracy 0.935122
# step 4600, cost 910.853
# step 4600, change in cost 0.378296
# step 4610, training accuracy 0.935122
# step 4610, cost 910.461
# step 4610, change in cost 0.391479
# step 4620, training accuracy 0.935122
# step 4620, cost 910.063
# step 4620, change in cost 0.398254
# step 4630, training accuracy 0.935122
# step 4630, cost 909.665
# step 4630, change in cost 0.398132
# step 4640, training accuracy 0.935122
# step 4640, cost 909.268
# step 4640, change in cost 0.396423
# step 4650, training accuracy 0.935191
# step 4650, cost 908.87
# step 4650, change in cost 0.398926
# step 4660, training accuracy 0.935191
# step 4660, cost 908.46
# step 4660, change in cost 0.409424
# step 4670, training accuracy 0.935191
# step 4670, cost 908.031
# step 4670, change in cost 0.429626
# step 4680, training accuracy 0.93526
# step 4680, cost 907.573
# step 4680, change in cost 0.457336
# step 4690, training accuracy 0.93526
# step 4690, cost 907.09
# step 4690, change in cost 0.483459
# step 4700, training accuracy 0.93533
# step 4700, cost 906.597
# step 4700, change in cost 0.492615
# step 4710, training accuracy 0.93533
# step 4710, cost 906.121
# step 4710, change in cost 0.476074
# step 4720, training accuracy 0.935399
# step 4720, cost 905.677
# step 4720, change in cost 0.444153
# step 4730, training accuracy 0.935399
# step 4730, cost 905.265
# step 4730, change in cost 0.412292
# step 4740, training accuracy 0.935538
# step 4740, cost 904.877
# step 4740, change in cost 0.387146
# step 4750, training accuracy 0.935538
# step 4750, cost 904.508
# step 4750, change in cost 0.369385
# step 4760, training accuracy 0.935538
# step 4760, cost 904.148
# step 4760, change in cost 0.359619
# step 4770, training accuracy 0.935538
# step 4770, cost 903.792
# step 4770, change in cost 0.356506
# step 4780, training accuracy 0.935538
# step 4780, cost 903.431
# step 4780, change in cost 0.361267
# step 4790, training accuracy 0.935538
# step 4790, cost 903.059
# step 4790, change in cost 0.371826
# step 4800, training accuracy 0.935607
# step 4800, cost 902.671
# step 4800, change in cost 0.388245
# step 4810, training accuracy 0.935607
# step 4810, cost 902.264
# step 4810, change in cost 0.40625
# step 4820, training accuracy 0.935676
# step 4820, cost 901.842
# step 4820, change in cost 0.422424
# step 4830, training accuracy 0.935676
# step 4830, cost 901.407
# step 4830, change in cost 0.435242
# step 4840, training accuracy 0.935745
# step 4840, cost 900.959
# step 4840, change in cost 0.447693
# step 4850, training accuracy 0.935745
# step 4850, cost 900.497
# step 4850, change in cost 0.462341
# step 4860, training accuracy 0.935745
# step 4860, cost 900.019
# step 4860, change in cost 0.477478
# step 4870, training accuracy 0.935815
# step 4870, cost 899.534
# step 4870, change in cost 0.484741
# step 4880, training accuracy 0.935815
# step 4880, cost 899.056
# step 4880, change in cost 0.478882
# step 4890, training accuracy 0.935815
# step 4890, cost 898.592
# step 4890, change in cost 0.46344
# step 4900, training accuracy 0.935884
# step 4900, cost 898.146
# step 4900, change in cost 0.446045
# step 4910, training accuracy 0.935884
# step 4910, cost 897.714
# step 4910, change in cost 0.432434
# step 4920, training accuracy 0.935884
# step 4920, cost 897.286
# step 4920, change in cost 0.42749
# step 4930, training accuracy 0.935884
# step 4930, cost 896.85
# step 4930, change in cost 0.43634
# step 4940, training accuracy 0.935884
# step 4940, cost 896.386
# step 4940, change in cost 0.463318
# step 4950, training accuracy 0.936092
# step 4950, cost 895.872
# step 4950, change in cost 0.514343
# step 4960, training accuracy 0.936161
# step 4960, cost 895.287
# step 4960, change in cost 0.584656
# step 4970, training accuracy 0.936161
# step 4970, cost 894.635
# step 4970, change in cost 0.652283
# step 4980, training accuracy 0.936161
# ...
# step 18410, cost 634.941
# step 18410, change in cost 0.114441
# step 18420, training accuracy 0.951896
# step 18420, cost 634.828
# step 18420, change in cost 0.113037
# step 18430, training accuracy 0.951965
# step 18430, cost 634.716
# step 18430, change in cost 0.111816
# step 18440, training accuracy 0.951965
# step 18440, cost 634.605
# step 18440, change in cost 0.11084
# step 18450, training accuracy 0.951965
# step 18450, cost 634.495
# step 18450, change in cost 0.109741
# step 18460, training accuracy 0.952034
# step 18460, cost 634.386
# step 18460, change in cost 0.108887
# step 18470, training accuracy 0.952034
# step 18470, cost 634.278
# step 18470, change in cost 0.108154
# step 18480, training accuracy 0.952034
# step 18480, cost 634.171
# step 18480, change in cost 0.107422
# step 18490, training accuracy 0.952034
# step 18490, cost 634.064
# step 18490, change in cost 0.106567
# step 18500, training accuracy 0.952104
# step 18500, cost 633.958
# step 18500, change in cost 0.105957
# step 18510, training accuracy 0.952104
# step 18510, cost 633.853
# step 18510, change in cost 0.105347
# step 18520, training accuracy 0.952104
# step 18520, cost 633.748
# step 18520, change in cost 0.104736
# step 18530, training accuracy 0.952104
# step 18530, cost 633.644
# step 18530, change in cost 0.104431
# step 18540, training accuracy 0.952173
# step 18540, cost 633.54
# step 18540, change in cost 0.103821
# step 18550, training accuracy 0.952242
# step 18550, cost 633.437
# step 18550, change in cost 0.103149
# step 18560, training accuracy 0.952242
# step 18560, cost 633.334
# step 18560, change in cost 0.102783
# step 18570, training accuracy 0.952312
# step 18570, cost 633.232
# step 18570, change in cost 0.102234
# step 18580, training accuracy 0.952312
# step 18580, cost 633.13
# step 18580, change in cost 0.101685
# step 18590, training accuracy 0.952242
# step 18590, cost 633.029
# step 18590, change in cost 0.101257
# step 18600, training accuracy 0.952242
# step 18600, cost 632.928
# step 18600, change in cost 0.100464
# step 18610, training accuracy 0.952242
# step 18610, cost 632.828
# step 18610, change in cost 0.0999756
# step 18620, training accuracy 0.952242
# step 18620, cost 632.729
# step 18620, change in cost 0.0994873
# step 18630, training accuracy 0.952242
# step 18630, cost 632.63
# step 18630, change in cost 0.098877
# step 18640, training accuracy 0.952242
# step 18640, cost 632.531
# step 18640, change in cost 0.0983887
# step 18650, training accuracy 0.952242
# step 18650, cost 632.434
# step 18650, change in cost 0.0977783
# step 18660, training accuracy 0.952242
# step 18660, cost 632.336
# step 18660, change in cost 0.09729
# step 18670, training accuracy 0.952242
# step 18670, cost 632.24
# step 18670, change in cost 0.0967407
# step 18680, training accuracy 0.952242
# step 18680, cost 632.143
# step 18680, change in cost 0.0962524
# step 18690, training accuracy 0.952242
# step 18690, cost 632.048
# step 18690, change in cost 0.0958252
# step 18700, training accuracy 0.952242
# step 18700, cost 631.952
# step 18700, change in cost 0.0953369
# step 18710, training accuracy 0.952242
# step 18710, cost 631.857
# step 18710, change in cost 0.0950928
# step 18720, training accuracy 0.952242
# step 18720, cost 631.762
# step 18720, change in cost 0.0947266
# step 18730, training accuracy 0.952242
# step 18730, cost 631.668
# step 18730, change in cost 0.0944824
# step 18740, training accuracy 0.952242
# step 18740, cost 631.574
# step 18740, change in cost 0.0941772
# step 18750, training accuracy 0.952242
# step 18750, cost 631.48
# step 18750, change in cost 0.0939941
# step 18760, training accuracy 0.952312
# step 18760, cost 631.386
# step 18760, change in cost 0.093811
# step 18770, training accuracy 0.952312
# step 18770, cost 631.292
# step 18770, change in cost 0.0938721
# step 18780, training accuracy 0.952312
# step 18780, cost 631.199
# step 18780, change in cost 0.0935669
# step 18790, training accuracy 0.952312
# step 18790, cost 631.105
# step 18790, change in cost 0.093689
# step 18800, training accuracy 0.952242
# step 18800, cost 631.011
# step 18800, change in cost 0.0938721
# step 18810, training accuracy 0.952242
# step 18810, cost 630.917
# step 18810, change in cost 0.0938721
# step 18820, training accuracy 0.952242
# step 18820, cost 630.823
# step 18820, change in cost 0.0941162
# step 18830, training accuracy 0.952242
# step 18830, cost 630.729
# step 18830, change in cost 0.0943604
# step 18840, training accuracy 0.952242
# step 18840, cost 630.634
# step 18840, change in cost 0.0946045
# step 18850, training accuracy 0.952312
# step 18850, cost 630.539
# step 18850, change in cost 0.0952759
# step 18860, training accuracy 0.952312
# step 18860, cost 630.443
# step 18860, change in cost 0.0960083
# step 18870, training accuracy 0.952312
# step 18870, cost 630.347
# step 18870, change in cost 0.0961914
# step 18880, training accuracy 0.952242
# step 18880, cost 630.25
# step 18880, change in cost 0.0970459
# step 18890, training accuracy 0.952173
# step 18890, cost 630.152
# step 18890, change in cost 0.0975952
# step 18900, training accuracy 0.952173
# step 18900, cost 630.054
# step 18900, change in cost 0.0982056
# step 18910, training accuracy 0.952173
# step 18910, cost 629.955
# step 18910, change in cost 0.0982666
# step 18920, training accuracy 0.952242
# step 18920, cost 629.858
# step 18920, change in cost 0.0979004
# step 18930, training accuracy 0.952312
# step 18930, cost 629.76
# step 18930, change in cost 0.0970459
# step 18940, training accuracy 0.952312
# step 18940, cost 629.665
# step 18940, change in cost 0.0955811
# step 18950, training accuracy 0.952312
# step 18950, cost 629.571
# step 18950, change in cost 0.09375
# step 18960, training accuracy 0.952312
# step 18960, cost 629.48
# step 18960, change in cost 0.0914307
# step 18970, training accuracy 0.952312
# step 18970, cost 629.391
# step 18970, change in cost 0.0889893
# step 18980, training accuracy 0.952312
# step 18980, cost 629.304
# step 18980, change in cost 0.0866089
# step 18990, training accuracy 0.952381
# step 18990, cost 629.22
# step 18990, change in cost 0.0842285
# step 19000, training accuracy 0.952381
# step 19000, cost 629.138
# step 19000, change in cost 0.0819702
# step 19010, training accuracy 0.952381
# step 19010, cost 629.058
# step 19010, change in cost 0.0802002
# step 19020, training accuracy 0.952381
# step 19020, cost 628.979
# step 19020, change in cost 0.0784912
# step 19030, training accuracy 0.952381
# step 19030, cost 628.902
# step 19030, change in cost 0.0767822
# step 19040, training accuracy 0.952381
# step 19040, cost 628.827
# step 19040, change in cost 0.0755615
# step 19050, training accuracy 0.952381
# step 19050, cost 628.753
# step 19050, change in cost 0.0740967
# step 19060, training accuracy 0.952381
# step 19060, cost 628.68
# step 19060, change in cost 0.0732422
# step 19070, training accuracy 0.952381
# step 19070, cost 628.607
# step 19070, change in cost 0.0722656
# step 19080, training accuracy 0.95245
# step 19080, cost 628.536
# step 19080, change in cost 0.0715332
# step 19090, training accuracy 0.95245
# step 19090, cost 628.465
# step 19090, change in cost 0.0709229
# step 19100, training accuracy 0.95245
# step 19100, cost 628.395
# step 19100, change in cost 0.0703125
# step 19110, training accuracy 0.95245
# step 19110, cost 628.325
# step 19110, change in cost 0.0698853
# step 19120, training accuracy 0.95245
# step 19120, cost 628.255
# step 19120, change in cost 0.069519
# step 19130, training accuracy 0.95252
# step 19130, cost 628.186
# step 19130, change in cost 0.069397
# step 19140, training accuracy 0.95252
# step 19140, cost 628.117
# step 19140, change in cost 0.0690308
# step 19150, training accuracy 0.95252
# step 19150, cost 628.048
# step 19150, change in cost 0.0690918
# step 19160, training accuracy 0.95252
# step 19160, cost 627.979
# step 19160, change in cost 0.0689697
# step 19170, training accuracy 0.95252
# step 19170, cost 627.91
# step 19170, change in cost 0.0689697
# step 19180, training accuracy 0.95252
# step 19180, cost 627.841
# step 19180, change in cost 0.0690918
# step 19190, training accuracy 0.95252
# step 19190, cost 627.772
# step 19190, change in cost 0.0687866
# step 19200, training accuracy 0.95252
# step 19200, cost 627.703
# step 19200, change in cost 0.0689697
# step 19210, training accuracy 0.952589
# step 19210, cost 627.634
# step 19210, change in cost 0.0690308
# step 19220, training accuracy 0.952589
# step 19220, cost 627.565
# step 19220, change in cost 0.0689697
# step 19230, training accuracy 0.952658
# step 19230, cost 627.496
# step 19230, change in cost 0.0687866
# step 19240, training accuracy 0.952658
# step 19240, cost 627.427
# step 19240, change in cost 0.0686035
# step 19250, training accuracy 0.952658
# step 19250, cost 627.359
# step 19250, change in cost 0.0683594
# step 19260, training accuracy 0.952658
# step 19260, cost 627.291
# step 19260, change in cost 0.0679932
# step 19270, training accuracy 0.952727
# step 19270, cost 627.224
# step 19270, change in cost 0.0675659
# step 19280, training accuracy 0.952727
# step 19280, cost 627.156
# step 19280, change in cost 0.0670166
# step 19290, training accuracy 0.952727
# step 19290, cost 627.09
# step 19290, change in cost 0.0665283
# step 19300, training accuracy 0.952797
# step 19300, cost 627.024
# step 19300, change in cost 0.0656738
# step 19310, training accuracy 0.952797
# step 19310, cost 626.959
# step 19310, change in cost 0.0651855
# step 19320, training accuracy 0.952866
# step 19320, cost 626.895
# step 19320, change in cost 0.0645752
# step 19330, training accuracy 0.952866
# step 19330, cost 626.831
# step 19330, change in cost 0.0638428
# step 19340, training accuracy 0.952866
# step 19340, cost 626.768
# step 19340, change in cost 0.0630493
# step 19350, training accuracy 0.952866
# step 19350, cost 626.705
# step 19350, change in cost 0.0628052
# step 19360, training accuracy 0.952866
# step 19360, cost 626.643
# step 19360, change in cost 0.0618896
# step 19370, training accuracy 0.952866
# step 19370, cost 626.581
# step 19370, change in cost 0.0615845
# step 19380, training accuracy 0.952866
# step 19380, cost 626.52
# step 19380, change in cost 0.0611572
# step 19390, training accuracy 0.952866
# step 19390, cost 626.459
# step 19390, change in cost 0.0608521
# step 19400, training accuracy 0.952866
# step 19400, cost 626.399
# step 19400, change in cost 0.0606689
# step 19410, training accuracy 0.952866
# step 19410, cost 626.338
# step 19410, change in cost 0.0603638
# step 19420, training accuracy 0.952866
# step 19420, cost 626.278
# step 19420, change in cost 0.0604858
# step 19430, training accuracy 0.952866
# step 19430, cost 626.217
# step 19430, change in cost 0.0604248
# step 19440, training accuracy 0.952866
# step 19440, cost 626.157
# step 19440, change in cost 0.060791
# step 19450, training accuracy 0.952866
# step 19450, cost 626.096
# step 19450, change in cost 0.0610352
# step 19460, training accuracy 0.952866
# step 19460, cost 626.034
# step 19460, change in cost 0.0615845
# step 19470, training accuracy 0.952866
# step 19470, cost 625.972
# step 19470, change in cost 0.0620117
# step 19480, training accuracy 0.952866
# step 19480, cost 625.909
# step 19480, change in cost 0.0629272
# step 19490, training accuracy 0.952866
# step 19490, cost 625.845
# step 19490, change in cost 0.0639648
# step 19500, training accuracy 0.952866
# step 19500, cost 625.78
# step 19500, change in cost 0.0649414
# step 19510, training accuracy 0.952866
# step 19510, cost 625.714
# step 19510, change in cost 0.0661621
# step 19520, training accuracy 0.952866
# step 19520, cost 625.647
# step 19520, change in cost 0.0673828
# step 19530, training accuracy 0.952866
# step 19530, cost 625.578
# step 19530, change in cost 0.0687256
# step 19540, training accuracy 0.952797
# step 19540, cost 625.508
# step 19540, change in cost 0.0700684
# step 19550, training accuracy 0.952797
# step 19550, cost 625.437
# step 19550, change in cost 0.0712891
# step 19560, training accuracy 0.952797
# step 19560, cost 625.365
# step 19560, change in cost 0.0718994
# step 19570, training accuracy 0.952797
# step 19570, cost 625.292
# step 19570, change in cost 0.0725098
# step 19580, training accuracy 0.952797
# step 19580, cost 625.22
# step 19580, change in cost 0.0721436
# step 19590, training accuracy 0.952797
# step 19590, cost 625.149
# step 19590, change in cost 0.0714111
# step 19600, training accuracy 0.952797
# step 19600, cost 625.078
# step 19600, change in cost 0.0703735
# step 19610, training accuracy 0.952797
# step 19610, cost 625.009
# step 19610, change in cost 0.0689087
# step 19620, training accuracy 0.952797
# step 19620, cost 624.942
# step 19620, change in cost 0.0670776
# step 19630, training accuracy 0.952797
# step 19630, cost 624.877
# step 19630, change in cost 0.0651245
# step 19640, training accuracy 0.952797
# step 19640, cost 624.814
# step 19640, change in cost 0.0635376
# step 19650, training accuracy 0.952797
# step 19650, cost 624.752
# step 19650, change in cost 0.0618896
# step 19660, training accuracy 0.952797
# step 19660, cost 624.691
# step 19660, change in cost 0.0604858
# step 19670, training accuracy 0.952797
# step 19670, cost 624.632
# step 19670, change in cost 0.0593872
# step 19680, training accuracy 0.952797
# step 19680, cost 624.574
# step 19680, change in cost 0.0580444
# step 19690, training accuracy 0.952866
# step 19690, cost 624.516
# step 19690, change in cost 0.057251
# step 19700, training accuracy 0.952935
# step 19700, cost 624.46
# step 19700, change in cost 0.0563965
# step 19710, training accuracy 0.952935
# step 19710, cost 624.404
# step 19710, change in cost 0.0557861
# step 19720, training accuracy 0.953005
# step 19720, cost 624.349
# step 19720, change in cost 0.0552979
# step 19730, training accuracy 0.953005
# step 19730, cost 624.294
# step 19730, change in cost 0.0549316
# step 19740, training accuracy 0.953005
# step 19740, cost 624.24
# step 19740, change in cost 0.0545654
# step 19750, training accuracy 0.953005
# step 19750, cost 624.185
# step 19750, change in cost 0.0541992
# step 19760, training accuracy 0.953005
# step 19760, cost 624.131
# step 19760, change in cost 0.0540771
# step 19770, training accuracy 0.953005
# step 19770, cost 624.078
# step 19770, change in cost 0.0537109
# step 19780, training accuracy 0.953005
# step 19780, cost 624.024
# step 19780, change in cost 0.0536499
# step 19790, training accuracy 0.952935
# step 19790, cost 623.97
# step 19790, change in cost 0.0536499
# step 19800, training accuracy 0.952935
# step 19800, cost 623.917
# step 19800, change in cost 0.0534668
# step 19810, training accuracy 0.952935
# step 19810, cost 623.864
# step 19810, change in cost 0.0532227
# step 19820, training accuracy 0.952935
# step 19820, cost 623.81
# step 19820, change in cost 0.0532227
# step 19830, training accuracy 0.952935
# step 19830, cost 623.757
# step 19830, change in cost 0.0532837
# step 19840, training accuracy 0.952935
# step 19840, cost 623.704
# step 19840, change in cost 0.0532837
# step 19850, training accuracy 0.952935
# step 19850, cost 623.651
# step 19850, change in cost 0.0532227
# step 19860, training accuracy 0.952935
# step 19860, cost 623.597
# step 19860, change in cost 0.0531616
# step 19870, training accuracy 0.952935
# step 19870, cost 623.544
# step 19870, change in cost 0.0532837
# step 19880, training accuracy 0.952935
# step 19880, cost 623.491
# step 19880, change in cost 0.0531616
# step 19890, training accuracy 0.952935
# step 19890, cost 623.438
# step 19890, change in cost 0.0532837
# step 19900, training accuracy 0.953005
# step 19900, cost 623.384
# step 19900, change in cost 0.0533447
# step 19910, training accuracy 0.953005
# step 19910, cost 623.331
# step 19910, change in cost 0.0532227
# step 19920, training accuracy 0.953005
# step 19920, cost 623.278
# step 19920, change in cost 0.0533447
# step 19930, training accuracy 0.953005
# step 19930, cost 623.224
# step 19930, change in cost 0.0533447
# step 19940, training accuracy 0.953005
# step 19940, cost 623.171
# step 19940, change in cost 0.0535889
# step 19950, training accuracy 0.953005
# step 19950, cost 623.117
# step 19950, change in cost 0.0535889
# step 19960, training accuracy 0.953074
# step 19960, cost 623.064
# step 19960, change in cost 0.0535278
# step 19970, training accuracy 0.953074
# step 19970, cost 623.01
# step 19970, change in cost 0.053772
# step 19980, training accuracy 0.953074
# step 19980, cost 622.956
# step 19980, change in cost 0.0536499
# step 19990, training accuracy 0.953074
# step 19990, cost 622.902
# step 19990, change in cost 0.053894
# final accuracy on test set: 0.951372

# %% [markdown]
# # Import new set
# Now we'll bring in the 1000 most recent recipes published to Cookpad and return those which are identified by the algorithm as 'dinner' so that we can subject them to human analysis.

# %%
data = rec_parse.parse_newest_recipes() 
print("data shape =", data.shape)
# Out:
# data shape = (1000, 4378)

# %%
import csv
with tf.Session() as lolo:
    saver.restore(lolo, '/tmp/breakfast-model')
    print("Model restored.")
    print("Checking ", len(data), "recipes.")
    
    predictions = lolo.run(activation_OP, feed_dict={X: data})
    
    id_set = []
    
    for index, i in enumerate(predictions):
        if i[0] > .8:
            id_set.append(index)
    
    for n in rec_parse.convert_to_id(id_set):  
        print('cookpad.com/us/recipes/' + n[1])
        
    print(len(id_set), "breakfast recipes detected")
# Out:
#   File "<ipython-input-10-ded5bb412f5d>", line 12
#     if i[0] > .8
#                  ^
# SyntaxError: invalid syntax
