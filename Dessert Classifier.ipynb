# %%
# %matplotlib inline

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import time
import rec_parse

# %% [markdown]
# # Collect Data
# To obtain data, a recipe is parsed to identify dictionary matches. Each dictionary entry corresponds to an index in recipe space. So, each recipe is represented as a vector in recipe space of dimension 4060. Beginnning with a set of 15768 recipe vectors. 10% of those vectors, at equal intervals are reserved as test data. The result should be 4 matrices, trainX representing 14191 recipe vectors, trainY representing binary labels for each of those recipes, testX representing 1577 recipe vectors on which to test, and testY reresenting labels for the test data. For the label matrices, a 1 in column 0 represents 'dinner', while a 1 in column 1 represents 'non-dinner'.

# %%
rec_parse.clear_data()

dinner_count = rec_parse.initialize_csv("rec_dinner_tag.csv")
breakfast_count = rec_parse.initialize_csv("breakfast_clean.csv")
dessert_count = rec_parse.initialize_csv("dessert_clean.csv")

data = rec_parse.generate_training_data()

dinner_labels = np.zeros((dinner_count, 2), dtype=np.int)
breakfast_labels = np.zeros((breakfast_count, 2), dtype=np.int)
dessert_labels = np.zeros((dessert_count, 2), dtype=np.int)
                          
for label in dinner_labels:
    label[1] = 1
                          
for label in breakfast_labels:
    label[1] = 1
                          
for label in dessert_labels:
    label[0] = 1
    
labels = np.concatenate((dinner_labels, breakfast_labels), axis=0)
labels = np.concatenate((labels, dessert_labels), axis=0)

trainX, testX = rec_parse.split(data)
trainY, testY = rec_parse.split(labels)
                          
# # data = rec_parse.parse_recipes()
                          
# # trainX, testX = rec_parse.split(data)

# # trainY = np.zeros((len(data)-1577, 2), dtype=np.int)
# # testY = np.zeros([1577, 2], dtype=np.int)

# # for ind, row in enumerate(trainY):
# #     if ind > 1500:
# #         trainY[ind][1] = 1
# #     else:
# #         trainY[ind][0] = 1

# # for ind, row in enumerate(testY):
# #     if ind > 150:
# #         testY[ind][1] = 1
# #     else:
# #         testY[ind][0] = 1
        
print("Your data is ready.")
print("trainX shape =", trainX.shape)
print("trainY shape =", trainY.shape)
print("testX shape =", testX.shape)
print("testY shape =", testY.shape)

print(len(data))
# Out:
# Your data is ready.
# trainX shape = (12575, 4114)
# trainY shape = (12575, 2)
# testX shape = (1398, 4114)
# testY shape = (1398, 2)
# 13973

# %% [markdown]
# # Initialize graph features
#
# At line 4, numEpochs is set very low at 100. This low number of epochs results in a model that builds quickly, but has low accuracy. to experiment with a more accurate model, increase numEpochs to at least 2000. To train a production model, you would likely run close to 30k, and probably continue running until cost no longer changes, or does so minimally from epoch to epoch.

# %%
numFeatures = trainX.shape[1]
numLabels = trainY.shape[1]

numEpochs = 20000

tf.reset_default_graph()

learningRate = tf.train.exponential_decay(learning_rate=0.0008,
                                          global_step= 1,
                                          decay_steps=trainX.shape[0],
                                          decay_rate= 0.95,
                                          staircase=True)

X = tf.placeholder(tf.float32, [None, numFeatures])
yGold = tf.placeholder(tf.float32, [None, numLabels])

# %% [markdown]
# # Initialize variables

# %%
weights = tf.Variable(tf.random_normal([numFeatures,numLabels],
                                       mean=0,
                                       stddev=(np.sqrt(6/numFeatures+
                                                         numLabels+1)),
                                       name="weights"))

bias = tf.Variable(tf.random_normal([1,numLabels],
                                    mean=0,
                                    stddev=(np.sqrt(6/numFeatures+numLabels+1)),
                                    name="bias"))

init_OP = tf.global_variables_initializer()

for i in tf.global_variables():
    print(i)
# Out:
# Tensor("Variable/read:0", shape=(4114, 2), dtype=float32)
# Tensor("Variable_1/read:0", shape=(1, 2), dtype=float32)

# %% [markdown]
# # The algorithm
# Multiply trainX(14191, 4060) by weights(4060, 2), resulting in apply_weights_OP(14191, 2).
# And add the bias(1, 2), resulting in add_bias_OP(14191, 2)
#
# Activate using rectified linear:
# f(x) = max(0, x)
#
# Calculate loss using Mean Squared Error:
# $\frac{1}{n}\sum_{i=0}^n ({y}_{estimated}-{y}_{real})^2$
#
# Optimize using gradient descent.

# %%
# FEEDFORWARD ALGORITHM
apply_weights_OP = tf.matmul(X, weights, name="apply_weights")
add_bias_OP = tf.add(apply_weights_OP, bias, name="add_bias")
activation_OP = tf.nn.sigmoid(add_bias_OP, name="activation")

# COST FUNCTION i.e. MEAN SQUARED ERROR
cost_OP = tf.nn.l2_loss(activation_OP-yGold, name="squared_error_cost")

# OPTIMIZATION ALGORITHM i.e. GRADIENT DESCENT
training_OP = tf.train.GradientDescentOptimizer(learningRate).minimize(cost_OP)

# %% [markdown]
# #  Run training

# %%
# Training epochs
with tf.Session() as sess:
    sess.run(init_OP)

    ###########################
    ### GRAPH LIVE UPDATING ###
    ###########################

    epoch_values=[]
    accuracy_values=[]
    cost_values=[]
    
    # Turn on interactive plotting
    plt.ion()
    # Create the main, super plot
    fig = plt.figure()
    # Create two subplots on their own axes and give titles
    ax1 = plt.subplot("211")
    ax1.set_title("TRAINING ACCURACY", fontsize=10)
    ax2 = plt.subplot("212")
    ax2.set_title("TRAINING COST", fontsize=10)
    plt.tight_layout()


    #####################
    ### RUN THE GRAPH ###
    #####################

    ## Ops for vizualization
    # argmax(activation_OP, 1) gives the label our model thought was most likely
    # argmax(yGold, 1) is the correct label
    correct_predictions_OP = tf.equal(tf.argmax(activation_OP,1),tf.argmax(yGold,1))
    # False is 0 and True is 1, what was our average?
    accuracy_OP = tf.reduce_mean(tf.cast(correct_predictions_OP, "float"))
    # Summary op for regression output
    activation_summary_OP = tf.summary.histogram("output", activation_OP)
    # Summary op for accuracy
    accuracy_summary_OP = tf.summary.scalar("accuracy", accuracy_OP)
    # Summary op for cost
    cost_summary_OP = tf.summary.scalar("cost", cost_OP)
    # Summary ops to check how variables (W, b) are updating after each iteration
    weightSummary = tf.summary.histogram("weights", weights.eval(session=sess))
    biasSummary = tf.summary.histogram("biases", bias.eval(session=sess))
    # Merge all summaries
    all_summary_OPS = tf.summary.merge_all()
    # Summary writer
    writer = tf.summary.FileWriter("summary_logs", sess.graph)

    # Initialize reporting variables
    cost = 0
    diff = 1

    for i in range(numEpochs): 
        if i > 1 and diff < .0001:
            print("change in cost %g; convergence."%diff)
            break
        else:
            # Run training step
            step = sess.run(training_OP, feed_dict={X: trainX, yGold: trainY})
            
            # Report occasional stats
            if i % 10 == 0:
                # Add epoch to epoch_values
                epoch_values.append(i)
                # Generate accuracy stats on test data
                summary_results, train_accuracy, newCost = sess.run(
                    [all_summary_OPS, accuracy_OP, cost_OP],
                    feed_dict={X: trainX, yGold: trainY}
                )
                # Add accuracy to live graphing variable
                accuracy_values.append(train_accuracy)
                # Add cost to live graphing variable
                cost_values.append(newCost)
                # Write summary stats to writer
                writer.add_summary(summary_results, i)
                # Re-assign values for variables
                diff = abs(newCost - cost)
                cost = newCost

                #generate print statements
                print("step %d, training accuracy %g"%(i, train_accuracy))
                print("step %d, cost %g"%(i, newCost))
                print("step %d, change in cost %g"%(i, diff))

                # Plot progress to our two subplots
                accuracyLine, = ax1.plot(epoch_values, accuracy_values)
                costLine, = ax2.plot(epoch_values, cost_values)
                fig.canvas.draw()
                time.sleep(1)
    
    # Create Saver
    saver = tf.train.Saver()   
    saver.save(sess, '/tmp/dessert-model')

    # How well do we perform on held-out test data?
    print("final accuracy on test set: %s" %str(sess.run(accuracy_OP,
                                                         feed_dict={X: testX,
                                                                    yGold: testY})))
# Out:
# step 0, training accuracy 0.535905
# step 0, cost 6047.61
# step 0, change in cost 6047.61
# step 10, training accuracy 0.582187
# step 10, cost 5355.72
# step 10, change in cost 691.894
# step 20, training accuracy 0.623459
# step 20, cost 4449.1
# step 20, change in cost 906.624
# step 30, training accuracy 0.704095
# step 30, cost 3838.26
# step 30, change in cost 610.837
# step 40, training accuracy 0.800398
# step 40, cost 2978.4
# step 40, change in cost 859.857
# step 50, training accuracy 0.849543
# step 50, cost 2335.15
# step 50, change in cost 643.255
# step 60, training accuracy 0.871173
# step 60, cost 2017.14
# step 60, change in cost 318.002
# step 70, training accuracy 0.886839
# step 70, cost 1775.63
# step 70, change in cost 241.518
# step 80, training accuracy 0.89829
# step 80, cost 1606.91
# step 80, change in cost 168.72
# step 90, training accuracy 0.907197
# step 90, cost 1472.72
# step 90, change in cost 134.182
# step 100, training accuracy 0.913718
# step 100, cost 1364.02
# step 100, change in cost 108.704
# step 110, training accuracy 0.92
# step 110, cost 1267.17
# step 110, change in cost 96.8547
# step 120, training accuracy 0.92493
# step 120, cost 1185.81
# step 120, change in cost 81.3518
# step 130, training accuracy 0.928111
# step 130, cost 1123.23
# step 130, change in cost 62.579
# step 140, training accuracy 0.931372
# step 140, cost 1072.6
# step 140, change in cost 50.634
# step 150, training accuracy 0.933996
# step 150, cost 1029.05
# step 150, change in cost 43.5471
# step 160, training accuracy 0.935825
# step 160, cost 989.836
# step 160, change in cost 39.2173
# step 170, training accuracy 0.937813
# step 170, cost 952.146
# step 170, change in cost 37.69
# step 180, training accuracy 0.939245
# step 180, cost 919.739
# step 180, change in cost 32.4071
# step 190, training accuracy 0.940755
# step 190, cost 892.492
# step 190, change in cost 27.2465
# step 200, training accuracy 0.942585
# step 200, cost 868.859
# step 200, change in cost 23.6331
# step 210, training accuracy 0.94338
# step 210, cost 847.176
# step 210, change in cost 21.6837
# step 220, training accuracy 0.944732
# step 220, cost 827.642
# step 220, change in cost 19.5333
# step 230, training accuracy 0.945447
# step 230, cost 809.28
# step 230, change in cost 18.3622
# step 240, training accuracy 0.946402
# step 240, cost 791.529
# step 240, change in cost 17.7509
# step 250, training accuracy 0.947356
# step 250, cost 774.75
# step 250, change in cost 16.7791
# step 260, training accuracy 0.948946
# step 260, cost 759.148
# step 260, change in cost 15.6021
# step 270, training accuracy 0.949821
# step 270, cost 744.812
# step 270, change in cost 14.3359
# step 280, training accuracy 0.950696
# step 280, cost 731.347
# step 280, change in cost 13.465
# step 290, training accuracy 0.951252
# step 290, cost 718.553
# step 290, change in cost 12.7938
# step 300, training accuracy 0.951491
# step 300, cost 706.62
# step 300, change in cost 11.9332
# step 310, training accuracy 0.952048
# step 310, cost 695.676
# step 310, change in cost 10.9444
# step 320, training accuracy 0.952366
# step 320, cost 685.78
# step 320, change in cost 9.89539
# step 330, training accuracy 0.952922
# step 330, cost 676.77
# step 330, change in cost 9.01007
# step 340, training accuracy 0.953479
# step 340, cost 668.487
# step 340, change in cost 8.2832
# step 350, training accuracy 0.953559
# step 350, cost 660.728
# step 350, change in cost 7.75946
# step 360, training accuracy 0.953956
# step 360, cost 653.345
# step 360, change in cost 7.38312
# step 370, training accuracy 0.954115
# step 370, cost 646.543
# step 370, change in cost 6.80194
# step 380, training accuracy 0.954592
# step 380, cost 640.083
# step 380, change in cost 6.4599
# step 390, training accuracy 0.954911
# step 390, cost 633.791
# step 390, change in cost 6.29156
# step 400, training accuracy 0.955149
# step 400, cost 627.669
# step 400, change in cost 6.1217
# step 410, training accuracy 0.955229
# step 410, cost 621.748
# step 410, change in cost 5.92169
# step 420, training accuracy 0.955785
# step 420, cost 615.957
# step 420, change in cost 5.79108
# step 430, training accuracy 0.956183
# step 430, cost 610.273
# step 430, change in cost 5.6839
# step 440, training accuracy 0.956342
# step 440, cost 604.655
# step 440, change in cost 5.6181
# step 450, training accuracy 0.95666
# step 450, cost 599.138
# step 450, change in cost 5.51697
# step 460, training accuracy 0.956899
# step 460, cost 593.77
# step 460, change in cost 5.36774
# step 470, training accuracy 0.956978
# step 470, cost 588.567
# step 470, change in cost 5.20251
# step 480, training accuracy 0.957058
# step 480, cost 583.54
# step 480, change in cost 5.02765
# step 490, training accuracy 0.957296
# step 490, cost 578.691
# step 490, change in cost 4.84851
# step 500, training accuracy 0.957694
# step 500, cost 574.019
# step 500, change in cost 4.67273
# step 510, training accuracy 0.958251
# step 510, cost 569.508
# step 510, change in cost 4.51074
# step 520, training accuracy 0.958489
# step 520, cost 565.137
# step 520, change in cost 4.37036
# step 530, training accuracy 0.958807
# step 530, cost 560.879
# step 530, change in cost 4.25842
# step 540, training accuracy 0.959125
# step 540, cost 556.703
# step 540, change in cost 4.17615
# step 550, training accuracy 0.959284
# step 550, cost 552.59
# step 550, change in cost 4.11328
# step 560, training accuracy 0.959443
# step 560, cost 548.546
# step 560, change in cost 4.04407
# step 570, training accuracy 0.959602
# step 570, cost 544.599
# step 570, change in cost 3.94647
# step 580, training accuracy 0.95992
# step 580, cost 540.777
# step 580, change in cost 3.82227
# step 590, training accuracy 0.960239
# step 590, cost 537.086
# step 590, change in cost 3.69086
# step 600, training accuracy 0.960398
# step 600, cost 533.519
# step 600, change in cost 3.56702
# step 610, training accuracy 0.960557
# step 610, cost 530.062
# step 610, change in cost 3.45703
# step 620, training accuracy 0.960716
# step 620, cost 526.701
# step 620, change in cost 3.3606
# step 630, training accuracy 0.960795
# step 630, cost 523.432
# step 630, change in cost 3.26917
# step 640, training accuracy 0.960954
# step 640, cost 520.261
# step 640, change in cost 3.17157
# step 650, training accuracy 0.961113
# step 650, cost 517.195
# step 650, change in cost 3.06512
# step 660, training accuracy 0.961272
# step 660, cost 514.238
# step 660, change in cost 2.95697
# step 670, training accuracy 0.961431
# step 670, cost 511.384
# step 670, change in cost 2.85437
# step 680, training accuracy 0.961511
# step 680, cost 508.623
# step 680, change in cost 2.76141
# step 690, training accuracy 0.961829
# step 690, cost 505.947
# step 690, change in cost 2.67557
# step 700, training accuracy 0.961988
# step 700, cost 503.35
# step 700, change in cost 2.59735
# step 710, training accuracy 0.962227
# step 710, cost 500.817
# step 710, change in cost 2.5329
# step 720, training accuracy 0.962465
# step 720, cost 498.332
# step 720, change in cost 2.48465
# step 730, training accuracy 0.962545
# step 730, cost 495.881
# step 730, change in cost 2.4516
# step 740, training accuracy 0.962624
# step 740, cost 493.45
# step 740, change in cost 2.43109
# step 750, training accuracy 0.962783
# step 750, cost 491.028
# step 750, change in cost 2.42126
# step 760, training accuracy 0.962863
# step 760, cost 488.609
# step 760, change in cost 2.41925
# step 770, training accuracy 0.96326
# step 770, cost 486.186
# step 770, change in cost 2.4231
# step 780, training accuracy 0.963499
# step 780, cost 483.755
# step 780, change in cost 2.431
# step 790, training accuracy 0.963579
# step 790, cost 481.312
# step 790, change in cost 2.4425
# step 800, training accuracy 0.963817
# step 800, cost 478.856
# step 800, change in cost 2.45636
# step 810, training accuracy 0.963976
# step 810, cost 476.387
# step 810, change in cost 2.46924
# step 820, training accuracy 0.964135
# step 820, cost 473.914
# step 820, change in cost 2.47287
# step 830, training accuracy 0.964294
# step 830, cost 471.459
# step 830, change in cost 2.45532
# step 840, training accuracy 0.964294
# step 840, cost 469.045
# step 840, change in cost 2.41379
# step 850, training accuracy 0.964294
# step 850, cost 466.69
# step 850, change in cost 2.35471
# step 860, training accuracy 0.964374
# step 860, cost 464.4
# step 860, change in cost 2.29019
# step 870, training accuracy 0.964533
# step 870, cost 462.171
# step 870, change in cost 2.22855
# step 880, training accuracy 0.964533
# step 880, cost 459.997
# step 880, change in cost 2.17471
# step 890, training accuracy 0.964533
# step 890, cost 457.867
# step 890, change in cost 2.12979
# step 900, training accuracy 0.964612
# step 900, cost 455.776
# step 900, change in cost 2.09113
# step 910, training accuracy 0.964612
# step 910, cost 453.719
# step 910, change in cost 2.05682
# step 920, training accuracy 0.964771
# step 920, cost 451.694
# step 920, change in cost 2.0246
# step 930, training accuracy 0.964771
# step 930, cost 449.698
# step 930, change in cost 1.99628
# step 940, training accuracy 0.964851
# step 940, cost 447.723
# step 940, change in cost 1.97549
# step 950, training accuracy 0.964851
# step 950, cost 445.749
# step 950, change in cost 1.97324
# step 960, training accuracy 0.964771
# step 960, cost 443.756
# step 960, change in cost 1.99326
# step 970, training accuracy 0.964851
# step 970, cost 441.807
# step 970, change in cost 1.94864
# step 980, training accuracy 0.96493
# step 980, cost 439.934
# step 980, change in cost 1.87347
# step 990, training accuracy 0.965169
# step 990, cost 438.113
# step 990, change in cost 1.82053
# step 1000, training accuracy 0.965328
# step 1000, cost 436.331
# step 1000, change in cost 1.78268
# step 1010, training accuracy 0.965249
# step 1010, cost 434.574
# step 1010, change in cost 1.75629
# step 1020, training accuracy 0.965408
# step 1020, cost 432.837
# step 1020, change in cost 1.7373
# step 1030, training accuracy 0.965567
# step 1030, cost 431.112
# step 1030, change in cost 1.72485
# step 1040, training accuracy 0.965805
# step 1040, cost 429.395
# step 1040, change in cost 1.71735
# step 1050, training accuracy 0.965964
# step 1050, cost 427.681
# step 1050, change in cost 1.71411
# step 1060, training accuracy 0.966044
# step 1060, cost 425.969
# step 1060, change in cost 1.71194
# step 1070, training accuracy 0.966123
# step 1070, cost 424.263
# step 1070, change in cost 1.7059
# step 1080, training accuracy 0.966123
# step 1080, cost 422.573
# step 1080, change in cost 1.6897
# step 1090, training accuracy 0.966203
# step 1090, cost 420.914
# step 1090, change in cost 1.65894
# step 1100, training accuracy 0.966521
# step 1100, cost 419.3
# step 1100, change in cost 1.61456
# step 1110, training accuracy 0.966521
# step 1110, cost 417.732
# step 1110, change in cost 1.56763
# step 1120, training accuracy 0.96668
# step 1120, cost 416.203
# step 1120, change in cost 1.52893
# step 1130, training accuracy 0.966839
# step 1130, cost 414.704
# step 1130, change in cost 1.49875
# step 1140, training accuracy 0.966918
# step 1140, cost 413.23
# step 1140, change in cost 1.47455
# step 1150, training accuracy 0.966998
# step 1150, cost 411.776
# step 1150, change in cost 1.45425
# step 1160, training accuracy 0.967157
# step 1160, cost 410.339
# step 1160, change in cost 1.43719
# step 1170, training accuracy 0.967157
# step 1170, cost 408.916
# step 1170, change in cost 1.42218
# step 1180, training accuracy 0.967237
# step 1180, cost 407.507
# step 1180, change in cost 1.40982
# step 1190, training accuracy 0.967316
# step 1190, cost 406.108
# step 1190, change in cost 1.39883
# step 1200, training accuracy 0.967316
# step 1200, cost 404.72
# step 1200, change in cost 1.3877
# step 1210, training accuracy 0.967316
# step 1210, cost 403.346
# step 1210, change in cost 1.37357
# step 1220, training accuracy 0.967316
# step 1220, cost 401.992
# step 1220, change in cost 1.35428
# step 1230, training accuracy 0.967396
# step 1230, cost 400.661
# step 1230, change in cost 1.33121
# step 1240, training accuracy 0.967396
# step 1240, cost 399.355
# step 1240, change in cost 1.30569
# step 1250, training accuracy 0.967475
# step 1250, cost 398.075
# step 1250, change in cost 1.28058
# step 1260, training accuracy 0.967475
# step 1260, cost 396.817
# step 1260, change in cost 1.25763
# step 1270, training accuracy 0.967555
# step 1270, cost 395.58
# step 1270, change in cost 1.23694
# step 1280, training accuracy 0.967555
# step 1280, cost 394.361
# step 1280, change in cost 1.21924
# step 1290, training accuracy 0.967714
# step 1290, cost 393.156
# step 1290, change in cost 1.20496
# step 1300, training accuracy 0.967714
# step 1300, cost 391.962
# step 1300, change in cost 1.19397
# step 1310, training accuracy 0.967714
# step 1310, cost 390.776
# step 1310, change in cost 1.18625
# step 1320, training accuracy 0.967714
# step 1320, cost 389.594
# step 1320, change in cost 1.18198
# step 1330, training accuracy 0.967793
# step 1330, cost 388.413
# step 1330, change in cost 1.18036
# step 1340, training accuracy 0.967793
# step 1340, cost 387.232
# step 1340, change in cost 1.18103
# step 1350, training accuracy 0.967793
# step 1350, cost 386.049
# step 1350, change in cost 1.18311
# step 1360, training accuracy 0.967873
# step 1360, cost 384.864
# step 1360, change in cost 1.1853
# step 1370, training accuracy 0.968032
# step 1370, cost 383.677
# step 1370, change in cost 1.18671
# step 1380, training accuracy 0.96827
# step 1380, cost 382.491
# step 1380, change in cost 1.18646
# step 1390, training accuracy 0.96827
# step 1390, cost 381.307
# step 1390, change in cost 1.18372
# step 1400, training accuracy 0.96835
# step 1400, cost 380.128
# step 1400, change in cost 1.17896
# step 1410, training accuracy 0.96835
# step 1410, cost 378.955
# step 1410, change in cost 1.17307
# step 1420, training accuracy 0.96835
# step 1420, cost 377.788
# step 1420, change in cost 1.1666
# step 1430, training accuracy 0.968588
# step 1430, cost 376.629
# step 1430, change in cost 1.15976
# step 1440, training accuracy 0.968588
# step 1440, cost 375.476
# step 1440, change in cost 1.15286
# step 1450, training accuracy 0.968668
# step 1450, cost 374.331
# step 1450, change in cost 1.1449
# step 1460, training accuracy 0.968668
# step 1460, cost 373.195
# step 1460, change in cost 1.13605
# step 1470, training accuracy 0.968668
# step 1470, cost 372.068
# step 1470, change in cost 1.12695
# step 1480, training accuracy 0.968588
# step 1480, cost 370.951
# step 1480, change in cost 1.11737
# step 1490, training accuracy 0.968668
# step 1490, cost 369.841
# step 1490, change in cost 1.10925
# step 1500, training accuracy 0.968668
# step 1500, cost 368.739
# step 1500, change in cost 1.10229
# step 1510, training accuracy 0.968747
# step 1510, cost 367.644
# step 1510, change in cost 1.09515
# step 1520, training accuracy 0.968747
# step 1520, cost 366.558
# step 1520, change in cost 1.08533
# step 1530, training accuracy 0.968747
# step 1530, cost 365.488
# step 1530, change in cost 1.07043
# step 1540, training accuracy 0.968827
# step 1540, cost 364.438
# step 1540, change in cost 1.05026
# step 1550, training accuracy 0.968827
# step 1550, cost 363.41
# step 1550, change in cost 1.02823
# step 1560, training accuracy 0.968907
# step 1560, cost 362.404
# step 1560, change in cost 1.00525
# step 1570, training accuracy 0.969066
# step 1570, cost 361.421
# step 1570, change in cost 0.983276
# step 1580, training accuracy 0.969066
# step 1580, cost 360.459
# step 1580, change in cost 0.961853
# step 1590, training accuracy 0.969066
# step 1590, cost 359.519
# step 1590, change in cost 0.939972
# step 1600, training accuracy 0.969384
# step 1600, cost 358.602
# step 1600, change in cost 0.917694
# step 1610, training accuracy 0.969384
# step 1610, cost 357.707
# step 1610, change in cost 0.894836
# step 1620, training accuracy 0.969463
# step 1620, cost 356.834
# step 1620, change in cost 0.872864
# step 1630, training accuracy 0.969543
# step 1630, cost 355.982
# step 1630, change in cost 0.851929
# step 1640, training accuracy 0.969781
# step 1640, cost 355.149
# step 1640, change in cost 0.832642
# step 1650, training accuracy 0.969861
# step 1650, cost 354.334
# step 1650, change in cost 0.815643
# step 1660, training accuracy 0.970099
# step 1660, cost 353.533
# step 1660, change in cost 0.800995
# step 1670, training accuracy 0.970099
# step 1670, cost 352.744
# step 1670, change in cost 0.78891
# step 1680, training accuracy 0.970179
# step 1680, cost 351.965
# step 1680, change in cost 0.779083
# step 1690, training accuracy 0.970258
# step 1690, cost 351.193
# step 1690, change in cost 0.771423
# step 1700, training accuracy 0.970258
# step 1700, cost 350.427
# step 1700, change in cost 0.766052
# step 1710, training accuracy 0.970258
# step 1710, cost 349.665
# step 1710, change in cost 0.761932
# step 1720, training accuracy 0.970258
# step 1720, cost 348.905
# step 1720, change in cost 0.759857
# step 1730, training accuracy 0.970338
# step 1730, cost 348.147
# step 1730, change in cost 0.758728
# step 1740, training accuracy 0.970417
# step 1740, cost 347.388
# step 1740, change in cost 0.75885
# step 1750, training accuracy 0.970417
# step 1750, cost 346.628
# step 1750, change in cost 0.760162
# step 1760, training accuracy 0.970417
# step 1760, cost 345.865
# step 1760, change in cost 0.76236
# step 1770, training accuracy 0.970497
# step 1770, cost 345.099
# step 1770, change in cost 0.765808
# step 1780, training accuracy 0.970577
# step 1780, cost 344.329
# step 1780, change in cost 0.770844
# step 1790, training accuracy 0.970895
# step 1790, cost 343.551
# step 1790, change in cost 0.77774
# step 1800, training accuracy 0.970895
# step 1800, cost 342.764
# step 1800, change in cost 0.787109
# step 1810, training accuracy 0.970895
# step 1810, cost 341.965
# step 1810, change in cost 0.799072
# step 1820, training accuracy 0.970974
# step 1820, cost 341.151
# step 1820, change in cost 0.813538
# step 1830, training accuracy 0.971054
# step 1830, cost 340.321
# step 1830, change in cost 0.829773
# step 1840, training accuracy 0.971054
# step 1840, cost 339.475
# step 1840, change in cost 0.846069
# step 1850, training accuracy 0.971054
# step 1850, cost 338.615
# step 1850, change in cost 0.860413
# step 1860, training accuracy 0.971054
# step 1860, cost 337.745
# step 1860, change in cost 0.870026
# step 1870, training accuracy 0.971133
# step 1870, cost 336.87
# step 1870, change in cost 0.874908
# step 1880, training accuracy 0.971133
# step 1880, cost 335.994
# step 1880, change in cost 0.876282
# step 1890, training accuracy 0.971054
# step 1890, cost 335.119
# step 1890, change in cost 0.875061
# step 1900, training accuracy 0.971213
# step 1900, cost 334.244
# step 1900, change in cost 0.874176
# step 1910, training accuracy 0.971292
# step 1910, cost 333.371
# step 1910, change in cost 0.873871
# step 1920, training accuracy 0.971372
# step 1920, cost 332.496
# step 1920, change in cost 0.874725
# step 1930, training accuracy 0.97161
# step 1930, cost 331.619
# step 1930, change in cost 0.876373
# step 1940, training accuracy 0.97169
# step 1940, cost 330.741
# step 1940, change in cost 0.878387
# step 1950, training accuracy 0.971849
# step 1950, cost 329.861
# step 1950, change in cost 0.879578
# step 1960, training accuracy 0.971769
# step 1960, cost 328.982
# step 1960, change in cost 0.879639
# step 1970, training accuracy 0.971769
# step 1970, cost 328.105
# step 1970, change in cost 0.876556
# step 1980, training accuracy 0.971849
# step 1980, cost 327.235
# step 1980, change in cost 0.870148
# step 1990, training accuracy 0.971928
# step 1990, cost 326.375
# step 1990, change in cost 0.860382
# step 2000, training accuracy 0.972008
# step 2000, cost 325.527
# step 2000, change in cost 0.848145
# step 2010, training accuracy 0.972088
# step 2010, cost 324.693
# step 2010, change in cost 0.833313
# step 2020, training accuracy 0.972167
# step 2020, cost 323.875
# step 2020, change in cost 0.817993
# step 2030, training accuracy 0.972247
# step 2030, cost 323.072
# step 2030, change in cost 0.802979
# step 2040, training accuracy 0.972326
# step 2040, cost 322.284
# step 2040, change in cost 0.788208
# step 2050, training accuracy 0.972326
# step 2050, cost 321.509
# step 2050, change in cost 0.775452
# step 2060, training accuracy 0.972326
# step 2060, cost 320.745
# step 2060, change in cost 0.764038
# step 2070, training accuracy 0.972485
# step 2070, cost 319.99
# step 2070, change in cost 0.754761
# step 2080, training accuracy 0.972485
# step 2080, cost 319.243
# step 2080, change in cost 0.747101
# step 2090, training accuracy 0.972485
# step 2090, cost 318.502
# step 2090, change in cost 0.74118
# step 2100, training accuracy 0.972485
# step 2100, cost 317.766
# step 2100, change in cost 0.735901
# step 2110, training accuracy 0.972565
# step 2110, cost 317.034
# step 2110, change in cost 0.731262
# step 2120, training accuracy 0.972724
# step 2120, cost 316.308
# step 2120, change in cost 0.726654
# step 2130, training accuracy 0.972803
# step 2130, cost 315.586
# step 2130, change in cost 0.721924
# step 2140, training accuracy 0.972803
# step 2140, cost 314.869
# step 2140, change in cost 0.716888
# step 2150, training accuracy 0.972803
# step 2150, cost 314.157
# step 2150, change in cost 0.711853
# step 2160, training accuracy 0.972803
# step 2160, cost 313.45
# step 2160, change in cost 0.70697
# step 2170, training accuracy 0.972803
# step 2170, cost 312.747
# step 2170, change in cost 0.702637
# step 2180, training accuracy 0.972962
# step 2180, cost 312.048
# step 2180, change in cost 0.699341
# step 2190, training accuracy 0.972883
# step 2190, cost 311.35
# step 2190, change in cost 0.697662
# step 2200, training accuracy 0.973042
# step 2200, cost 310.652
# step 2200, change in cost 0.698029
# step 2210, training accuracy 0.973042
# step 2210, cost 309.953
# step 2210, change in cost 0.699799
# step 2220, training accuracy 0.973121
# step 2220, cost 309.25
# step 2220, change in cost 0.702423
# step 2230, training accuracy 0.973201
# step 2230, cost 308.547
# step 2230, change in cost 0.703644
# step 2240, training accuracy 0.973201
# step 2240, cost 307.844
# step 2240, change in cost 0.702606
# step 2250, training accuracy 0.973201
# step 2250, cost 307.145
# step 2250, change in cost 0.698792
# step 2260, training accuracy 0.973201
# step 2260, cost 306.451
# step 2260, change in cost 0.694702
# step 2270, training accuracy 0.973201
# step 2270, cost 305.76
# step 2270, change in cost 0.690125
# step 2280, training accuracy 0.97328
# step 2280, cost 305.075
# step 2280, change in cost 0.685425
# step 2290, training accuracy 0.973439
# step 2290, cost 304.394
# step 2290, change in cost 0.680969
# step 2300, training accuracy 0.973519
# step 2300, cost 303.717
# step 2300, change in cost 0.676514
# step 2310, training accuracy 0.973678
# step 2310, cost 303.046
# step 2310, change in cost 0.671021
# step 2320, training accuracy 0.973757
# step 2320, cost 302.381
# step 2320, change in cost 0.665405
# step 2330, training accuracy 0.973917
# step 2330, cost 301.722
# step 2330, change in cost 0.65863
# step 2340, training accuracy 0.974155
# step 2340, cost 301.071
# step 2340, change in cost 0.651733
# step 2350, training accuracy 0.974314
# step 2350, cost 300.426
# step 2350, change in cost 0.644531
# step 2360, training accuracy 0.974235
# step 2360, cost 299.789
# step 2360, change in cost 0.636993
# step 2370, training accuracy 0.974314
# step 2370, cost 299.16
# step 2370, change in cost 0.629578
# step 2380, training accuracy 0.974314
# step 2380, cost 298.538
# step 2380, change in cost 0.621857
# step 2390, training accuracy 0.974314
# step 2390, cost 297.923
# step 2390, change in cost 0.61438
# step 2400, training accuracy 0.974394
# step 2400, cost 297.316
# step 2400, change in cost 0.606995
# step 2410, training accuracy 0.974394
# step 2410, cost 296.717
# step 2410, change in cost 0.599396
# step 2420, training accuracy 0.974394
# step 2420, cost 296.125
# step 2420, change in cost 0.592163
# step 2430, training accuracy 0.974394
# step 2430, cost 295.54
# step 2430, change in cost 0.585114
# step 2440, training accuracy 0.974473
# step 2440, cost 294.961
# step 2440, change in cost 0.578918
# step 2450, training accuracy 0.974473
# step 2450, cost 294.388
# step 2450, change in cost 0.57312
# step 2460, training accuracy 0.974473
# step 2460, cost 293.819
# step 2460, change in cost 0.568481
# step 2470, training accuracy 0.974473
# step 2470, cost 293.254
# step 2470, change in cost 0.564972
# step 2480, training accuracy 0.974394
# step 2480, cost 292.691
# step 2480, change in cost 0.562836
# step 2490, training accuracy 0.974473
# step 2490, cost 292.129
# step 2490, change in cost 0.562256
# step 2500, training accuracy 0.974553
# step 2500, cost 291.566
# step 2500, change in cost 0.563171
# step 2510, training accuracy 0.974553
# step 2510, cost 291
# step 2510, change in cost 0.565491
# step 2520, training accuracy 0.974553
# step 2520, cost 290.433
# step 2520, change in cost 0.567474
# step 2530, training accuracy 0.974712
# step 2530, cost 289.866
# step 2530, change in cost 0.567444
# step 2540, training accuracy 0.974871
# step 2540, cost 289.302
# step 2540, change in cost 0.563812
# step 2550, training accuracy 0.97495
# step 2550, cost 288.745
# step 2550, change in cost 0.556793
# step 2560, training accuracy 0.97495
# step 2560, cost 288.197
# step 2560, change in cost 0.547852
# step 2570, training accuracy 0.974871
# step 2570, cost 287.658
# step 2570, change in cost 0.539093
# step 2580, training accuracy 0.974871
# step 2580, cost 287.127
# step 2580, change in cost 0.531128
# step 2590, training accuracy 0.974871
# step 2590, cost 286.603
# step 2590, change in cost 0.524323
# step 2600, training accuracy 0.97495
# step 2600, cost 286.084
# step 2600, change in cost 0.518433
# step 2610, training accuracy 0.97503
# step 2610, cost 285.57
# step 2610, change in cost 0.513794
# step 2620, training accuracy 0.975109
# step 2620, cost 285.061
# step 2620, change in cost 0.509369
# step 2630, training accuracy 0.975109
# step 2630, cost 284.555
# step 2630, change in cost 0.505432
# step 2640, training accuracy 0.975268
# step 2640, cost 284.054
# step 2640, change in cost 0.501862
# step 2650, training accuracy 0.975268
# step 2650, cost 283.555
# step 2650, change in cost 0.498596
# step 2660, training accuracy 0.975427
# step 2660, cost 283.059
# step 2660, change in cost 0.495544
# step 2670, training accuracy 0.975427
# step 2670, cost 282.567
# step 2670, change in cost 0.492584
# step 2680, training accuracy 0.975507
# step 2680, cost 282.077
# step 2680, change in cost 0.489929
# step 2690, training accuracy 0.975507
# step 2690, cost 281.59
# step 2690, change in cost 0.487335
# step 2700, training accuracy 0.975507
# step 2700, cost 281.105
# step 2700, change in cost 0.484894
# step 2710, training accuracy 0.975586
# step 2710, cost 280.622
# step 2710, change in cost 0.482666
# step 2720, training accuracy 0.975666
# step 2720, cost 280.142
# step 2720, change in cost 0.480438
# step 2730, training accuracy 0.975666
# step 2730, cost 279.663
# step 2730, change in cost 0.478333
# step 2740, training accuracy 0.975745
# step 2740, cost 279.187
# step 2740, change in cost 0.476379
# step 2750, training accuracy 0.975745
# step 2750, cost 278.713
# step 2750, change in cost 0.474243
# step 2760, training accuracy 0.975745
# step 2760, cost 278.24
# step 2760, change in cost 0.472687
# step 2770, training accuracy 0.975745
# step 2770, cost 277.769
# step 2770, change in cost 0.471191
# step 2780, training accuracy 0.975825
# step 2780, cost 277.299
# step 2780, change in cost 0.469849
# step 2790, training accuracy 0.975905
# step 2790, cost 276.83
# step 2790, change in cost 0.468689
# step 2800, training accuracy 0.975905
# step 2800, cost 276.362
# step 2800, change in cost 0.467896
# step 2810, training accuracy 0.975984
# step 2810, cost 275.895
# step 2810, change in cost 0.467255
# step 2820, training accuracy 0.976064
# step 2820, cost 275.428
# step 2820, change in cost 0.466705
# step 2830, training accuracy 0.976143
# step 2830, cost 274.962
# step 2830, change in cost 0.466248
# step 2840, training accuracy 0.976223
# step 2840, cost 274.496
# step 2840, change in cost 0.465759
# step 2850, training accuracy 0.976382
# step 2850, cost 274.031
# step 2850, change in cost 0.464966
# step 2860, training accuracy 0.976382
# step 2860, cost 273.567
# step 2860, change in cost 0.464172
# step 2870, training accuracy 0.976382
# step 2870, cost 273.104
# step 2870, change in cost 0.462952
# step 2880, training accuracy 0.976382
# step 2880, cost 272.643
# step 2880, change in cost 0.461639
# step 2890, training accuracy 0.976382
# step 2890, cost 272.183
# step 2890, change in cost 0.460114
# step 2900, training accuracy 0.976382
# step 2900, cost 271.724
# step 2900, change in cost 0.458374
# step 2910, training accuracy 0.976382
# step 2910, cost 271.268
# step 2910, change in cost 0.45636
# step 2920, training accuracy 0.976382
# step 2920, cost 270.813
# step 2920, change in cost 0.454468
# step 2930, training accuracy 0.976382
# step 2930, cost 270.361
# step 2930, change in cost 0.452637
# step 2940, training accuracy 0.976461
# step 2940, cost 269.91
# step 2940, change in cost 0.450928
# step 2950, training accuracy 0.976461
# step 2950, cost 269.461
# step 2950, change in cost 0.449219
# step 2960, training accuracy 0.976461
# step 2960, cost 269.013
# step 2960, change in cost 0.447815
# step 2970, training accuracy 0.976461
# step 2970, cost 268.566
# step 2970, change in cost 0.446655
# step 2980, training accuracy 0.976461
# step 2980, cost 268.121
# step 2980, change in cost 0.445557
# step 2990, training accuracy 0.976461
# step 2990, cost 267.676
# step 2990, change in cost 0.444702
# step 3000, training accuracy 0.976541
# step 3000, cost 267.232
# step 3000, change in cost 0.44397
# step 3010, training accuracy 0.976541
# step 3010, cost 266.788
# step 3010, change in cost 0.44342
# step 3020, training accuracy 0.97662
# step 3020, cost 266.346
# step 3020, change in cost 0.44278
# step 3030, training accuracy 0.97662
# step 3030, cost 265.904
# step 3030, change in cost 0.442108
# step 3040, training accuracy 0.976779
# step 3040, cost 265.462
# step 3040, change in cost 0.441589
# step 3050, training accuracy 0.976859
# step 3050, cost 265.021
# step 3050, change in cost 0.441162
# step 3060, training accuracy 0.976859
# step 3060, cost 264.58
# step 3060, change in cost 0.440735
# step 3070, training accuracy 0.976859
# step 3070, cost 264.139
# step 3070, change in cost 0.440765
# step 3080, training accuracy 0.976859
# step 3080, cost 263.698
# step 3080, change in cost 0.441223
# step 3090, training accuracy 0.976859
# step 3090, cost 263.255
# step 3090, change in cost 0.442596
# step 3100, training accuracy 0.976859
# step 3100, cost 262.81
# step 3100, change in cost 0.445068
# step 3110, training accuracy 0.976938
# step 3110, cost 262.362
# step 3110, change in cost 0.448547
# step 3120, training accuracy 0.976938
# step 3120, cost 261.909
# step 3120, change in cost 0.453186
# step 3130, training accuracy 0.976938
# step 3130, cost 261.452
# step 3130, change in cost 0.456757
# step 3140, training accuracy 0.976938
# step 3140, cost 260.993
# step 3140, change in cost 0.458588
# step 3150, training accuracy 0.976938
# step 3150, cost 260.537
# step 3150, change in cost 0.456787
# step 3160, training accuracy 0.976938
# step 3160, cost 260.086
# step 3160, change in cost 0.450989
# step 3170, training accuracy 0.977018
# step 3170, cost 259.643
# step 3170, change in cost 0.442963
# step 3180, training accuracy 0.977018
# step 3180, cost 259.208
# step 3180, change in cost 0.434357
# step 3190, training accuracy 0.976938
# step 3190, cost 258.781
# step 3190, change in cost 0.427032
# step 3200, training accuracy 0.976938
# step 3200, cost 258.36
# step 3200, change in cost 0.421692
# step 3210, training accuracy 0.976938
# step 3210, cost 257.94
# step 3210, change in cost 0.419739
# step 3220, training accuracy 0.976938
# step 3220, cost 257.518
# step 3220, change in cost 0.421356
# step 3230, training accuracy 0.977018
# step 3230, cost 257.093
# step 3230, change in cost 0.42572
# step 3240, training accuracy 0.977177
# step 3240, cost 256.664
# step 3240, change in cost 0.428528
# step 3250, training accuracy 0.977177
# step 3250, cost 256.241
# step 3250, change in cost 0.423584
# step 3260, training accuracy 0.977177
# step 3260, cost 255.83
# step 3260, change in cost 0.410782
# step 3270, training accuracy 0.977177
# step 3270, cost 255.435
# step 3270, change in cost 0.394989
# step 3280, training accuracy 0.977177
# step 3280, cost 255.054
# step 3280, change in cost 0.381271
# step 3290, training accuracy 0.977177
# step 3290, cost 254.683
# step 3290, change in cost 0.370178
# step 3300, training accuracy 0.977336
# step 3300, cost 254.322
# step 3300, change in cost 0.361816
# step 3310, training accuracy 0.977416
# step 3310, cost 253.966
# step 3310, change in cost 0.355347
# step 3320, training accuracy 0.977416
# step 3320, cost 253.616
# step 3320, change in cost 0.35054
# step 3330, training accuracy 0.977416
# step 3330, cost 253.269
# step 3330, change in cost 0.346817
# step 3340, training accuracy 0.977416
# step 3340, cost 252.925
# step 3340, change in cost 0.343491
# step 3350, training accuracy 0.977416
# step 3350, cost 252.584
# step 3350, change in cost 0.34111
# step 3360, training accuracy 0.977416
# step 3360, cost 252.245
# step 3360, change in cost 0.338989
# step 3370, training accuracy 0.977495
# step 3370, cost 251.908
# step 3370, change in cost 0.337234
# step 3380, training accuracy 0.977495
# step 3380, cost 251.572
# step 3380, change in cost 0.335831
# step 3390, training accuracy 0.977575
# step 3390, cost 251.238
# step 3390, change in cost 0.334473
# step 3400, training accuracy 0.977575
# step 3400, cost 250.904
# step 3400, change in cost 0.333298
# step 3410, training accuracy 0.977575
# step 3410, cost 250.572
# step 3410, change in cost 0.332291
# step 3420, training accuracy 0.977575
# step 3420, cost 250.241
# step 3420, change in cost 0.331299
# step 3430, training accuracy 0.977575
# step 3430, cost 249.911
# step 3430, change in cost 0.330292
# step 3440, training accuracy 0.977575
# step 3440, cost 249.581
# step 3440, change in cost 0.329315
# step 3450, training accuracy 0.977575
# step 3450, cost 249.253
# step 3450, change in cost 0.328308
# step 3460, training accuracy 0.977575
# step 3460, cost 248.926
# step 3460, change in cost 0.327393
# step 3470, training accuracy 0.977734
# step 3470, cost 248.599
# step 3470, change in cost 0.326187
# step 3480, training accuracy 0.977734
# step 3480, cost 248.274
# step 3480, change in cost 0.325104
# step 3490, training accuracy 0.977734
# step 3490, cost 247.95
# step 3490, change in cost 0.323837
# step 3500, training accuracy 0.977734
# step 3500, cost 247.628
# step 3500, change in cost 0.322693
# step 3510, training accuracy 0.977893
# step 3510, cost 247.306
# step 3510, change in cost 0.321594
# step 3520, training accuracy 0.977893
# step 3520, cost 246.986
# step 3520, change in cost 0.320465
# step 3530, training accuracy 0.977972
# step 3530, cost 246.666
# step 3530, change in cost 0.319489
# step 3540, training accuracy 0.977972
# step 3540, cost 246.347
# step 3540, change in cost 0.318756
# step 3550, training accuracy 0.978052
# step 3550, cost 246.029
# step 3550, change in cost 0.317963
# step 3560, training accuracy 0.978052
# step 3560, cost 245.712
# step 3560, change in cost 0.317657
# step 3570, training accuracy 0.978052
# step 3570, cost 245.394
# step 3570, change in cost 0.317795
# step 3580, training accuracy 0.978052
# step 3580, cost 245.076
# step 3580, change in cost 0.318161
# step 3590, training accuracy 0.978052
# step 3590, cost 244.757
# step 3590, change in cost 0.319046
# step 3600, training accuracy 0.978052
# step 3600, cost 244.436
# step 3600, change in cost 0.320328
# step 3610, training accuracy 0.978131
# step 3610, cost 244.114
# step 3610, change in cost 0.322205
# step 3620, training accuracy 0.978131
# step 3620, cost 243.79
# step 3620, change in cost 0.324402
# step 3630, training accuracy 0.978211
# step 3630, cost 243.463
# step 3630, change in cost 0.326874
# step 3640, training accuracy 0.978211
# step 3640, cost 243.134
# step 3640, change in cost 0.329269
# step 3650, training accuracy 0.978211
# step 3650, cost 242.802
# step 3650, change in cost 0.331238
# step 3660, training accuracy 0.978211
# step 3660, cost 242.47
# step 3660, change in cost 0.332596
# step 3670, training accuracy 0.978211
# step 3670, cost 242.137
# step 3670, change in cost 0.332916
# step 3680, training accuracy 0.978211
# step 3680, cost 241.805
# step 3680, change in cost 0.332199
# step 3690, training accuracy 0.978211
# step 3690, cost 241.474
# step 3690, change in cost 0.330627
# step 3700, training accuracy 0.97829
# step 3700, cost 241.146
# step 3700, change in cost 0.328323
# step 3710, training accuracy 0.97829
# step 3710, cost 240.82
# step 3710, change in cost 0.325714
# step 3720, training accuracy 0.97829
# step 3720, cost 240.497
# step 3720, change in cost 0.323242
# step 3730, training accuracy 0.97837
# step 3730, cost 240.176
# step 3730, change in cost 0.321045
# step 3740, training accuracy 0.978449
# step 3740, cost 239.856
# step 3740, change in cost 0.319748
# step 3750, training accuracy 0.978529
# step 3750, cost 239.537
# step 3750, change in cost 0.319366
# step 3760, training accuracy 0.978529
# step 3760, cost 239.216
# step 3760, change in cost 0.320465
# step 3770, training accuracy 0.978529
# step 3770, cost 238.893
# step 3770, change in cost 0.322983
# step 3780, training accuracy 0.978608
# step 3780, cost 238.566
# step 3780, change in cost 0.327209
# step 3790, training accuracy 0.978608
# step 3790, cost 238.234
# step 3790, change in cost 0.331802
# step 3800, training accuracy 0.978608
# step 3800, cost 237.899
# step 3800, change in cost 0.335266
# step 3810, training accuracy 0.978608
# step 3810, cost 237.564
# step 3810, change in cost 0.334854
# step 3820, training accuracy 0.978688
# step 3820, cost 237.234
# step 3820, change in cost 0.329697
# step 3830, training accuracy 0.978688
# step 3830, cost 236.912
# step 3830, change in cost 0.321976
# step 3840, training accuracy 0.978688
# step 3840, cost 236.599
# step 3840, change in cost 0.313248
# step 3850, training accuracy 0.978688
# step 3850, cost 236.294
# step 3850, change in cost 0.30513
# step 3860, training accuracy 0.978688
# step 3860, cost 235.996
# step 3860, change in cost 0.298386
# step 3870, training accuracy 0.978688
# step 3870, cost 235.703
# step 3870, change in cost 0.292984
# step 3880, training accuracy 0.978688
# step 3880, cost 235.414
# step 3880, change in cost 0.288788
# step 3890, training accuracy 0.978688
# step 3890, cost 235.128
# step 3890, change in cost 0.285645
# step 3900, training accuracy 0.978688
# step 3900, cost 234.844
# step 3900, change in cost 0.283783
# step 3910, training accuracy 0.978688
# step 3910, cost 234.562
# step 3910, change in cost 0.282562
# step 3920, training accuracy 0.978767
# step 3920, cost 234.28
# step 3920, change in cost 0.282043
# step 3930, training accuracy 0.978767
# step 3930, cost 233.998
# step 3930, change in cost 0.281891
# step 3940, training accuracy 0.978847
# step 3940, cost 233.716
# step 3940, change in cost 0.281509
# step 3950, training accuracy 0.979006
# step 3950, cost 233.435
# step 3950, change in cost 0.281265
# step 3960, training accuracy 0.979086
# step 3960, cost 233.155
# step 3960, change in cost 0.280563
# step 3970, training accuracy 0.979086
# step 3970, cost 232.875
# step 3970, change in cost 0.279465
# step 3980, training accuracy 0.979086
# step 3980, cost 232.597
# step 3980, change in cost 0.277985
# step 3990, training accuracy 0.979086
# step 3990, cost 232.321
# step 3990, change in cost 0.276184
# step 4000, training accuracy 0.979165
# step 4000, cost 232.047
# step 4000, change in cost 0.27449
# step 4010, training accuracy 0.979165
# step 4010, cost 231.774
# step 4010, change in cost 0.272858
# step 4020, training accuracy 0.979165
# step 4020, cost 231.502
# step 4020, change in cost 0.271622
# step 4030, training accuracy 0.979245
# step 4030, cost 231.232
# step 4030, change in cost 0.270386
# step 4040, training accuracy 0.979245
# step 4040, cost 230.962
# step 4040, change in cost 0.269501
# step 4050, training accuracy 0.979245
# step 4050, cost 230.694
# step 4050, change in cost 0.268188
# step 4060, training accuracy 0.979324
# step 4060, cost 230.427
# step 4060, change in cost 0.26651
# step 4070, training accuracy 0.979404
# step 4070, cost 230.163
# step 4070, change in cost 0.264008
# step 4080, training accuracy 0.979404
# step 4080, cost 229.903
# step 4080, change in cost 0.260681
# step 4090, training accuracy 0.979483
# step 4090, cost 229.646
# step 4090, change in cost 0.256561
# step 4100, training accuracy 0.979563
# step 4100, cost 229.394
# step 4100, change in cost 0.252396
# step 4110, training accuracy 0.979642
# step 4110, cost 229.146
# step 4110, change in cost 0.248032
# step 4120, training accuracy 0.979642
# step 4120, cost 228.902
# step 4120, change in cost 0.243805
# step 4130, training accuracy 0.979642
# step 4130, cost 228.662
# step 4130, change in cost 0.240051
# step 4140, training accuracy 0.979642
# step 4140, cost 228.425
# step 4140, change in cost 0.236557
# step 4150, training accuracy 0.979642
# step 4150, cost 228.192
# step 4150, change in cost 0.233261
# step 4160, training accuracy 0.979722
# step 4160, cost 227.962
# step 4160, change in cost 0.230103
# step 4170, training accuracy 0.979722
# step 4170, cost 227.735
# step 4170, change in cost 0.227386
# step 4180, training accuracy 0.979881
# step 4180, cost 227.51
# step 4180, change in cost 0.224808
# step 4190, training accuracy 0.979881
# step 4190, cost 227.288
# step 4190, change in cost 0.222244
# step 4200, training accuracy 0.97996
# step 4200, cost 227.068
# step 4200, change in cost 0.220032
# step 4210, training accuracy 0.97996
# step 4210, cost 226.85
# step 4210, change in cost 0.217712
# step 4220, training accuracy 0.97996
# step 4220, cost 226.634
# step 4220, change in cost 0.215958
# step 4230, training accuracy 0.98004
# step 4230, cost 226.42
# step 4230, change in cost 0.213974
# step 4240, training accuracy 0.97996
# step 4240, cost 226.208
# step 4240, change in cost 0.212341
# step 4250, training accuracy 0.97996
# step 4250, cost 225.997
# step 4250, change in cost 0.210953
# step 4260, training accuracy 0.97996
# step 4260, cost 225.787
# step 4260, change in cost 0.209671
# step 4270, training accuracy 0.97996
# step 4270, cost 225.578
# step 4270, change in cost 0.208557
# step 4280, training accuracy 0.980119
# step 4280, cost 225.371
# step 4280, change in cost 0.207703
# step 4290, training accuracy 0.980119
# step 4290, cost 225.164
# step 4290, change in cost 0.207123
# step 4300, training accuracy 0.980119
# step 4300, cost 224.957
# step 4300, change in cost 0.206573
# step 4310, training accuracy 0.980119
# step 4310, cost 224.751
# step 4310, change in cost 0.206329
# step 4320, training accuracy 0.980119
# step 4320, cost 224.544
# step 4320, change in cost 0.206375
# step 4330, training accuracy 0.980119
# step 4330, cost 224.338
# step 4330, change in cost 0.206528
# step 4340, training accuracy 0.980119
# step 4340, cost 224.131
# step 4340, change in cost 0.207001
# step 4350, training accuracy 0.980119
# step 4350, cost 223.923
# step 4350, change in cost 0.207642
# step 4360, training accuracy 0.980199
# step 4360, cost 223.714
# step 4360, change in cost 0.20871
# step 4370, training accuracy 0.980199
# step 4370, cost 223.505
# step 4370, change in cost 0.209869
# step 4380, training accuracy 0.980199
# step 4380, cost 223.293
# step 4380, change in cost 0.211426
# step 4390, training accuracy 0.980358
# step 4390, cost 223.08
# step 4390, change in cost 0.213394
# step 4400, training accuracy 0.980358
# step 4400, cost 222.864
# step 4400, change in cost 0.215439
# step 4410, training accuracy 0.980358
# step 4410, cost 222.646
# step 4410, change in cost 0.218063
# step 4420, training accuracy 0.980358
# step 4420, cost 222.425
# step 4420, change in cost 0.220703
# step 4430, training accuracy 0.980517
# step 4430, cost 222.202
# step 4430, change in cost 0.223877
# step 4440, training accuracy 0.980517
# step 4440, cost 221.974
# step 4440, change in cost 0.227219
# step 4450, training accuracy 0.980517
# step 4450, cost 221.744
# step 4450, change in cost 0.230759
# step 4460, training accuracy 0.980596
# step 4460, cost 221.509
# step 4460, change in cost 0.23439
# step 4470, training accuracy 0.980676
# step 4470, cost 221.271
# step 4470, change in cost 0.238129
# step 4480, training accuracy 0.980676
# step 4480, cost 221.029
# step 4480, change in cost 0.241974
# step 4490, training accuracy 0.980676
# step 4490, cost 220.783
# step 4490, change in cost 0.245972
# step 4500, training accuracy 0.980676
# step 4500, cost 220.533
# step 4500, change in cost 0.250061
# step 4510, training accuracy 0.980676
# step 4510, cost 220.279
# step 4510, change in cost 0.254501
# step 4520, training accuracy 0.980676
# step 4520, cost 220.019
# step 4520, change in cost 0.259247
# step 4530, training accuracy 0.980676
# step 4530, cost 219.756
# step 4530, change in cost 0.263687
# step 4540, training accuracy 0.980676
# step 4540, cost 219.488
# step 4540, change in cost 0.267929
# step 4550, training accuracy 0.980676
# step 4550, cost 219.217
# step 4550, change in cost 0.271011
# step 4560, training accuracy 0.980676
# step 4560, cost 218.944
# step 4560, change in cost 0.272339
# step 4570, training accuracy 0.980676
# step 4570, cost 218.673
# step 4570, change in cost 0.271866
# step 4580, training accuracy 0.980676
# step 4580, cost 218.403
# step 4580, change in cost 0.269516
# step 4590, training accuracy 0.980676
# step 4590, cost 218.137
# step 4590, change in cost 0.266098
# step 4600, training accuracy 0.980676
# step 4600, cost 217.875
# step 4600, change in cost 0.261795
# step 4610, training accuracy 0.980676
# step 4610, cost 217.618
# step 4610, change in cost 0.257141
# step 4620, training accuracy 0.980676
# step 4620, cost 217.365
# step 4620, change in cost 0.252502
# step 4630, training accuracy 0.980676
# step 4630, cost 217.118
# step 4630, change in cost 0.247772
# step 4640, training accuracy 0.980676
# step 4640, cost 216.874
# step 4640, change in cost 0.243515
# step 4650, training accuracy 0.980676
# step 4650, cost 216.635
# step 4650, change in cost 0.239212
# step 4660, training accuracy 0.980676
# step 4660, cost 216.4
# step 4660, change in cost 0.235443
# step 4670, training accuracy 0.980676
# step 4670, cost 216.168
# step 4670, change in cost 0.231842
# step 4680, training accuracy 0.980676
# step 4680, cost 215.939
# step 4680, change in cost 0.228699
# step 4690, training accuracy 0.980676
# step 4690, cost 215.713
# step 4690, change in cost 0.225784
# step 4700, training accuracy 0.980676
# step 4700, cost 215.49
# step 4700, change in cost 0.222961
# step 4710, training accuracy 0.980676
# step 4710, cost 215.27
# step 4710, change in cost 0.220627
# step 4720, training accuracy 0.980676
# step 4720, cost 215.051
# step 4720, change in cost 0.21814
# step 4730, training accuracy 0.980676
# step 4730, cost 214.835
# step 4730, change in cost 0.216248
# step 4740, training accuracy 0.980676
# step 4740, cost 214.621
# step 4740, change in cost 0.214233
# step 4750, training accuracy 0.980676
# step 4750, cost 214.409
# step 4750, change in cost 0.212387
# step 4760, training accuracy 0.980596
# step 4760, cost 214.198
# step 4760, change in cost 0.210632
# step 4770, training accuracy 0.980596
# step 4770, cost 213.989
# step 4770, change in cost 0.208923
# step 4780, training accuracy 0.980596
# step 4780, cost 213.782
# step 4780, change in cost 0.207275
# step 4790, training accuracy 0.980676
# step 4790, cost 213.576
# step 4790, change in cost 0.205917
# step 4800, training accuracy 0.980755
# step 4800, cost 213.372
# step 4800, change in cost 0.204315
# step 4810, training accuracy 0.980755
# step 4810, cost 213.169
# step 4810, change in cost 0.202972
# step 4820, training accuracy 0.980835
# step 4820, cost 212.967
# step 4820, change in cost 0.201675
# step 4830, training accuracy 0.980835
# step 4830, cost 212.767
# step 4830, change in cost 0.200333
# step 4840, training accuracy 0.980835
# step 4840, cost 212.567
# step 4840, change in cost 0.199219
# step 4850, training accuracy 0.980835
# step 4850, cost 212.369
# step 4850, change in cost 0.198151
# step 4860, training accuracy 0.980835
# step 4860, cost 212.172
# step 4860, change in cost 0.197189
# step 4870, training accuracy 0.980835
# step 4870, cost 211.976
# step 4870, change in cost 0.196274
# step 4880, training accuracy 0.980835
# step 4880, cost 211.78
# step 4880, change in cost 0.19548
# step 4890, training accuracy 0.980915
# step 4890, cost 211.585
# step 4890, change in cost 0.195023
# step 4900, training accuracy 0.980915
# step 4900, cost 211.391
# step 4900, change in cost 0.194305
# step 4910, training accuracy 0.980915
# step 4910, cost 211.197
# step 4910, change in cost 0.193909
# step 4920, training accuracy 0.980915
# step 4920, cost 211.003
# step 4920, change in cost 0.193649
# step 4930, training accuracy 0.981074
# step 4930, cost 210.81
# step 4930, change in cost 0.193558
# step 4940, training accuracy 0.981074
# step 4940, cost 210.616
# step 4940, change in cost 0.193481
# step 4950, training accuracy 0.981153
# step 4950, cost 210.423
# step 4950, change in cost 0.19342
# step 4960, training accuracy 0.981153
# step 4960, cost 210.229
# step 4960, change in cost 0.193893
# step 4970, training accuracy 0.981153
# step 4970, cost 210.035
# step 4970, change in cost 0.194
# step 4980, training accuracy 0.981153
# step 4980, cost 209.841
# step 4980, change in cost 0.194473
# step 4990, training accuracy 0.981153
# step 4990, cost 209.646
# step 4990, change in cost 0.194855
# step 5000, training accuracy 0.981153
# step 5000, cost 209.45
# step 5000, change in cost 0.195297
# step 5010, training accuracy 0.981233
# ...
# step 18410, change in cost 0.0259018
# step 18420, training accuracy 0.987913
# step 18420, cost 121.9
# step 18420, change in cost 0.0260086
# step 18430, training accuracy 0.987913
# step 18430, cost 121.874
# step 18430, change in cost 0.0261002
# step 18440, training accuracy 0.987913
# step 18440, cost 121.847
# step 18440, change in cost 0.026207
# step 18450, training accuracy 0.987913
# step 18450, cost 121.821
# step 18450, change in cost 0.0263596
# step 18460, training accuracy 0.987992
# step 18460, cost 121.795
# step 18460, change in cost 0.0265045
# step 18470, training accuracy 0.987992
# step 18470, cost 121.768
# step 18470, change in cost 0.0265884
# step 18480, training accuracy 0.987992
# step 18480, cost 121.741
# step 18480, change in cost 0.0267334
# step 18490, training accuracy 0.987992
# step 18490, cost 121.714
# step 18490, change in cost 0.026886
# step 18500, training accuracy 0.987992
# step 18500, cost 121.687
# step 18500, change in cost 0.0269928
# step 18510, training accuracy 0.987992
# step 18510, cost 121.66
# step 18510, change in cost 0.0271454
# step 18520, training accuracy 0.987992
# step 18520, cost 121.633
# step 18520, change in cost 0.0273438
# step 18530, training accuracy 0.987992
# step 18530, cost 121.605
# step 18530, change in cost 0.0274734
# step 18540, training accuracy 0.987992
# step 18540, cost 121.578
# step 18540, change in cost 0.0275955
# step 18550, training accuracy 0.987992
# step 18550, cost 121.55
# step 18550, change in cost 0.0278473
# step 18560, training accuracy 0.987992
# step 18560, cost 121.522
# step 18560, change in cost 0.0279999
# step 18570, training accuracy 0.987992
# step 18570, cost 121.494
# step 18570, change in cost 0.0282135
# step 18580, training accuracy 0.987992
# step 18580, cost 121.465
# step 18580, change in cost 0.0284271
# step 18590, training accuracy 0.987992
# step 18590, cost 121.437
# step 18590, change in cost 0.0286255
# step 18600, training accuracy 0.987992
# step 18600, cost 121.408
# step 18600, change in cost 0.0288849
# step 18610, training accuracy 0.987992
# step 18610, cost 121.379
# step 18610, change in cost 0.0290451
# step 18620, training accuracy 0.987992
# step 18620, cost 121.349
# step 18620, change in cost 0.0293961
# step 18630, training accuracy 0.987992
# step 18630, cost 121.32
# step 18630, change in cost 0.0296402
# step 18640, training accuracy 0.987992
# step 18640, cost 121.29
# step 18640, change in cost 0.0299225
# step 18650, training accuracy 0.987992
# step 18650, cost 121.259
# step 18650, change in cost 0.0302811
# step 18660, training accuracy 0.987992
# step 18660, cost 121.229
# step 18660, change in cost 0.0305786
# step 18670, training accuracy 0.987992
# step 18670, cost 121.198
# step 18670, change in cost 0.0308838
# step 18680, training accuracy 0.987992
# step 18680, cost 121.167
# step 18680, change in cost 0.031311
# step 18690, training accuracy 0.987992
# step 18690, cost 121.135
# step 18690, change in cost 0.0316772
# step 18700, training accuracy 0.987992
# step 18700, cost 121.103
# step 18700, change in cost 0.0320663
# step 18710, training accuracy 0.987992
# step 18710, cost 121.07
# step 18710, change in cost 0.032486
# step 18720, training accuracy 0.987992
# step 18720, cost 121.038
# step 18720, change in cost 0.0328751
# step 18730, training accuracy 0.987992
# step 18730, cost 121.004
# step 18730, change in cost 0.0333176
# step 18740, training accuracy 0.987992
# step 18740, cost 120.971
# step 18740, change in cost 0.0336533
# step 18750, training accuracy 0.987992
# step 18750, cost 120.937
# step 18750, change in cost 0.0340881
# step 18760, training accuracy 0.987992
# step 18760, cost 120.902
# step 18760, change in cost 0.0343933
# step 18770, training accuracy 0.987992
# step 18770, cost 120.867
# step 18770, change in cost 0.034729
# step 18780, training accuracy 0.987992
# step 18780, cost 120.832
# step 18780, change in cost 0.0349197
# step 18790, training accuracy 0.987992
# step 18790, cost 120.797
# step 18790, change in cost 0.0351334
# step 18800, training accuracy 0.987992
# step 18800, cost 120.762
# step 18800, change in cost 0.0351486
# step 18810, training accuracy 0.988072
# step 18810, cost 120.727
# step 18810, change in cost 0.0351639
# step 18820, training accuracy 0.988072
# step 18820, cost 120.692
# step 18820, change in cost 0.0350571
# step 18830, training accuracy 0.988072
# step 18830, cost 120.657
# step 18830, change in cost 0.0347366
# step 18840, training accuracy 0.988072
# step 18840, cost 120.623
# step 18840, change in cost 0.0344849
# step 18850, training accuracy 0.988072
# step 18850, cost 120.589
# step 18850, change in cost 0.0341034
# step 18860, training accuracy 0.988072
# step 18860, cost 120.555
# step 18860, change in cost 0.0335846
# step 18870, training accuracy 0.988072
# step 18870, cost 120.522
# step 18870, change in cost 0.0330505
# step 18880, training accuracy 0.988072
# step 18880, cost 120.49
# step 18880, change in cost 0.0324936
# step 18890, training accuracy 0.988151
# step 18890, cost 120.458
# step 18890, change in cost 0.0318832
# step 18900, training accuracy 0.988151
# step 18900, cost 120.426
# step 18900, change in cost 0.0312576
# step 18910, training accuracy 0.988151
# step 18910, cost 120.396
# step 18910, change in cost 0.0306473
# step 18920, training accuracy 0.988151
# step 18920, cost 120.366
# step 18920, change in cost 0.0300446
# step 18930, training accuracy 0.988151
# step 18930, cost 120.336
# step 18930, change in cost 0.0294571
# step 18940, training accuracy 0.988151
# step 18940, cost 120.307
# step 18940, change in cost 0.0289459
# step 18950, training accuracy 0.988151
# step 18950, cost 120.279
# step 18950, change in cost 0.028389
# step 18960, training accuracy 0.988151
# step 18960, cost 120.251
# step 18960, change in cost 0.0278931
# step 18970, training accuracy 0.988151
# step 18970, cost 120.224
# step 18970, change in cost 0.0274048
# step 18980, training accuracy 0.988151
# step 18980, cost 120.197
# step 18980, change in cost 0.0269775
# step 18990, training accuracy 0.988151
# step 18990, cost 120.17
# step 18990, change in cost 0.0266113
# step 19000, training accuracy 0.988151
# step 19000, cost 120.144
# step 19000, change in cost 0.0262375
# step 19010, training accuracy 0.988151
# step 19010, cost 120.118
# step 19010, change in cost 0.0258713
# step 19020, training accuracy 0.988151
# step 19020, cost 120.092
# step 19020, change in cost 0.0255661
# step 19030, training accuracy 0.988151
# step 19030, cost 120.067
# step 19030, change in cost 0.0252457
# step 19040, training accuracy 0.988151
# step 19040, cost 120.042
# step 19040, change in cost 0.0249939
# step 19050, training accuracy 0.988151
# step 19050, cost 120.017
# step 19050, change in cost 0.0247421
# step 19060, training accuracy 0.988151
# step 19060, cost 119.993
# step 19060, change in cost 0.0244446
# step 19070, training accuracy 0.988151
# step 19070, cost 119.969
# step 19070, change in cost 0.0242615
# step 19080, training accuracy 0.988151
# step 19080, cost 119.945
# step 19080, change in cost 0.0240784
# step 19090, training accuracy 0.988151
# step 19090, cost 119.921
# step 19090, change in cost 0.0238266
# step 19100, training accuracy 0.988151
# step 19100, cost 119.897
# step 19100, change in cost 0.0237274
# step 19110, training accuracy 0.988151
# step 19110, cost 119.874
# step 19110, change in cost 0.0234833
# step 19120, training accuracy 0.988151
# step 19120, cost 119.85
# step 19120, change in cost 0.0233612
# step 19130, training accuracy 0.988151
# step 19130, cost 119.827
# step 19130, change in cost 0.0231934
# step 19140, training accuracy 0.988151
# step 19140, cost 119.804
# step 19140, change in cost 0.0230713
# step 19150, training accuracy 0.988151
# step 19150, cost 119.781
# step 19150, change in cost 0.0229263
# step 19160, training accuracy 0.988151
# step 19160, cost 119.758
# step 19160, change in cost 0.0228195
# step 19170, training accuracy 0.988151
# step 19170, cost 119.735
# step 19170, change in cost 0.0226822
# step 19180, training accuracy 0.988151
# step 19180, cost 119.713
# step 19180, change in cost 0.0225449
# step 19190, training accuracy 0.988151
# step 19190, cost 119.69
# step 19190, change in cost 0.0225067
# step 19200, training accuracy 0.988151
# step 19200, cost 119.668
# step 19200, change in cost 0.0223923
# step 19210, training accuracy 0.988151
# step 19210, cost 119.646
# step 19210, change in cost 0.0222626
# step 19220, training accuracy 0.988151
# step 19220, cost 119.624
# step 19220, change in cost 0.0222702
# step 19230, training accuracy 0.988151
# step 19230, cost 119.601
# step 19230, change in cost 0.02211
# step 19240, training accuracy 0.988151
# step 19240, cost 119.579
# step 19240, change in cost 0.0221024
# step 19250, training accuracy 0.988151
# step 19250, cost 119.557
# step 19250, change in cost 0.0220261
# step 19260, training accuracy 0.988151
# step 19260, cost 119.535
# step 19260, change in cost 0.0219498
# step 19270, training accuracy 0.988151
# step 19270, cost 119.513
# step 19270, change in cost 0.0219345
# step 19280, training accuracy 0.988151
# step 19280, cost 119.492
# step 19280, change in cost 0.0218658
# step 19290, training accuracy 0.988151
# step 19290, cost 119.47
# step 19290, change in cost 0.0218964
# step 19300, training accuracy 0.988151
# step 19300, cost 119.448
# step 19300, change in cost 0.0218201
# step 19310, training accuracy 0.988151
# step 19310, cost 119.426
# step 19310, change in cost 0.0218353
# step 19320, training accuracy 0.988151
# step 19320, cost 119.404
# step 19320, change in cost 0.0217896
# step 19330, training accuracy 0.988151
# step 19330, cost 119.382
# step 19330, change in cost 0.0217743
# step 19340, training accuracy 0.988151
# step 19340, cost 119.361
# step 19340, change in cost 0.0218124
# step 19350, training accuracy 0.988151
# step 19350, cost 119.339
# step 19350, change in cost 0.0218582
# step 19360, training accuracy 0.988151
# step 19360, cost 119.317
# step 19360, change in cost 0.0217972
# step 19370, training accuracy 0.988151
# step 19370, cost 119.295
# step 19370, change in cost 0.0218811
# step 19380, training accuracy 0.988151
# step 19380, cost 119.273
# step 19380, change in cost 0.0219116
# step 19390, training accuracy 0.988231
# step 19390, cost 119.251
# step 19390, change in cost 0.0219574
# step 19400, training accuracy 0.988231
# step 19400, cost 119.229
# step 19400, change in cost 0.0219955
# step 19410, training accuracy 0.988231
# step 19410, cost 119.207
# step 19410, change in cost 0.0220642
# step 19420, training accuracy 0.988231
# step 19420, cost 119.185
# step 19420, change in cost 0.0221558
# step 19430, training accuracy 0.988231
# step 19430, cost 119.163
# step 19430, change in cost 0.0222397
# step 19440, training accuracy 0.988231
# step 19440, cost 119.14
# step 19440, change in cost 0.022316
# step 19450, training accuracy 0.988231
# step 19450, cost 119.118
# step 19450, change in cost 0.0224533
# step 19460, training accuracy 0.988231
# step 19460, cost 119.095
# step 19460, change in cost 0.0225296
# step 19470, training accuracy 0.988231
# step 19470, cost 119.073
# step 19470, change in cost 0.0227051
# step 19480, training accuracy 0.988231
# step 19480, cost 119.05
# step 19480, change in cost 0.0228195
# step 19490, training accuracy 0.988231
# step 19490, cost 119.027
# step 19490, change in cost 0.0230179
# step 19500, training accuracy 0.988231
# step 19500, cost 119.004
# step 19500, change in cost 0.0231476
# step 19510, training accuracy 0.988231
# step 19510, cost 118.98
# step 19510, change in cost 0.0233231
# step 19520, training accuracy 0.988231
# step 19520, cost 118.957
# step 19520, change in cost 0.0235519
# step 19530, training accuracy 0.988231
# step 19530, cost 118.933
# step 19530, change in cost 0.0237961
# step 19540, training accuracy 0.988231
# step 19540, cost 118.909
# step 19540, change in cost 0.0240097
# step 19550, training accuracy 0.988231
# step 19550, cost 118.885
# step 19550, change in cost 0.0242157
# step 19560, training accuracy 0.988231
# step 19560, cost 118.86
# step 19560, change in cost 0.0245209
# step 19570, training accuracy 0.988231
# step 19570, cost 118.836
# step 19570, change in cost 0.024765
# step 19580, training accuracy 0.988231
# step 19580, cost 118.81
# step 19580, change in cost 0.0251007
# step 19590, training accuracy 0.988231
# step 19590, cost 118.785
# step 19590, change in cost 0.0254059
# step 19600, training accuracy 0.988231
# step 19600, cost 118.759
# step 19600, change in cost 0.0257492
# step 19610, training accuracy 0.988231
# step 19610, cost 118.733
# step 19610, change in cost 0.0261459
# step 19620, training accuracy 0.988231
# step 19620, cost 118.707
# step 19620, change in cost 0.0265045
# step 19630, training accuracy 0.988231
# step 19630, cost 118.68
# step 19630, change in cost 0.0268936
# step 19640, training accuracy 0.988231
# step 19640, cost 118.652
# step 19640, change in cost 0.0273132
# step 19650, training accuracy 0.988231
# step 19650, cost 118.625
# step 19650, change in cost 0.0277863
# step 19660, training accuracy 0.988231
# step 19660, cost 118.596
# step 19660, change in cost 0.0282822
# step 19670, training accuracy 0.988231
# step 19670, cost 118.568
# step 19670, change in cost 0.0287628
# step 19680, training accuracy 0.988231
# step 19680, cost 118.538
# step 19680, change in cost 0.0292206
# step 19690, training accuracy 0.988231
# step 19690, cost 118.509
# step 19690, change in cost 0.0297928
# step 19700, training accuracy 0.988231
# step 19700, cost 118.478
# step 19700, change in cost 0.0302887
# step 19710, training accuracy 0.988231
# step 19710, cost 118.447
# step 19710, change in cost 0.0309372
# step 19720, training accuracy 0.988231
# step 19720, cost 118.416
# step 19720, change in cost 0.0314789
# step 19730, training accuracy 0.988231
# step 19730, cost 118.384
# step 19730, change in cost 0.0320816
# step 19740, training accuracy 0.988231
# step 19740, cost 118.351
# step 19740, change in cost 0.0327072
# step 19750, training accuracy 0.988231
# step 19750, cost 118.318
# step 19750, change in cost 0.0332794
# step 19760, training accuracy 0.988231
# step 19760, cost 118.284
# step 19760, change in cost 0.0339203
# step 19770, training accuracy 0.988231
# step 19770, cost 118.249
# step 19770, change in cost 0.0345306
# step 19780, training accuracy 0.988231
# step 19780, cost 118.214
# step 19780, change in cost 0.0351257
# step 19790, training accuracy 0.988231
# step 19790, cost 118.179
# step 19790, change in cost 0.0356903
# step 19800, training accuracy 0.988231
# step 19800, cost 118.142
# step 19800, change in cost 0.0363007
# step 19810, training accuracy 0.988231
# step 19810, cost 118.105
# step 19810, change in cost 0.0368042
# step 19820, training accuracy 0.988231
# step 19820, cost 118.068
# step 19820, change in cost 0.0373535
# step 19830, training accuracy 0.988231
# step 19830, cost 118.03
# step 19830, change in cost 0.0377884
# step 19840, training accuracy 0.988231
# step 19840, cost 117.992
# step 19840, change in cost 0.0382156
# step 19850, training accuracy 0.988231
# step 19850, cost 117.953
# step 19850, change in cost 0.0386124
# step 19860, training accuracy 0.988231
# step 19860, cost 117.915
# step 19860, change in cost 0.0389023
# step 19870, training accuracy 0.988231
# step 19870, cost 117.875
# step 19870, change in cost 0.0391388
# step 19880, training accuracy 0.988231
# step 19880, cost 117.836
# step 19880, change in cost 0.0393143
# step 19890, training accuracy 0.988231
# step 19890, cost 117.797
# step 19890, change in cost 0.0394745
# step 19900, training accuracy 0.988231
# step 19900, cost 117.757
# step 19900, change in cost 0.0395432
# step 19910, training accuracy 0.988231
# step 19910, cost 117.718
# step 19910, change in cost 0.0394516
# step 19920, training accuracy 0.988231
# step 19920, cost 117.678
# step 19920, change in cost 0.0393906
# step 19930, training accuracy 0.988231
# step 19930, cost 117.639
# step 19930, change in cost 0.039238
# step 19940, training accuracy 0.988231
# step 19940, cost 117.6
# step 19940, change in cost 0.0389938
# step 19950, training accuracy 0.988231
# step 19950, cost 117.561
# step 19950, change in cost 0.0387268
# step 19960, training accuracy 0.988231
# step 19960, cost 117.523
# step 19960, change in cost 0.0383453
# step 19970, training accuracy 0.988231
# step 19970, cost 117.485
# step 19970, change in cost 0.0379639
# step 19980, training accuracy 0.988231
# step 19980, cost 117.447
# step 19980, change in cost 0.0375443
# step 19990, training accuracy 0.988231
# step 19990, cost 117.41
# step 19990, change in cost 0.0370865
# final accuracy on test set: 0.986409

# %% [markdown]
# # Import new set
# Now we'll bring in the 1000 most recent recipes published to Cookpad and return those which are identified by the algorithm as 'dinner' so that we can subject them to human analysis.

# %%
data = rec_parse.parse_newest_recipes() 
print("data shape =", data.shape)
# Out:
# data shape = (1000, 4114)

# %%
import csv
with tf.Session() as lolo:
    saver.restore(lolo, '/tmp/dessert-model')
    print("Model restored.")
    print("Checking ", len(data), "recipes.")
    
    predictions = lolo.run(activation_OP, feed_dict={X: data})

    
    id_set = []
    
    for index, i in enumerate(predictions):
        if i[0] > .99:
            id_set.append(index)
    
    for n in rec_parse.convert_to_id(id_set):  
        print('cookpad.com/us/recipes/' + n[1])
        
    print(len(id_set), "dinner recipes detected")
# Out:
# Model restored.
# Checking  1000 recipes.
# cookpad.com/us/recipes/1900940
# cookpad.com/us/recipes/1900388
# cookpad.com/us/recipes/1900016
# cookpad.com/us/recipes/1896954
# cookpad.com/us/recipes/1896590
# cookpad.com/us/recipes/1896166
# cookpad.com/us/recipes/1894543
# cookpad.com/us/recipes/1886049
# cookpad.com/us/recipes/1895723
# cookpad.com/us/recipes/1895628
# cookpad.com/us/recipes/1895125
# cookpad.com/us/recipes/1894743
# cookpad.com/us/recipes/1880324
# cookpad.com/us/recipes/1893527
# cookpad.com/us/recipes/1892928
# cookpad.com/us/recipes/1892055
# cookpad.com/us/recipes/1891589
# cookpad.com/us/recipes/1891156
# cookpad.com/us/recipes/1890205
# cookpad.com/us/recipes/1889791
# cookpad.com/us/recipes/1888753
# cookpad.com/us/recipes/1887796
# cookpad.com/us/recipes/1887425
# cookpad.com/us/recipes/1886909
# cookpad.com/us/recipes/1886894
# cookpad.com/us/recipes/1885047
# cookpad.com/us/recipes/1551724
# cookpad.com/us/recipes/1877240
# cookpad.com/us/recipes/1875458
# cookpad.com/us/recipes/1873629
# cookpad.com/us/recipes/1873226
# cookpad.com/us/recipes/1773916
# cookpad.com/us/recipes/1871652
# cookpad.com/us/recipes/1871535
# cookpad.com/us/recipes/1870662
# cookpad.com/us/recipes/453738
# cookpad.com/us/recipes/863008
# cookpad.com/us/recipes/1866763
# cookpad.com/us/recipes/1868923
# cookpad.com/us/recipes/1868523
# cookpad.com/us/recipes/1866820
# cookpad.com/us/recipes/1571866
# cookpad.com/us/recipes/1866511
# cookpad.com/us/recipes/1865934
# cookpad.com/us/recipes/1865108
# cookpad.com/us/recipes/1839361
# cookpad.com/us/recipes/1862880
# cookpad.com/us/recipes/1859824
# cookpad.com/us/recipes/1859821
# cookpad.com/us/recipes/652971
# cookpad.com/us/recipes/1862034
# cookpad.com/us/recipes/1861402
# cookpad.com/us/recipes/1419061
# cookpad.com/us/recipes/1860616
# cookpad.com/us/recipes/1859180
# cookpad.com/us/recipes/1860534
# cookpad.com/us/recipes/1860210
# cookpad.com/us/recipes/1732230
# cookpad.com/us/recipes/1858845
# cookpad.com/us/recipes/1856684
# cookpad.com/us/recipes/1856148
# cookpad.com/us/recipes/1854078
# cookpad.com/us/recipes/1853740
# cookpad.com/us/recipes/1814299
# cookpad.com/us/recipes/1848004
# cookpad.com/us/recipes/1847724
# cookpad.com/us/recipes/1847730
# cookpad.com/us/recipes/1842604
# cookpad.com/us/recipes/1843692
# cookpad.com/us/recipes/1844133
# cookpad.com/us/recipes/1842133
# cookpad.com/us/recipes/1841799
# cookpad.com/us/recipes/1825521
# cookpad.com/us/recipes/1840323
# cookpad.com/us/recipes/688510
# cookpad.com/us/recipes/1837689
# cookpad.com/us/recipes/1839142
# cookpad.com/us/recipes/1828429
# cookpad.com/us/recipes/1837809
# cookpad.com/us/recipes/1659780
# cookpad.com/us/recipes/1836887
# cookpad.com/us/recipes/1836770
# cookpad.com/us/recipes/1836446
# cookpad.com/us/recipes/1835858
# cookpad.com/us/recipes/1835306
# cookpad.com/us/recipes/1834872
# cookpad.com/us/recipes/1834721
# cookpad.com/us/recipes/1834410
# cookpad.com/us/recipes/1825925
# cookpad.com/us/recipes/1833307
# cookpad.com/us/recipes/1823064
# cookpad.com/us/recipes/1831602
# cookpad.com/us/recipes/1831537
# cookpad.com/us/recipes/1808053
# cookpad.com/us/recipes/1828342
# cookpad.com/us/recipes/1828434
# cookpad.com/us/recipes/1828263
# cookpad.com/us/recipes/722468
# cookpad.com/us/recipes/1825582
# cookpad.com/us/recipes/1811537
# cookpad.com/us/recipes/1822409
# cookpad.com/us/recipes/1818799
# cookpad.com/us/recipes/1822089
# cookpad.com/us/recipes/1821661
# cookpad.com/us/recipes/1761097
# cookpad.com/us/recipes/1818699
# cookpad.com/us/recipes/1818628
# cookpad.com/us/recipes/1808551
# cookpad.com/us/recipes/1814044
# cookpad.com/us/recipes/1813564
# cookpad.com/us/recipes/1813190
# cookpad.com/us/recipes/1709830
# cookpad.com/us/recipes/1812154
# cookpad.com/us/recipes/1793820
# cookpad.com/us/recipes/1808172
# cookpad.com/us/recipes/1800541
# cookpad.com/us/recipes/1779048
# cookpad.com/us/recipes/1807861
# cookpad.com/us/recipes/1518393
# cookpad.com/us/recipes/1807194
# cookpad.com/us/recipes/1216410
# cookpad.com/us/recipes/1798897
# cookpad.com/us/recipes/1490562
# cookpad.com/us/recipes/1803380
# cookpad.com/us/recipes/1803188
# cookpad.com/us/recipes/1796827
# cookpad.com/us/recipes/1802694
# cookpad.com/us/recipes/1802630
# cookpad.com/us/recipes/1802505
# cookpad.com/us/recipes/1760368
# cookpad.com/us/recipes/1798230
# cookpad.com/us/recipes/1798309
# cookpad.com/us/recipes/1795208
# cookpad.com/us/recipes/526585
# cookpad.com/us/recipes/1469550
# cookpad.com/us/recipes/1793839
# cookpad.com/us/recipes/1793682
# cookpad.com/us/recipes/1793644
# cookpad.com/us/recipes/1792399
# cookpad.com/us/recipes/1792224
# cookpad.com/us/recipes/1789824
# cookpad.com/us/recipes/1789827
# cookpad.com/us/recipes/1781415
# cookpad.com/us/recipes/1776191
# cookpad.com/us/recipes/1757669
# cookpad.com/us/recipes/1773119
# cookpad.com/us/recipes/1786286
# cookpad.com/us/recipes/1784812
# cookpad.com/us/recipes/1784536
# cookpad.com/us/recipes/1782912
# cookpad.com/us/recipes/1780534
# cookpad.com/us/recipes/1780273
# cookpad.com/us/recipes/1780264
# cookpad.com/us/recipes/1780237
# cookpad.com/us/recipes/1775119
# cookpad.com/us/recipes/453726
# cookpad.com/us/recipes/1778965
# cookpad.com/us/recipes/1778118
# cookpad.com/us/recipes/1777418
# cookpad.com/us/recipes/1776555
# cookpad.com/us/recipes/1775587
# cookpad.com/us/recipes/1772179
# cookpad.com/us/recipes/1775376
# cookpad.com/us/recipes/1775131
# 164 dinner recipes detected
