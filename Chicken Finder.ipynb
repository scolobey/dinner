# %%
# %matplotlib inline

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import time
import rec_parse

# %% [markdown]
# # Collect Data
# To obtain data, a recipe is parsed to identify dictionary matches. Each dictionary entry corresponds to an index in recipe space. So, each recipe is represented as a vector in recipe space of dimension 4060. Beginnning with a set of 15768 recipe vectors. 10% of those vectors, at equal intervals are reserved as test data. The result should be 4 matrices, trainX representing 14191 recipe vectors, trainY representing binary labels for each of those recipes, testX representing 1577 recipe vectors on which to test, and testY reresenting labels for the test data. For the label matrices, a 1 in column 0 represents 'dinner', while a 1 in column 1 represents 'non-dinner'.

# %%
rec_parse.clear_data()

chicken_count = rec_parse.initialize_csv("chicken_magic.csv")

data = rec_parse.generate_training_data()

chicken_labels = np.zeros((chicken_count, 2), dtype=np.int)

for ind, label in enumerate(chicken_labels):
    if ind > 5000:
        chicken_labels[ind][1] = 1
    else:
        chicken_labels[ind][0] = 1
                                                 
labels = chicken_labels

trainX, testX = rec_parse.split(data)
trainY, testY = rec_parse.split(chicken_labels)
                          
# # data = rec_parse.parse_recipes()
                          
# # trainX, testX = rec_parse.split(data)

# # trainY = np.zeros((len(data)-1577, 2), dtype=np.int)
# # testY = np.zeros([1577, 2], dtype=np.int)

# # for ind, row in enumerate(trainY):
# #     if ind > 1500:
# #         trainY[ind][1] = 1
# #     else:
# #         trainY[ind][0] = 1

# # for ind, row in enumerate(testY):
# #     if ind > 150:
# #         testY[ind][1] = 1
# #     else:
# #         testY[ind][0] = 1
        
print("Your data is ready.")
print("trainX shape =", trainX.shape)
print("trainY shape =", trainY.shape)
print("testX shape =", testX.shape)
print("testY shape =", testY.shape)

print(len(data))
# Out:
# Your data is ready.
# trainX shape = (15541, 3937)
# trainY shape = (15541, 2)
# testX shape = (1727, 3937)
# testY shape = (1727, 2)
# 17268

# %% [markdown]
# # Initialize graph features
#
# At line 4, numEpochs is set very low at 100. This low number of epochs results in a model that builds quickly, but has low accuracy. to experiment with a more accurate model, increase numEpochs to at least 2000. To train a production model, you would likely run close to 30k, and probably continue running until cost no longer changes, or does so minimally from epoch to epoch.

# %%
numFeatures = trainX.shape[1]
numLabels = trainY.shape[1]

numEpochs = 20000

tf.reset_default_graph()

learningRate = tf.train.exponential_decay(learning_rate=0.0008,
                                          global_step= 1,
                                          decay_steps=trainX.shape[0],
                                          decay_rate= 0.95,
                                          staircase=True)

X = tf.placeholder(tf.float32, [None, numFeatures])
yGold = tf.placeholder(tf.float32, [None, numLabels])

# %% [markdown]
# # Initialize variables

# %%
weights = tf.Variable(tf.random_normal([numFeatures,numLabels],
                                       mean=0,
                                       stddev=(np.sqrt(6/numFeatures+
                                                         numLabels+1)),
                                       name="weights"))

bias = tf.Variable(tf.random_normal([1,numLabels],
                                    mean=0,
                                    stddev=(np.sqrt(6/numFeatures+numLabels+1)),
                                    name="bias"))

init_OP = tf.global_variables_initializer()

for i in tf.global_variables():
    print(i)
# Out:
# Tensor("Variable/read:0", shape=(3937, 2), dtype=float32)
# Tensor("Variable_1/read:0", shape=(1, 2), dtype=float32)

# %% [markdown]
# # The algorithm
# Multiply trainX(14191, 4060) by weights(4060, 2), resulting in apply_weights_OP(14191, 2).
# And add the bias(1, 2), resulting in add_bias_OP(14191, 2)
#
# Activate using rectified linear:
# f(x) = max(0, x)
#
# Calculate loss using Mean Squared Error:
# $\frac{1}{n}\sum_{i=0}^n ({y}_{estimated}-{y}_{real})^2$
#
# Optimize using gradient descent.

# %%
# FEEDFORWARD ALGORITHM
apply_weights_OP = tf.matmul(X, weights, name="apply_weights")
add_bias_OP = tf.add(apply_weights_OP, bias, name="add_bias")
activation_OP = tf.nn.sigmoid(add_bias_OP, name="activation")

# COST FUNCTION i.e. MEAN SQUARED ERROR
cost_OP = tf.nn.l2_loss(activation_OP-yGold, name="squared_error_cost")

# OPTIMIZATION ALGORITHM i.e. GRADIENT DESCENT
training_OP = tf.train.GradientDescentOptimizer(learningRate).minimize(cost_OP)

# %% [markdown]
# #  Run training

# %%
# Training epochs
with tf.Session() as sess:
    sess.run(init_OP)

    ###########################
    ### GRAPH LIVE UPDATING ###
    ###########################

    epoch_values=[]
    accuracy_values=[]
    cost_values=[]
    
    # Turn on interactive plotting
    plt.ion()
    # Create the main, super plot
    fig = plt.figure()
    # Create two subplots on their own axes and give titles
    ax1 = plt.subplot("211")
    ax1.set_title("TRAINING ACCURACY", fontsize=10)
    ax2 = plt.subplot("212")
    ax2.set_title("TRAINING COST", fontsize=10)
    plt.tight_layout()


    #####################
    ### RUN THE GRAPH ###
    #####################

    ## Ops for vizualization
    # argmax(activation_OP, 1) gives the label our model thought was most likely
    # argmax(yGold, 1) is the correct label
    correct_predictions_OP = tf.equal(tf.argmax(activation_OP,1),tf.argmax(yGold,1))
    # False is 0 and True is 1, what was our average?
    accuracy_OP = tf.reduce_mean(tf.cast(correct_predictions_OP, "float"))
    # Summary op for regression output
    activation_summary_OP = tf.summary.histogram("output", activation_OP)
    # Summary op for accuracy
    accuracy_summary_OP = tf.summary.scalar("accuracy", accuracy_OP)
    # Summary op for cost
    cost_summary_OP = tf.summary.scalar("cost", cost_OP)
    # Summary ops to check how variables (W, b) are updating after each iteration
    weightSummary = tf.summary.histogram("weights", weights.eval(session=sess))
    biasSummary = tf.summary.histogram("biases", bias.eval(session=sess))
    # Merge all summaries
    all_summary_OPS = tf.summary.merge_all()
    # Summary writer
    writer = tf.summary.FileWriter("summary_logs", sess.graph)

    # Initialize reporting variables
    cost = 0
    diff = 1

    for i in range(numEpochs): 
        if i > 1 and diff < .0001:
            print("change in cost %g; convergence."%diff)
            break
        else:
            # Run training step
            step = sess.run(training_OP, feed_dict={X: trainX, yGold: trainY})
            
            # Report occasional stats
            if i % 10 == 0:
                # Add epoch to epoch_values
                epoch_values.append(i)
                # Generate accuracy stats on test data
                summary_results, train_accuracy, newCost = sess.run(
                    [all_summary_OPS, accuracy_OP, cost_OP],
                    feed_dict={X: trainX, yGold: trainY}
                )
                # Add accuracy to live graphing variable
                accuracy_values.append(train_accuracy)
                # Add cost to live graphing variable
                cost_values.append(newCost)
                # Write summary stats to writer
                writer.add_summary(summary_results, i)
                # Re-assign values for variables
                diff = abs(newCost - cost)
                cost = newCost

                #generate print statements
                print("step %d, training accuracy %g"%(i, train_accuracy))
                print("step %d, cost %g"%(i, newCost))
                print("step %d, change in cost %g"%(i, diff))

                # Plot progress to our two subplots
                accuracyLine, = ax1.plot(epoch_values, accuracy_values)
                costLine, = ax2.plot(epoch_values, cost_values)
                fig.canvas.draw()
                time.sleep(1)
    
    # Create Saver
    saver = tf.train.Saver()   
    saver.save(sess, '/tmp/chicken-model')

    # How well do we perform on held-out test data?
    print("final accuracy on test set: %s" %str(sess.run(accuracy_OP,
                                                         feed_dict={X: testX,
                                                                    yGold: testY})))
# Out:
# step 0, training accuracy 0.445274
# step 0, cost 7853.38
# step 0, change in cost 7853.38
# step 10, training accuracy 0.675761
# step 10, cost 5128.57
# step 10, change in cost 2724.81
# step 20, training accuracy 0.694164
# step 20, cost 4805.84
# step 20, change in cost 322.729
# step 30, training accuracy 0.699891
# step 30, cost 4705.68
# step 30, change in cost 100.157
# step 40, training accuracy 0.702336
# step 40, cost 4664.03
# step 40, change in cost 41.6538
# step 50, training accuracy 0.703623
# step 50, cost 4639.6
# step 50, change in cost 24.4238
# step 60, training accuracy 0.705424
# step 60, cost 4615.66
# step 60, change in cost 23.9385
# step 70, training accuracy 0.706325
# step 70, cost 4599.2
# step 70, change in cost 16.4614
# step 80, training accuracy 0.706583
# step 80, cost 4586.9
# step 80, change in cost 12.3008
# step 90, training accuracy 0.707226
# step 90, cost 4575.52
# step 90, change in cost 11.3833
# step 100, training accuracy 0.707548
# step 100, cost 4565.47
# step 100, change in cost 10.0474
# step 110, training accuracy 0.707998
# step 110, cost 4558.3
# step 110, change in cost 7.16943
# step 120, training accuracy 0.707934
# step 120, cost 4553.05
# step 120, change in cost 5.24805
# step 130, training accuracy 0.70832
# step 130, cost 4549.04
# step 130, change in cost 4.01221
# step 140, training accuracy 0.708513
# step 140, cost 4545.85
# step 140, change in cost 3.18994
# step 150, training accuracy 0.708384
# step 150, cost 4543.15
# step 150, change in cost 2.69922
# step 160, training accuracy 0.708577
# step 160, cost 4540.68
# step 160, change in cost 2.46875
# step 170, training accuracy 0.708642
# step 170, cost 4538.33
# step 170, change in cost 2.35645
# step 180, training accuracy 0.708642
# step 180, cost 4536.05
# step 180, change in cost 2.27588
# step 190, training accuracy 0.70877
# step 190, cost 4533.86
# step 190, change in cost 2.18994
# step 200, training accuracy 0.708706
# step 200, cost 4531.82
# step 200, change in cost 2.03955
# step 210, training accuracy 0.708835
# step 210, cost 4529.99
# step 210, change in cost 1.83105
# step 220, training accuracy 0.708899
# step 220, cost 4528.36
# step 220, change in cost 1.62646
# step 230, training accuracy 0.708835
# step 230, cost 4526.92
# step 230, change in cost 1.44629
# step 240, training accuracy 0.708835
# step 240, cost 4525.62
# step 240, change in cost 1.30078
# step 250, training accuracy 0.708835
# step 250, cost 4524.41
# step 250, change in cost 1.20605
# step 260, training accuracy 0.708835
# step 260, cost 4523.27
# step 260, change in cost 1.14258
# step 270, training accuracy 0.708835
# step 270, cost 4522.16
# step 270, change in cost 1.10547
# step 280, training accuracy 0.708963
# step 280, cost 4521.1
# step 280, change in cost 1.06641
# step 290, training accuracy 0.708963
# step 290, cost 4520.07
# step 290, change in cost 1.02148
# step 300, training accuracy 0.709092
# step 300, cost 4519.11
# step 300, change in cost 0.960938
# step 310, training accuracy 0.709092
# step 310, cost 4518.21
# step 310, change in cost 0.908203
# step 320, training accuracy 0.709028
# step 320, cost 4517.34
# step 320, change in cost 0.861328
# step 330, training accuracy 0.709028
# step 330, cost 4516.52
# step 330, change in cost 0.82373
# step 340, training accuracy 0.709092
# step 340, cost 4515.72
# step 340, change in cost 0.80127
# step 350, training accuracy 0.709092
# step 350, cost 4514.94
# step 350, change in cost 0.78125
# step 360, training accuracy 0.709092
# step 360, cost 4514.17
# step 360, change in cost 0.765625
# step 370, training accuracy 0.709028
# step 370, cost 4513.42
# step 370, change in cost 0.74707
# step 380, training accuracy 0.709028
# step 380, cost 4512.69
# step 380, change in cost 0.739746
# step 390, training accuracy 0.708963
# step 390, cost 4511.96
# step 390, change in cost 0.726074
# step 400, training accuracy 0.708963
# step 400, cost 4511.25
# step 400, change in cost 0.708984
# step 410, training accuracy 0.709028
# step 410, cost 4510.56
# step 410, change in cost 0.694336
# step 420, training accuracy 0.709028
# step 420, cost 4509.88
# step 420, change in cost 0.67334
# step 430, training accuracy 0.709028
# step 430, cost 4509.23
# step 430, change in cost 0.655762
# step 440, training accuracy 0.709028
# step 440, cost 4508.59
# step 440, change in cost 0.635742
# step 450, training accuracy 0.709092
# step 450, cost 4507.98
# step 450, change in cost 0.615234
# step 460, training accuracy 0.709221
# step 460, cost 4507.37
# step 460, change in cost 0.602539
# step 470, training accuracy 0.709221
# step 470, cost 4506.79
# step 470, change in cost 0.585938
# step 480, training accuracy 0.709285
# step 480, cost 4506.22
# step 480, change in cost 0.571289
# step 490, training accuracy 0.709285
# step 490, cost 4505.65
# step 490, change in cost 0.563965
# step 500, training accuracy 0.709285
# step 500, cost 4505.1
# step 500, change in cost 0.552246
# step 510, training accuracy 0.709349
# step 510, cost 4504.56
# step 510, change in cost 0.543457
# step 520, training accuracy 0.709349
# step 520, cost 4504.02
# step 520, change in cost 0.535645
# step 530, training accuracy 0.709285
# step 530, cost 4503.48
# step 530, change in cost 0.536133
# step 540, training accuracy 0.709285
# step 540, cost 4502.96
# step 540, change in cost 0.521484
# step 550, training accuracy 0.709285
# step 550, cost 4502.47
# step 550, change in cost 0.494141
# step 560, training accuracy 0.709285
# step 560, cost 4502.01
# step 560, change in cost 0.460449
# step 570, training accuracy 0.709285
# step 570, cost 4501.58
# step 570, change in cost 0.431152
# step 580, training accuracy 0.709285
# step 580, cost 4501.17
# step 580, change in cost 0.408203
# step 590, training accuracy 0.709285
# step 590, cost 4500.77
# step 590, change in cost 0.394531
# step 600, training accuracy 0.709285
# step 600, cost 4500.39
# step 600, change in cost 0.385742
# step 610, training accuracy 0.709285
# step 610, cost 4500.01
# step 610, change in cost 0.375488
# step 620, training accuracy 0.709285
# step 620, cost 4499.64
# step 620, change in cost 0.37207
# step 630, training accuracy 0.709414
# step 630, cost 4499.28
# step 630, change in cost 0.362305
# step 640, training accuracy 0.709414
# step 640, cost 4498.92
# step 640, change in cost 0.356445
# step 650, training accuracy 0.709414
# step 650, cost 4498.57
# step 650, change in cost 0.354492
# step 660, training accuracy 0.709414
# step 660, cost 4498.22
# step 660, change in cost 0.349121
# step 670, training accuracy 0.709414
# step 670, cost 4497.87
# step 670, change in cost 0.348633
# step 680, training accuracy 0.709414
# step 680, cost 4497.53
# step 680, change in cost 0.341797
# step 690, training accuracy 0.709414
# step 690, cost 4497.19
# step 690, change in cost 0.335449
# step 700, training accuracy 0.709414
# step 700, cost 4496.86
# step 700, change in cost 0.334473
# step 710, training accuracy 0.709414
# step 710, cost 4496.53
# step 710, change in cost 0.332031
# step 720, training accuracy 0.709414
# step 720, cost 4496.2
# step 720, change in cost 0.328613
# step 730, training accuracy 0.709414
# step 730, cost 4495.87
# step 730, change in cost 0.328125
# step 740, training accuracy 0.709414
# step 740, cost 4495.55
# step 740, change in cost 0.321777
# step 750, training accuracy 0.709414
# step 750, cost 4495.23
# step 750, change in cost 0.321289
# step 760, training accuracy 0.709414
# step 760, cost 4494.91
# step 760, change in cost 0.320801
# step 770, training accuracy 0.709414
# step 770, cost 4494.59
# step 770, change in cost 0.314941
# step 780, training accuracy 0.709414
# step 780, cost 4494.27
# step 780, change in cost 0.320312
# step 790, training accuracy 0.709414
# step 790, cost 4493.96
# step 790, change in cost 0.314453
# step 800, training accuracy 0.709414
# step 800, cost 4493.64
# step 800, change in cost 0.314941
# step 810, training accuracy 0.709414
# step 810, cost 4493.33
# step 810, change in cost 0.312988
# step 820, training accuracy 0.709478
# step 820, cost 4493.02
# step 820, change in cost 0.310547
# step 830, training accuracy 0.709478
# step 830, cost 4492.71
# step 830, change in cost 0.30957
# step 840, training accuracy 0.709478
# step 840, cost 4492.4
# step 840, change in cost 0.311035
# step 850, training accuracy 0.709478
# step 850, cost 4492.09
# step 850, change in cost 0.306641
# step 860, training accuracy 0.709478
# step 860, cost 4491.79
# step 860, change in cost 0.304199
# step 870, training accuracy 0.709478
# step 870, cost 4491.49
# step 870, change in cost 0.300293
# step 880, training accuracy 0.709478
# step 880, cost 4491.19
# step 880, change in cost 0.299805
# step 890, training accuracy 0.709478
# step 890, cost 4490.89
# step 890, change in cost 0.297363
# step 900, training accuracy 0.709478
# step 900, cost 4490.59
# step 900, change in cost 0.294434
# step 910, training accuracy 0.709478
# step 910, cost 4490.3
# step 910, change in cost 0.292969
# step 920, training accuracy 0.709478
# step 920, cost 4490
# step 920, change in cost 0.29834
# step 930, training accuracy 0.709478
# step 930, cost 4489.71
# step 930, change in cost 0.291016
# step 940, training accuracy 0.709478
# step 940, cost 4489.42
# step 940, change in cost 0.292969
# step 950, training accuracy 0.709478
# step 950, cost 4489.12
# step 950, change in cost 0.295898
# step 960, training accuracy 0.709478
# step 960, cost 4488.82
# step 960, change in cost 0.298828
# step 970, training accuracy 0.709478
# step 970, cost 4488.52
# step 970, change in cost 0.299316
# step 980, training accuracy 0.709478
# step 980, cost 4488.23
# step 980, change in cost 0.298828
# step 990, training accuracy 0.709478
# step 990, cost 4487.93
# step 990, change in cost 0.297363
# step 1000, training accuracy 0.709543
# step 1000, cost 4487.64
# step 1000, change in cost 0.293457
# step 1010, training accuracy 0.709543
# step 1010, cost 4487.35
# step 1010, change in cost 0.288086
# step 1020, training accuracy 0.709543
# step 1020, cost 4487.06
# step 1020, change in cost 0.283691
# step 1030, training accuracy 0.709543
# step 1030, cost 4486.79
# step 1030, change in cost 0.27832
# step 1040, training accuracy 0.709543
# step 1040, cost 4486.51
# step 1040, change in cost 0.272461
# step 1050, training accuracy 0.709543
# step 1050, cost 4486.24
# step 1050, change in cost 0.271484
# step 1060, training accuracy 0.709543
# step 1060, cost 4485.97
# step 1060, change in cost 0.266602
# step 1070, training accuracy 0.709543
# step 1070, cost 4485.71
# step 1070, change in cost 0.261719
# step 1080, training accuracy 0.709543
# step 1080, cost 4485.45
# step 1080, change in cost 0.258789
# step 1090, training accuracy 0.709543
# step 1090, cost 4485.2
# step 1090, change in cost 0.254883
# step 1100, training accuracy 0.709543
# step 1100, cost 4484.95
# step 1100, change in cost 0.249023
# step 1110, training accuracy 0.709543
# step 1110, cost 4484.71
# step 1110, change in cost 0.241211
# step 1120, training accuracy 0.709607
# step 1120, cost 4484.47
# step 1120, change in cost 0.235352
# step 1130, training accuracy 0.709607
# step 1130, cost 4484.24
# step 1130, change in cost 0.230469
# step 1140, training accuracy 0.709607
# step 1140, cost 4484.02
# step 1140, change in cost 0.225586
# step 1150, training accuracy 0.709607
# step 1150, cost 4483.8
# step 1150, change in cost 0.216309
# step 1160, training accuracy 0.709607
# step 1160, cost 4483.59
# step 1160, change in cost 0.215332
# step 1170, training accuracy 0.709671
# step 1170, cost 4483.38
# step 1170, change in cost 0.209961
# step 1180, training accuracy 0.709671
# step 1180, cost 4483.17
# step 1180, change in cost 0.203125
# step 1190, training accuracy 0.709671
# step 1190, cost 4482.97
# step 1190, change in cost 0.199219
# step 1200, training accuracy 0.709671
# step 1200, cost 4482.78
# step 1200, change in cost 0.195312
# step 1210, training accuracy 0.709671
# step 1210, cost 4482.59
# step 1210, change in cost 0.192871
# step 1220, training accuracy 0.709671
# step 1220, cost 4482.4
# step 1220, change in cost 0.189453
# step 1230, training accuracy 0.709671
# step 1230, cost 4482.21
# step 1230, change in cost 0.1875
# step 1240, training accuracy 0.709671
# step 1240, cost 4482.02
# step 1240, change in cost 0.184082
# step 1250, training accuracy 0.709736
# step 1250, cost 4481.84
# step 1250, change in cost 0.181641
# step 1260, training accuracy 0.709736
# step 1260, cost 4481.66
# step 1260, change in cost 0.178711
# step 1270, training accuracy 0.709736
# step 1270, cost 4481.48
# step 1270, change in cost 0.180664
# step 1280, training accuracy 0.709736
# step 1280, cost 4481.31
# step 1280, change in cost 0.174805
# step 1290, training accuracy 0.709736
# step 1290, cost 4481.13
# step 1290, change in cost 0.174805
# step 1300, training accuracy 0.709736
# step 1300, cost 4480.96
# step 1300, change in cost 0.173828
# step 1310, training accuracy 0.709736
# step 1310, cost 4480.79
# step 1310, change in cost 0.171387
# step 1320, training accuracy 0.709736
# step 1320, cost 4480.62
# step 1320, change in cost 0.17334
# step 1330, training accuracy 0.709736
# step 1330, cost 4480.44
# step 1330, change in cost 0.171875
# step 1340, training accuracy 0.709736
# step 1340, cost 4480.27
# step 1340, change in cost 0.171875
# step 1350, training accuracy 0.7098
# step 1350, cost 4480.1
# step 1350, change in cost 0.172363
# step 1360, training accuracy 0.7098
# step 1360, cost 4479.93
# step 1360, change in cost 0.172363
# step 1370, training accuracy 0.709864
# step 1370, cost 4479.76
# step 1370, change in cost 0.171387
# step 1380, training accuracy 0.709864
# step 1380, cost 4479.58
# step 1380, change in cost 0.171387
# step 1390, training accuracy 0.709929
# step 1390, cost 4479.41
# step 1390, change in cost 0.17041
# step 1400, training accuracy 0.709929
# step 1400, cost 4479.25
# step 1400, change in cost 0.168457
# step 1410, training accuracy 0.709929
# step 1410, cost 4479.08
# step 1410, change in cost 0.169434
# step 1420, training accuracy 0.709929
# step 1420, cost 4478.91
# step 1420, change in cost 0.166504
# step 1430, training accuracy 0.709929
# step 1430, cost 4478.75
# step 1430, change in cost 0.164062
# step 1440, training accuracy 0.709929
# step 1440, cost 4478.58
# step 1440, change in cost 0.160156
# step 1450, training accuracy 0.709929
# step 1450, cost 4478.43
# step 1450, change in cost 0.158203
# step 1460, training accuracy 0.709929
# step 1460, cost 4478.27
# step 1460, change in cost 0.155273
# step 1470, training accuracy 0.709929
# step 1470, cost 4478.12
# step 1470, change in cost 0.150879
# step 1480, training accuracy 0.709929
# step 1480, cost 4477.97
# step 1480, change in cost 0.149414
# step 1490, training accuracy 0.709929
# step 1490, cost 4477.82
# step 1490, change in cost 0.148438
# step 1500, training accuracy 0.709929
# step 1500, cost 4477.68
# step 1500, change in cost 0.14502
# step 1510, training accuracy 0.709929
# step 1510, cost 4477.54
# step 1510, change in cost 0.142578
# step 1520, training accuracy 0.709929
# step 1520, cost 4477.39
# step 1520, change in cost 0.142578
# step 1530, training accuracy 0.709929
# step 1530, cost 4477.25
# step 1530, change in cost 0.138184
# step 1540, training accuracy 0.709929
# step 1540, cost 4477.12
# step 1540, change in cost 0.138184
# step 1550, training accuracy 0.709929
# step 1550, cost 4476.98
# step 1550, change in cost 0.134766
# step 1560, training accuracy 0.709929
# step 1560, cost 4476.85
# step 1560, change in cost 0.133301
# step 1570, training accuracy 0.709929
# step 1570, cost 4476.72
# step 1570, change in cost 0.131348
# step 1580, training accuracy 0.709929
# step 1580, cost 4476.59
# step 1580, change in cost 0.130371
# step 1590, training accuracy 0.709929
# step 1590, cost 4476.46
# step 1590, change in cost 0.126953
# step 1600, training accuracy 0.709929
# step 1600, cost 4476.33
# step 1600, change in cost 0.125488
# step 1610, training accuracy 0.709929
# step 1610, cost 4476.21
# step 1610, change in cost 0.12207
# step 1620, training accuracy 0.709929
# step 1620, cost 4476.09
# step 1620, change in cost 0.123047
# step 1630, training accuracy 0.709929
# step 1630, cost 4475.97
# step 1630, change in cost 0.120117
# step 1640, training accuracy 0.709929
# step 1640, cost 4475.85
# step 1640, change in cost 0.118652
# step 1650, training accuracy 0.709929
# step 1650, cost 4475.73
# step 1650, change in cost 0.117676
# step 1660, training accuracy 0.709929
# step 1660, cost 4475.62
# step 1660, change in cost 0.115234
# step 1670, training accuracy 0.709929
# step 1670, cost 4475.5
# step 1670, change in cost 0.11377
# step 1680, training accuracy 0.709929
# step 1680, cost 4475.39
# step 1680, change in cost 0.112305
# step 1690, training accuracy 0.709929
# step 1690, cost 4475.28
# step 1690, change in cost 0.11084
# step 1700, training accuracy 0.709929
# step 1700, cost 4475.17
# step 1700, change in cost 0.108398
# step 1710, training accuracy 0.709929
# step 1710, cost 4475.06
# step 1710, change in cost 0.111328
# step 1720, training accuracy 0.709929
# step 1720, cost 4474.96
# step 1720, change in cost 0.105469
# step 1730, training accuracy 0.709929
# step 1730, cost 4474.85
# step 1730, change in cost 0.104492
# step 1740, training accuracy 0.709929
# step 1740, cost 4474.74
# step 1740, change in cost 0.105957
# step 1750, training accuracy 0.709993
# step 1750, cost 4474.64
# step 1750, change in cost 0.105957
# step 1760, training accuracy 0.709993
# step 1760, cost 4474.54
# step 1760, change in cost 0.103516
# step 1770, training accuracy 0.709929
# step 1770, cost 4474.43
# step 1770, change in cost 0.103516
# step 1780, training accuracy 0.709929
# step 1780, cost 4474.33
# step 1780, change in cost 0.102051
# step 1790, training accuracy 0.709929
# step 1790, cost 4474.23
# step 1790, change in cost 0.102051
# step 1800, training accuracy 0.709929
# step 1800, cost 4474.12
# step 1800, change in cost 0.102539
# step 1810, training accuracy 0.709929
# step 1810, cost 4474.02
# step 1810, change in cost 0.100586
# step 1820, training accuracy 0.709929
# step 1820, cost 4473.92
# step 1820, change in cost 0.100586
# step 1830, training accuracy 0.709929
# step 1830, cost 4473.82
# step 1830, change in cost 0.100586
# step 1840, training accuracy 0.709929
# step 1840, cost 4473.72
# step 1840, change in cost 0.100098
# step 1850, training accuracy 0.709929
# step 1850, cost 4473.62
# step 1850, change in cost 0.0996094
# step 1860, training accuracy 0.709929
# step 1860, cost 4473.52
# step 1860, change in cost 0.100098
# step 1870, training accuracy 0.709929
# step 1870, cost 4473.43
# step 1870, change in cost 0.0981445
# step 1880, training accuracy 0.710057
# step 1880, cost 4473.32
# step 1880, change in cost 0.101074
# step 1890, training accuracy 0.710057
# step 1890, cost 4473.23
# step 1890, change in cost 0.0957031
# step 1900, training accuracy 0.710057
# step 1900, cost 4473.13
# step 1900, change in cost 0.0996094
# step 1910, training accuracy 0.710122
# step 1910, cost 4473.03
# step 1910, change in cost 0.0986328
# step 1920, training accuracy 0.710122
# step 1920, cost 4472.93
# step 1920, change in cost 0.0976562
# step 1930, training accuracy 0.710122
# step 1930, cost 4472.83
# step 1930, change in cost 0.0981445
# step 1940, training accuracy 0.710122
# step 1940, cost 4472.74
# step 1940, change in cost 0.0976562
# step 1950, training accuracy 0.710122
# step 1950, cost 4472.64
# step 1950, change in cost 0.097168
# step 1960, training accuracy 0.710122
# step 1960, cost 4472.54
# step 1960, change in cost 0.0976562
# step 1970, training accuracy 0.710122
# step 1970, cost 4472.44
# step 1970, change in cost 0.0986328
# step 1980, training accuracy 0.710186
# step 1980, cost 4472.35
# step 1980, change in cost 0.0976562
# step 1990, training accuracy 0.710186
# step 1990, cost 4472.25
# step 1990, change in cost 0.097168
# step 2000, training accuracy 0.710186
# step 2000, cost 4472.15
# step 2000, change in cost 0.0976562
# step 2010, training accuracy 0.710186
# step 2010, cost 4472.06
# step 2010, change in cost 0.0957031
# step 2020, training accuracy 0.710186
# step 2020, cost 4471.96
# step 2020, change in cost 0.097168
# step 2030, training accuracy 0.710186
# step 2030, cost 4471.86
# step 2030, change in cost 0.0966797
# step 2040, training accuracy 0.710186
# step 2040, cost 4471.76
# step 2040, change in cost 0.0976562
# step 2050, training accuracy 0.710186
# step 2050, cost 4471.67
# step 2050, change in cost 0.0957031
# step 2060, training accuracy 0.710186
# step 2060, cost 4471.57
# step 2060, change in cost 0.0961914
# step 2070, training accuracy 0.710186
# step 2070, cost 4471.47
# step 2070, change in cost 0.0981445
# step 2080, training accuracy 0.710186
# step 2080, cost 4471.38
# step 2080, change in cost 0.0952148
# step 2090, training accuracy 0.710186
# step 2090, cost 4471.28
# step 2090, change in cost 0.0961914
# step 2100, training accuracy 0.710186
# step 2100, cost 4471.18
# step 2100, change in cost 0.0976562
# step 2110, training accuracy 0.710186
# step 2110, cost 4471.09
# step 2110, change in cost 0.0966797
# step 2120, training accuracy 0.710186
# step 2120, cost 4470.99
# step 2120, change in cost 0.0957031
# step 2130, training accuracy 0.710186
# step 2130, cost 4470.9
# step 2130, change in cost 0.0966797
# step 2140, training accuracy 0.710186
# step 2140, cost 4470.8
# step 2140, change in cost 0.0966797
# step 2150, training accuracy 0.710186
# step 2150, cost 4470.7
# step 2150, change in cost 0.0961914
# step 2160, training accuracy 0.710186
# step 2160, cost 4470.6
# step 2160, change in cost 0.0986328
# step 2170, training accuracy 0.710186
# step 2170, cost 4470.51
# step 2170, change in cost 0.097168
# step 2180, training accuracy 0.710186
# step 2180, cost 4470.41
# step 2180, change in cost 0.0957031
# step 2190, training accuracy 0.710186
# step 2190, cost 4470.31
# step 2190, change in cost 0.0986328
# step 2200, training accuracy 0.710186
# step 2200, cost 4470.22
# step 2200, change in cost 0.0966797
# step 2210, training accuracy 0.710186
# step 2210, cost 4470.12
# step 2210, change in cost 0.0981445
# step 2220, training accuracy 0.710186
# step 2220, cost 4470.02
# step 2220, change in cost 0.0981445
# step 2230, training accuracy 0.710186
# step 2230, cost 4469.92
# step 2230, change in cost 0.0976562
# step 2240, training accuracy 0.71025
# step 2240, cost 4469.82
# step 2240, change in cost 0.100586
# step 2250, training accuracy 0.71025
# step 2250, cost 4469.72
# step 2250, change in cost 0.0996094
# step 2260, training accuracy 0.71025
# step 2260, cost 4469.62
# step 2260, change in cost 0.0991211
# step 2270, training accuracy 0.71025
# step 2270, cost 4469.52
# step 2270, change in cost 0.101562
# step 2280, training accuracy 0.71025
# step 2280, cost 4469.42
# step 2280, change in cost 0.102051
# step 2290, training accuracy 0.71025
# step 2290, cost 4469.32
# step 2290, change in cost 0.0996094
# step 2300, training accuracy 0.710315
# step 2300, cost 4469.22
# step 2300, change in cost 0.102051
# step 2310, training accuracy 0.710315
# step 2310, cost 4469.12
# step 2310, change in cost 0.102051
# step 2320, training accuracy 0.710315
# step 2320, cost 4469.01
# step 2320, change in cost 0.102539
# step 2330, training accuracy 0.710315
# step 2330, cost 4468.91
# step 2330, change in cost 0.104492
# step 2340, training accuracy 0.710315
# step 2340, cost 4468.8
# step 2340, change in cost 0.104492
# step 2350, training accuracy 0.710315
# step 2350, cost 4468.7
# step 2350, change in cost 0.104492
# step 2360, training accuracy 0.710315
# step 2360, cost 4468.59
# step 2360, change in cost 0.106445
# step 2370, training accuracy 0.710315
# step 2370, cost 4468.49
# step 2370, change in cost 0.105469
# step 2380, training accuracy 0.710315
# step 2380, cost 4468.38
# step 2380, change in cost 0.107422
# step 2390, training accuracy 0.710315
# step 2390, cost 4468.27
# step 2390, change in cost 0.107422
# step 2400, training accuracy 0.710315
# step 2400, cost 4468.16
# step 2400, change in cost 0.108887
# step 2410, training accuracy 0.710315
# step 2410, cost 4468.05
# step 2410, change in cost 0.108887
# step 2420, training accuracy 0.710315
# step 2420, cost 4467.94
# step 2420, change in cost 0.110352
# step 2430, training accuracy 0.710315
# step 2430, cost 4467.83
# step 2430, change in cost 0.113281
# step 2440, training accuracy 0.710315
# step 2440, cost 4467.72
# step 2440, change in cost 0.112793
# step 2450, training accuracy 0.710315
# step 2450, cost 4467.6
# step 2450, change in cost 0.115723
# step 2460, training accuracy 0.710315
# step 2460, cost 4467.48
# step 2460, change in cost 0.119141
# step 2470, training accuracy 0.710315
# step 2470, cost 4467.36
# step 2470, change in cost 0.120605
# step 2480, training accuracy 0.710315
# step 2480, cost 4467.24
# step 2480, change in cost 0.122559
# step 2490, training accuracy 0.710315
# step 2490, cost 4467.11
# step 2490, change in cost 0.12793
# step 2500, training accuracy 0.710315
# step 2500, cost 4466.98
# step 2500, change in cost 0.131836
# step 2510, training accuracy 0.710315
# step 2510, cost 4466.85
# step 2510, change in cost 0.134277
# step 2520, training accuracy 0.710315
# step 2520, cost 4466.71
# step 2520, change in cost 0.140137
# step 2530, training accuracy 0.710315
# step 2530, cost 4466.56
# step 2530, change in cost 0.141113
# step 2540, training accuracy 0.710315
# step 2540, cost 4466.42
# step 2540, change in cost 0.144043
# step 2550, training accuracy 0.710315
# step 2550, cost 4466.28
# step 2550, change in cost 0.145508
# step 2560, training accuracy 0.710315
# step 2560, cost 4466.13
# step 2560, change in cost 0.144043
# step 2570, training accuracy 0.710315
# step 2570, cost 4465.99
# step 2570, change in cost 0.143555
# step 2580, training accuracy 0.710315
# step 2580, cost 4465.85
# step 2580, change in cost 0.138672
# step 2590, training accuracy 0.710315
# step 2590, cost 4465.71
# step 2590, change in cost 0.135254
# step 2600, training accuracy 0.710315
# step 2600, cost 4465.59
# step 2600, change in cost 0.12793
# step 2610, training accuracy 0.710315
# step 2610, cost 4465.46
# step 2610, change in cost 0.124023
# step 2620, training accuracy 0.710379
# step 2620, cost 4465.34
# step 2620, change in cost 0.118164
# step 2630, training accuracy 0.710379
# step 2630, cost 4465.23
# step 2630, change in cost 0.111328
# step 2640, training accuracy 0.710379
# step 2640, cost 4465.12
# step 2640, change in cost 0.110352
# step 2650, training accuracy 0.710379
# step 2650, cost 4465.02
# step 2650, change in cost 0.103516
# step 2660, training accuracy 0.710379
# step 2660, cost 4464.92
# step 2660, change in cost 0.102539
# step 2670, training accuracy 0.710379
# step 2670, cost 4464.82
# step 2670, change in cost 0.0976562
# step 2680, training accuracy 0.710379
# step 2680, cost 4464.72
# step 2680, change in cost 0.097168
# step 2690, training accuracy 0.710379
# step 2690, cost 4464.63
# step 2690, change in cost 0.0922852
# step 2700, training accuracy 0.710379
# step 2700, cost 4464.54
# step 2700, change in cost 0.0908203
# step 2710, training accuracy 0.710379
# step 2710, cost 4464.45
# step 2710, change in cost 0.0898438
# step 2720, training accuracy 0.710379
# step 2720, cost 4464.36
# step 2720, change in cost 0.0859375
# step 2730, training accuracy 0.710379
# step 2730, cost 4464.28
# step 2730, change in cost 0.0869141
# step 2740, training accuracy 0.710379
# step 2740, cost 4464.19
# step 2740, change in cost 0.0878906
# step 2750, training accuracy 0.710379
# step 2750, cost 4464.1
# step 2750, change in cost 0.0839844
# step 2760, training accuracy 0.710379
# step 2760, cost 4464.02
# step 2760, change in cost 0.0849609
# step 2770, training accuracy 0.710379
# step 2770, cost 4463.94
# step 2770, change in cost 0.0834961
# step 2780, training accuracy 0.710379
# step 2780, cost 4463.85
# step 2780, change in cost 0.0834961
# step 2790, training accuracy 0.710379
# step 2790, cost 4463.77
# step 2790, change in cost 0.0839844
# step 2800, training accuracy 0.710379
# step 2800, cost 4463.69
# step 2800, change in cost 0.0820312
# step 2810, training accuracy 0.710379
# step 2810, cost 4463.6
# step 2810, change in cost 0.0849609
# step 2820, training accuracy 0.710379
# step 2820, cost 4463.52
# step 2820, change in cost 0.0839844
# step 2830, training accuracy 0.710379
# step 2830, cost 4463.43
# step 2830, change in cost 0.0834961
# step 2840, training accuracy 0.710379
# step 2840, cost 4463.35
# step 2840, change in cost 0.0825195
# step 2850, training accuracy 0.710379
# step 2850, cost 4463.26
# step 2850, change in cost 0.0859375
# step 2860, training accuracy 0.710379
# step 2860, cost 4463.18
# step 2860, change in cost 0.0830078
# step 2870, training accuracy 0.710379
# step 2870, cost 4463.1
# step 2870, change in cost 0.0854492
# step 2880, training accuracy 0.710379
# step 2880, cost 4463.01
# step 2880, change in cost 0.0849609
# step 2890, training accuracy 0.710379
# step 2890, cost 4462.92
# step 2890, change in cost 0.0874023
# step 2900, training accuracy 0.710379
# step 2900, cost 4462.84
# step 2900, change in cost 0.0864258
# step 2910, training accuracy 0.710379
# step 2910, cost 4462.75
# step 2910, change in cost 0.0859375
# step 2920, training accuracy 0.710379
# step 2920, cost 4462.66
# step 2920, change in cost 0.0874023
# step 2930, training accuracy 0.710379
# step 2930, cost 4462.58
# step 2930, change in cost 0.0869141
# step 2940, training accuracy 0.710379
# step 2940, cost 4462.49
# step 2940, change in cost 0.0849609
# step 2950, training accuracy 0.710379
# step 2950, cost 4462.41
# step 2950, change in cost 0.0859375
# step 2960, training accuracy 0.710379
# step 2960, cost 4462.32
# step 2960, change in cost 0.0854492
# step 2970, training accuracy 0.710379
# step 2970, cost 4462.24
# step 2970, change in cost 0.0854492
# step 2980, training accuracy 0.710379
# step 2980, cost 4462.15
# step 2980, change in cost 0.0820312
# step 2990, training accuracy 0.710379
# step 2990, cost 4462.07
# step 2990, change in cost 0.0810547
# step 3000, training accuracy 0.710379
# step 3000, cost 4461.99
# step 3000, change in cost 0.0810547
# step 3010, training accuracy 0.710379
# step 3010, cost 4461.91
# step 3010, change in cost 0.0800781
# step 3020, training accuracy 0.710443
# step 3020, cost 4461.83
# step 3020, change in cost 0.0791016
# step 3030, training accuracy 0.710443
# step 3030, cost 4461.76
# step 3030, change in cost 0.0766602
# step 3040, training accuracy 0.710443
# step 3040, cost 4461.68
# step 3040, change in cost 0.0756836
# step 3050, training accuracy 0.710443
# step 3050, cost 4461.6
# step 3050, change in cost 0.074707
# step 3060, training accuracy 0.710443
# step 3060, cost 4461.53
# step 3060, change in cost 0.0756836
# step 3070, training accuracy 0.710443
# step 3070, cost 4461.46
# step 3070, change in cost 0.0722656
# step 3080, training accuracy 0.710443
# step 3080, cost 4461.38
# step 3080, change in cost 0.0722656
# step 3090, training accuracy 0.710443
# step 3090, cost 4461.31
# step 3090, change in cost 0.0712891
# step 3100, training accuracy 0.710443
# step 3100, cost 4461.24
# step 3100, change in cost 0.0712891
# step 3110, training accuracy 0.710443
# step 3110, cost 4461.17
# step 3110, change in cost 0.0703125
# step 3120, training accuracy 0.710443
# step 3120, cost 4461.1
# step 3120, change in cost 0.0693359
# step 3130, training accuracy 0.710443
# step 3130, cost 4461.03
# step 3130, change in cost 0.0683594
# step 3140, training accuracy 0.710443
# step 3140, cost 4460.97
# step 3140, change in cost 0.0688477
# step 3150, training accuracy 0.710443
# step 3150, cost 4460.9
# step 3150, change in cost 0.0678711
# step 3160, training accuracy 0.710508
# step 3160, cost 4460.83
# step 3160, change in cost 0.0678711
# step 3170, training accuracy 0.710508
# step 3170, cost 4460.76
# step 3170, change in cost 0.0668945
# step 3180, training accuracy 0.710508
# step 3180, cost 4460.7
# step 3180, change in cost 0.0664062
# step 3190, training accuracy 0.710508
# step 3190, cost 4460.63
# step 3190, change in cost 0.0664062
# step 3200, training accuracy 0.710508
# step 3200, cost 4460.56
# step 3200, change in cost 0.0668945
# step 3210, training accuracy 0.710508
# step 3210, cost 4460.5
# step 3210, change in cost 0.0649414
# step 3220, training accuracy 0.710508
# step 3220, cost 4460.43
# step 3220, change in cost 0.0654297
# step 3230, training accuracy 0.710508
# step 3230, cost 4460.37
# step 3230, change in cost 0.0654297
# step 3240, training accuracy 0.710508
# step 3240, cost 4460.3
# step 3240, change in cost 0.0649414
# step 3250, training accuracy 0.710508
# step 3250, cost 4460.24
# step 3250, change in cost 0.0668945
# step 3260, training accuracy 0.710508
# step 3260, cost 4460.17
# step 3260, change in cost 0.0644531
# step 3270, training accuracy 0.710508
# step 3270, cost 4460.11
# step 3270, change in cost 0.0644531
# step 3280, training accuracy 0.710508
# step 3280, cost 4460.04
# step 3280, change in cost 0.0654297
# step 3290, training accuracy 0.710508
# step 3290, cost 4459.98
# step 3290, change in cost 0.0644531
# step 3300, training accuracy 0.710508
# step 3300, cost 4459.91
# step 3300, change in cost 0.0644531
# step 3310, training accuracy 0.710508
# step 3310, cost 4459.85
# step 3310, change in cost 0.0625
# step 3320, training accuracy 0.710508
# step 3320, cost 4459.78
# step 3320, change in cost 0.0664062
# step 3330, training accuracy 0.710508
# step 3330, cost 4459.72
# step 3330, change in cost 0.0639648
# step 3340, training accuracy 0.710508
# step 3340, cost 4459.65
# step 3340, change in cost 0.0654297
# step 3350, training accuracy 0.710508
# step 3350, cost 4459.59
# step 3350, change in cost 0.0649414
# step 3360, training accuracy 0.710508
# step 3360, cost 4459.52
# step 3360, change in cost 0.0654297
# step 3370, training accuracy 0.710508
# step 3370, cost 4459.46
# step 3370, change in cost 0.0639648
# step 3380, training accuracy 0.710508
# step 3380, cost 4459.4
# step 3380, change in cost 0.0629883
# step 3390, training accuracy 0.710508
# step 3390, cost 4459.33
# step 3390, change in cost 0.065918
# step 3400, training accuracy 0.710508
# step 3400, cost 4459.26
# step 3400, change in cost 0.065918
# step 3410, training accuracy 0.710508
# step 3410, cost 4459.2
# step 3410, change in cost 0.0649414
# step 3420, training accuracy 0.710508
# step 3420, cost 4459.13
# step 3420, change in cost 0.0649414
# step 3430, training accuracy 0.710508
# step 3430, cost 4459.07
# step 3430, change in cost 0.0654297
# step 3440, training accuracy 0.710508
# step 3440, cost 4459
# step 3440, change in cost 0.0649414
# step 3450, training accuracy 0.710508
# step 3450, cost 4458.94
# step 3450, change in cost 0.0644531
# step 3460, training accuracy 0.710508
# step 3460, cost 4458.87
# step 3460, change in cost 0.065918
# step 3470, training accuracy 0.710508
# step 3470, cost 4458.81
# step 3470, change in cost 0.065918
# step 3480, training accuracy 0.710508
# step 3480, cost 4458.74
# step 3480, change in cost 0.0649414
# step 3490, training accuracy 0.710508
# step 3490, cost 4458.68
# step 3490, change in cost 0.0664062
# step 3500, training accuracy 0.710508
# step 3500, cost 4458.61
# step 3500, change in cost 0.0654297
# step 3510, training accuracy 0.710508
# step 3510, cost 4458.54
# step 3510, change in cost 0.0673828
# step 3520, training accuracy 0.710508
# step 3520, cost 4458.48
# step 3520, change in cost 0.0654297
# step 3530, training accuracy 0.710508
# step 3530, cost 4458.41
# step 3530, change in cost 0.0668945
# step 3540, training accuracy 0.710508
# step 3540, cost 4458.35
# step 3540, change in cost 0.0664062
# step 3550, training accuracy 0.710508
# step 3550, cost 4458.28
# step 3550, change in cost 0.0683594
# step 3560, training accuracy 0.710508
# step 3560, cost 4458.21
# step 3560, change in cost 0.0673828
# step 3570, training accuracy 0.710508
# step 3570, cost 4458.14
# step 3570, change in cost 0.0678711
# step 3580, training accuracy 0.710508
# step 3580, cost 4458.08
# step 3580, change in cost 0.0664062
# step 3590, training accuracy 0.710508
# step 3590, cost 4458.01
# step 3590, change in cost 0.0693359
# step 3600, training accuracy 0.710508
# step 3600, cost 4457.94
# step 3600, change in cost 0.0683594
# step 3610, training accuracy 0.710508
# step 3610, cost 4457.87
# step 3610, change in cost 0.0683594
# step 3620, training accuracy 0.710508
# step 3620, cost 4457.8
# step 3620, change in cost 0.0688477
# step 3630, training accuracy 0.710508
# step 3630, cost 4457.73
# step 3630, change in cost 0.0708008
# step 3640, training accuracy 0.710508
# step 3640, cost 4457.66
# step 3640, change in cost 0.0683594
# step 3650, training accuracy 0.710508
# step 3650, cost 4457.59
# step 3650, change in cost 0.0683594
# step 3660, training accuracy 0.710508
# step 3660, cost 4457.52
# step 3660, change in cost 0.0722656
# step 3670, training accuracy 0.710508
# step 3670, cost 4457.45
# step 3670, change in cost 0.0693359
# step 3680, training accuracy 0.710508
# step 3680, cost 4457.38
# step 3680, change in cost 0.0712891
# step 3690, training accuracy 0.710508
# step 3690, cost 4457.31
# step 3690, change in cost 0.0703125
# step 3700, training accuracy 0.710508
# step 3700, cost 4457.24
# step 3700, change in cost 0.0722656
# step 3710, training accuracy 0.710508
# step 3710, cost 4457.16
# step 3710, change in cost 0.0727539
# step 3720, training accuracy 0.710508
# step 3720, cost 4457.09
# step 3720, change in cost 0.0722656
# step 3730, training accuracy 0.710572
# step 3730, cost 4457.02
# step 3730, change in cost 0.0717773
# step 3740, training accuracy 0.710572
# step 3740, cost 4456.95
# step 3740, change in cost 0.0717773
# step 3750, training accuracy 0.710572
# step 3750, cost 4456.88
# step 3750, change in cost 0.0737305
# step 3760, training accuracy 0.710572
# step 3760, cost 4456.8
# step 3760, change in cost 0.0722656
# step 3770, training accuracy 0.710572
# step 3770, cost 4456.73
# step 3770, change in cost 0.0722656
# step 3780, training accuracy 0.710572
# step 3780, cost 4456.66
# step 3780, change in cost 0.0722656
# step 3790, training accuracy 0.710572
# step 3790, cost 4456.59
# step 3790, change in cost 0.0727539
# step 3800, training accuracy 0.710572
# step 3800, cost 4456.51
# step 3800, change in cost 0.0737305
# step 3810, training accuracy 0.710572
# step 3810, cost 4456.44
# step 3810, change in cost 0.0732422
# step 3820, training accuracy 0.710572
# step 3820, cost 4456.36
# step 3820, change in cost 0.0751953
# step 3830, training accuracy 0.710572
# step 3830, cost 4456.29
# step 3830, change in cost 0.0732422
# step 3840, training accuracy 0.710572
# step 3840, cost 4456.21
# step 3840, change in cost 0.0751953
# step 3850, training accuracy 0.710572
# step 3850, cost 4456.14
# step 3850, change in cost 0.0742188
# step 3860, training accuracy 0.710572
# step 3860, cost 4456.07
# step 3860, change in cost 0.0732422
# step 3870, training accuracy 0.710572
# step 3870, cost 4455.99
# step 3870, change in cost 0.0732422
# step 3880, training accuracy 0.710572
# step 3880, cost 4455.92
# step 3880, change in cost 0.0742188
# step 3890, training accuracy 0.710572
# step 3890, cost 4455.84
# step 3890, change in cost 0.0751953
# step 3900, training accuracy 0.710572
# step 3900, cost 4455.77
# step 3900, change in cost 0.074707
# step 3910, training accuracy 0.710572
# step 3910, cost 4455.7
# step 3910, change in cost 0.0727539
# step 3920, training accuracy 0.710572
# step 3920, cost 4455.62
# step 3920, change in cost 0.0742188
# step 3930, training accuracy 0.710572
# step 3930, cost 4455.55
# step 3930, change in cost 0.0737305
# step 3940, training accuracy 0.710572
# step 3940, cost 4455.48
# step 3940, change in cost 0.0732422
# step 3950, training accuracy 0.710572
# step 3950, cost 4455.4
# step 3950, change in cost 0.0727539
# step 3960, training accuracy 0.710572
# step 3960, cost 4455.33
# step 3960, change in cost 0.074707
# step 3970, training accuracy 0.710572
# step 3970, cost 4455.26
# step 3970, change in cost 0.0717773
# step 3980, training accuracy 0.710572
# step 3980, cost 4455.18
# step 3980, change in cost 0.0722656
# step 3990, training accuracy 0.710572
# step 3990, cost 4455.11
# step 3990, change in cost 0.0722656
# step 4000, training accuracy 0.710572
# step 4000, cost 4455.04
# step 4000, change in cost 0.0727539
# step 4010, training accuracy 0.710572
# step 4010, cost 4454.97
# step 4010, change in cost 0.0717773
# step 4020, training accuracy 0.710572
# step 4020, cost 4454.9
# step 4020, change in cost 0.0722656
# step 4030, training accuracy 0.710508
# step 4030, cost 4454.83
# step 4030, change in cost 0.0703125
# step 4040, training accuracy 0.710508
# step 4040, cost 4454.75
# step 4040, change in cost 0.0732422
# step 4050, training accuracy 0.710508
# step 4050, cost 4454.68
# step 4050, change in cost 0.0712891
# step 4060, training accuracy 0.710508
# step 4060, cost 4454.61
# step 4060, change in cost 0.0722656
# step 4070, training accuracy 0.710572
# step 4070, cost 4454.54
# step 4070, change in cost 0.0703125
# step 4080, training accuracy 0.710572
# step 4080, cost 4454.47
# step 4080, change in cost 0.0722656
# step 4090, training accuracy 0.710572
# step 4090, cost 4454.39
# step 4090, change in cost 0.0712891
# step 4100, training accuracy 0.710572
# step 4100, cost 4454.32
# step 4100, change in cost 0.0732422
# step 4110, training accuracy 0.710572
# step 4110, cost 4454.25
# step 4110, change in cost 0.0703125
# step 4120, training accuracy 0.710636
# step 4120, cost 4454.18
# step 4120, change in cost 0.0708008
# step 4130, training accuracy 0.710636
# step 4130, cost 4454.11
# step 4130, change in cost 0.0708008
# step 4140, training accuracy 0.710636
# step 4140, cost 4454.04
# step 4140, change in cost 0.0722656
# step 4150, training accuracy 0.710636
# step 4150, cost 4453.97
# step 4150, change in cost 0.0708008
# step 4160, training accuracy 0.710636
# step 4160, cost 4453.9
# step 4160, change in cost 0.0712891
# step 4170, training accuracy 0.710636
# step 4170, cost 4453.82
# step 4170, change in cost 0.0717773
# step 4180, training accuracy 0.710636
# step 4180, cost 4453.75
# step 4180, change in cost 0.0712891
# step 4190, training accuracy 0.710636
# step 4190, cost 4453.68
# step 4190, change in cost 0.0712891
# step 4200, training accuracy 0.710636
# step 4200, cost 4453.61
# step 4200, change in cost 0.0722656
# step 4210, training accuracy 0.710636
# step 4210, cost 4453.54
# step 4210, change in cost 0.0722656
# step 4220, training accuracy 0.710636
# step 4220, cost 4453.46
# step 4220, change in cost 0.0751953
# step 4230, training accuracy 0.710636
# step 4230, cost 4453.39
# step 4230, change in cost 0.0737305
# step 4240, training accuracy 0.710636
# step 4240, cost 4453.31
# step 4240, change in cost 0.0761719
# step 4250, training accuracy 0.710636
# step 4250, cost 4453.23
# step 4250, change in cost 0.0776367
# step 4260, training accuracy 0.710636
# step 4260, cost 4453.15
# step 4260, change in cost 0.081543
# step 4270, training accuracy 0.710636
# step 4270, cost 4453.07
# step 4270, change in cost 0.0849609
# step 4280, training accuracy 0.710636
# step 4280, cost 4452.97
# step 4280, change in cost 0.0922852
# step 4290, training accuracy 0.710636
# step 4290, cost 4452.87
# step 4290, change in cost 0.100586
# step 4300, training accuracy 0.710636
# step 4300, cost 4452.76
# step 4300, change in cost 0.113281
# step 4310, training accuracy 0.710636
# step 4310, cost 4452.63
# step 4310, change in cost 0.126953
# step 4320, training accuracy 0.710636
# step 4320, cost 4452.5
# step 4320, change in cost 0.133789
# step 4330, training accuracy 0.710636
# step 4330, cost 4452.37
# step 4330, change in cost 0.130859
# step 4340, training accuracy 0.710701
# step 4340, cost 4452.25
# step 4340, change in cost 0.119141
# step 4350, training accuracy 0.710701
# step 4350, cost 4452.14
# step 4350, change in cost 0.109375
# step 4360, training accuracy 0.710701
# step 4360, cost 4452.04
# step 4360, change in cost 0.0996094
# step 4370, training accuracy 0.710701
# step 4370, cost 4451.95
# step 4370, change in cost 0.0957031
# step 4380, training accuracy 0.710701
# step 4380, cost 4451.85
# step 4380, change in cost 0.0908203
# step 4390, training accuracy 0.710701
# step 4390, cost 4451.77
# step 4390, change in cost 0.0883789
# step 4400, training accuracy 0.710701
# step 4400, cost 4451.68
# step 4400, change in cost 0.0888672
# step 4410, training accuracy 0.710701
# step 4410, cost 4451.59
# step 4410, change in cost 0.0849609
# step 4420, training accuracy 0.710701
# step 4420, cost 4451.51
# step 4420, change in cost 0.0854492
# step 4430, training accuracy 0.710701
# step 4430, cost 4451.42
# step 4430, change in cost 0.0854492
# step 4440, training accuracy 0.710701
# step 4440, cost 4451.34
# step 4440, change in cost 0.0854492
# step 4450, training accuracy 0.710701
# step 4450, cost 4451.25
# step 4450, change in cost 0.0834961
# step 4460, training accuracy 0.710701
# step 4460, cost 4451.17
# step 4460, change in cost 0.0849609
# step 4470, training accuracy 0.710701
# step 4470, cost 4451.08
# step 4470, change in cost 0.0844727
# step 4480, training accuracy 0.710701
# step 4480, cost 4451
# step 4480, change in cost 0.0830078
# step 4490, training accuracy 0.710701
# step 4490, cost 4450.92
# step 4490, change in cost 0.0839844
# step 4500, training accuracy 0.710701
# step 4500, cost 4450.83
# step 4500, change in cost 0.0830078
# step 4510, training accuracy 0.710701
# step 4510, cost 4450.75
# step 4510, change in cost 0.0830078
# step 4520, training accuracy 0.710701
# step 4520, cost 4450.67
# step 4520, change in cost 0.0839844
# step 4530, training accuracy 0.710701
# step 4530, cost 4450.58
# step 4530, change in cost 0.0830078
# step 4540, training accuracy 0.710701
# step 4540, cost 4450.5
# step 4540, change in cost 0.0839844
# step 4550, training accuracy 0.710701
# step 4550, cost 4450.42
# step 4550, change in cost 0.0830078
# step 4560, training accuracy 0.710701
# step 4560, cost 4450.33
# step 4560, change in cost 0.0820312
# step 4570, training accuracy 0.710701
# step 4570, cost 4450.25
# step 4570, change in cost 0.0844727
# step 4580, training accuracy 0.710701
# step 4580, cost 4450.17
# step 4580, change in cost 0.0844727
# step 4590, training accuracy 0.710701
# step 4590, cost 4450.08
# step 4590, change in cost 0.0830078
# step 4600, training accuracy 0.710701
# step 4600, cost 4450
# step 4600, change in cost 0.0825195
# step 4610, training accuracy 0.710701
# step 4610, cost 4449.91
# step 4610, change in cost 0.0854492
# step 4620, training accuracy 0.710701
# step 4620, cost 4449.83
# step 4620, change in cost 0.0830078
# step 4630, training accuracy 0.710701
# step 4630, cost 4449.75
# step 4630, change in cost 0.0849609
# step 4640, training accuracy 0.710701
# step 4640, cost 4449.66
# step 4640, change in cost 0.0839844
# step 4650, training accuracy 0.710701
# step 4650, cost 4449.58
# step 4650, change in cost 0.0830078
# step 4660, training accuracy 0.710701
# step 4660, cost 4449.5
# step 4660, change in cost 0.0830078
# step 4670, training accuracy 0.710701
# step 4670, cost 4449.41
# step 4670, change in cost 0.0839844
# step 4680, training accuracy 0.710701
# step 4680, cost 4449.33
# step 4680, change in cost 0.0834961
# step 4690, training accuracy 0.710701
# step 4690, cost 4449.25
# step 4690, change in cost 0.081543
# step 4700, training accuracy 0.710701
# step 4700, cost 4449.16
# step 4700, change in cost 0.0825195
# step 4710, training accuracy 0.710701
# step 4710, cost 4449.08
# step 4710, change in cost 0.081543
# step 4720, training accuracy 0.710701
# step 4720, cost 4449
# step 4720, change in cost 0.0791016
# step 4730, training accuracy 0.710701
# step 4730, cost 4448.92
# step 4730, change in cost 0.0795898
# step 4740, training accuracy 0.710701
# step 4740, cost 4448.85
# step 4740, change in cost 0.0776367
# step 4750, training accuracy 0.710701
# step 4750, cost 4448.77
# step 4750, change in cost 0.0771484
# step 4760, training accuracy 0.710701
# step 4760, cost 4448.69
# step 4760, change in cost 0.0771484
# step 4770, training accuracy 0.710701
# step 4770, cost 4448.61
# step 4770, change in cost 0.0776367
# step 4780, training accuracy 0.710701
# step 4780, cost 4448.54
# step 4780, change in cost 0.0751953
# step 4790, training accuracy 0.710701
# step 4790, cost 4448.46
# step 4790, change in cost 0.0756836
# step 4800, training accuracy 0.710701
# step 4800, cost 4448.39
# step 4800, change in cost 0.0742188
# step 4810, training accuracy 0.710701
# step 4810, cost 4448.32
# step 4810, change in cost 0.0732422
# step 4820, training accuracy 0.710701
# step 4820, cost 4448.24
# step 4820, change in cost 0.0742188
# step 4830, training accuracy 0.710701
# step 4830, cost 4448.17
# step 4830, change in cost 0.0751953
# step 4840, training accuracy 0.710701
# step 4840, cost 4448.09
# step 4840, change in cost 0.0732422
# step 4850, training accuracy 0.710701
# step 4850, cost 4448.02
# step 4850, change in cost 0.0722656
# step 4860, training accuracy 0.710701
# step 4860, cost 4447.95
# step 4860, change in cost 0.0727539
# step 4870, training accuracy 0.710701
# step 4870, cost 4447.88
# step 4870, change in cost 0.0722656
# step 4880, training accuracy 0.710701
# step 4880, cost 4447.8
# step 4880, change in cost 0.0727539
# step 4890, training accuracy 0.710701
# step 4890, cost 4447.73
# step 4890, change in cost 0.0712891
# step 4900, training accuracy 0.710701
# step 4900, cost 4447.66
# step 4900, change in cost 0.0742188
# step 4910, training accuracy 0.710701
# step 4910, cost 4447.59
# step 4910, change in cost 0.0712891
# step 4920, training accuracy 0.710701
# step 4920, cost 4447.51
# step 4920, change in cost 0.0737305
# step 4930, training accuracy 0.710701
# step 4930, cost 4447.44
# step 4930, change in cost 0.0717773
# step 4940, training accuracy 0.710636
# step 4940, cost 4447.37
# step 4940, change in cost 0.0737305
# step 4950, training accuracy 0.710636
# step 4950, cost 4447.29
# step 4950, change in cost 0.0751953
# step 4960, training accuracy 0.710636
# step 4960, cost 4447.22
# ...
# step 18400, training accuracy 0.715205
# step 18400, cost 4201.38
# step 18400, change in cost 0.226562
# step 18410, training accuracy 0.715205
# step 18410, cost 4201.16
# step 18410, change in cost 0.223633
# step 18420, training accuracy 0.715205
# step 18420, cost 4200.93
# step 18420, change in cost 0.228516
# step 18430, training accuracy 0.715205
# step 18430, cost 4200.7
# step 18430, change in cost 0.227051
# step 18440, training accuracy 0.715205
# step 18440, cost 4200.47
# step 18440, change in cost 0.227051
# step 18450, training accuracy 0.715205
# step 18450, cost 4200.24
# step 18450, change in cost 0.231445
# step 18460, training accuracy 0.715205
# step 18460, cost 4200.01
# step 18460, change in cost 0.232422
# step 18470, training accuracy 0.715205
# step 18470, cost 4199.78
# step 18470, change in cost 0.233398
# step 18480, training accuracy 0.715205
# step 18480, cost 4199.54
# step 18480, change in cost 0.23584
# step 18490, training accuracy 0.715205
# step 18490, cost 4199.3
# step 18490, change in cost 0.236816
# step 18500, training accuracy 0.715205
# step 18500, cost 4199.07
# step 18500, change in cost 0.236328
# step 18510, training accuracy 0.715205
# step 18510, cost 4198.83
# step 18510, change in cost 0.237305
# step 18520, training accuracy 0.715205
# step 18520, cost 4198.59
# step 18520, change in cost 0.238281
# step 18530, training accuracy 0.715205
# step 18530, cost 4198.36
# step 18530, change in cost 0.234375
# step 18540, training accuracy 0.715205
# step 18540, cost 4198.12
# step 18540, change in cost 0.236816
# step 18550, training accuracy 0.715205
# step 18550, cost 4197.89
# step 18550, change in cost 0.23584
# step 18560, training accuracy 0.715141
# step 18560, cost 4197.65
# step 18560, change in cost 0.231934
# step 18570, training accuracy 0.715141
# step 18570, cost 4197.42
# step 18570, change in cost 0.231445
# step 18580, training accuracy 0.715141
# step 18580, cost 4197.19
# step 18580, change in cost 0.23291
# step 18590, training accuracy 0.715141
# step 18590, cost 4196.96
# step 18590, change in cost 0.22998
# step 18600, training accuracy 0.715141
# step 18600, cost 4196.73
# step 18600, change in cost 0.225098
# step 18610, training accuracy 0.715141
# step 18610, cost 4196.51
# step 18610, change in cost 0.229004
# step 18620, training accuracy 0.715141
# step 18620, cost 4196.28
# step 18620, change in cost 0.227051
# step 18630, training accuracy 0.715141
# step 18630, cost 4196.05
# step 18630, change in cost 0.223633
# step 18640, training accuracy 0.715141
# step 18640, cost 4195.83
# step 18640, change in cost 0.226074
# step 18650, training accuracy 0.715205
# step 18650, cost 4195.61
# step 18650, change in cost 0.223145
# step 18660, training accuracy 0.715205
# step 18660, cost 4195.38
# step 18660, change in cost 0.221191
# step 18670, training accuracy 0.715205
# step 18670, cost 4195.16
# step 18670, change in cost 0.219727
# step 18680, training accuracy 0.715205
# step 18680, cost 4194.94
# step 18680, change in cost 0.222656
# step 18690, training accuracy 0.715205
# step 18690, cost 4194.72
# step 18690, change in cost 0.217285
# step 18700, training accuracy 0.715205
# step 18700, cost 4194.51
# step 18700, change in cost 0.216797
# step 18710, training accuracy 0.715205
# step 18710, cost 4194.29
# step 18710, change in cost 0.212891
# step 18720, training accuracy 0.715141
# step 18720, cost 4194.08
# step 18720, change in cost 0.212891
# step 18730, training accuracy 0.715141
# step 18730, cost 4193.87
# step 18730, change in cost 0.210449
# step 18740, training accuracy 0.715141
# step 18740, cost 4193.66
# step 18740, change in cost 0.20752
# step 18750, training accuracy 0.715141
# step 18750, cost 4193.46
# step 18750, change in cost 0.208008
# step 18760, training accuracy 0.715141
# step 18760, cost 4193.25
# step 18760, change in cost 0.203125
# step 18770, training accuracy 0.715141
# step 18770, cost 4193.05
# step 18770, change in cost 0.202148
# step 18780, training accuracy 0.715141
# step 18780, cost 4192.85
# step 18780, change in cost 0.201172
# step 18790, training accuracy 0.715141
# step 18790, cost 4192.65
# step 18790, change in cost 0.199219
# step 18800, training accuracy 0.715141
# step 18800, cost 4192.45
# step 18800, change in cost 0.197266
# step 18810, training accuracy 0.715141
# step 18810, cost 4192.25
# step 18810, change in cost 0.198242
# step 18820, training accuracy 0.715141
# step 18820, cost 4192.06
# step 18820, change in cost 0.192871
# step 18830, training accuracy 0.715141
# step 18830, cost 4191.87
# step 18830, change in cost 0.194824
# step 18840, training accuracy 0.715141
# step 18840, cost 4191.68
# step 18840, change in cost 0.191406
# step 18850, training accuracy 0.715141
# step 18850, cost 4191.48
# step 18850, change in cost 0.193359
# step 18860, training accuracy 0.715141
# step 18860, cost 4191.29
# step 18860, change in cost 0.192383
# step 18870, training accuracy 0.715141
# step 18870, cost 4191.1
# step 18870, change in cost 0.187988
# step 18880, training accuracy 0.715141
# step 18880, cost 4190.91
# step 18880, change in cost 0.189453
# step 18890, training accuracy 0.715141
# step 18890, cost 4190.72
# step 18890, change in cost 0.190918
# step 18900, training accuracy 0.715141
# step 18900, cost 4190.54
# step 18900, change in cost 0.185547
# step 18910, training accuracy 0.715205
# step 18910, cost 4190.35
# step 18910, change in cost 0.1875
# step 18920, training accuracy 0.715205
# step 18920, cost 4190.16
# step 18920, change in cost 0.188477
# step 18930, training accuracy 0.715205
# step 18930, cost 4189.98
# step 18930, change in cost 0.18457
# step 18940, training accuracy 0.715205
# step 18940, cost 4189.79
# step 18940, change in cost 0.186523
# step 18950, training accuracy 0.715205
# step 18950, cost 4189.6
# step 18950, change in cost 0.1875
# step 18960, training accuracy 0.715205
# step 18960, cost 4189.42
# step 18960, change in cost 0.186523
# step 18970, training accuracy 0.715205
# step 18970, cost 4189.23
# step 18970, change in cost 0.183105
# step 18980, training accuracy 0.715205
# step 18980, cost 4189.04
# step 18980, change in cost 0.187012
# step 18990, training accuracy 0.715269
# step 18990, cost 4188.86
# step 18990, change in cost 0.185547
# step 19000, training accuracy 0.715269
# step 19000, cost 4188.67
# step 19000, change in cost 0.188477
# step 19010, training accuracy 0.715269
# step 19010, cost 4188.49
# step 19010, change in cost 0.183594
# step 19020, training accuracy 0.715269
# step 19020, cost 4188.3
# step 19020, change in cost 0.189453
# step 19030, training accuracy 0.715269
# step 19030, cost 4188.11
# step 19030, change in cost 0.1875
# step 19040, training accuracy 0.715269
# step 19040, cost 4187.92
# step 19040, change in cost 0.192383
# step 19050, training accuracy 0.715269
# step 19050, cost 4187.73
# step 19050, change in cost 0.190918
# step 19060, training accuracy 0.715269
# step 19060, cost 4187.53
# step 19060, change in cost 0.194824
# step 19070, training accuracy 0.715269
# step 19070, cost 4187.34
# step 19070, change in cost 0.194824
# step 19080, training accuracy 0.715334
# step 19080, cost 4187.14
# step 19080, change in cost 0.201172
# step 19090, training accuracy 0.715269
# step 19090, cost 4186.93
# step 19090, change in cost 0.205566
# step 19100, training accuracy 0.715269
# step 19100, cost 4186.72
# step 19100, change in cost 0.206543
# step 19110, training accuracy 0.715269
# step 19110, cost 4186.51
# step 19110, change in cost 0.213379
# step 19120, training accuracy 0.715334
# step 19120, cost 4186.29
# step 19120, change in cost 0.216309
# step 19130, training accuracy 0.715334
# step 19130, cost 4186.07
# step 19130, change in cost 0.220215
# step 19140, training accuracy 0.715334
# step 19140, cost 4185.85
# step 19140, change in cost 0.220703
# step 19150, training accuracy 0.715334
# step 19150, cost 4185.63
# step 19150, change in cost 0.220703
# step 19160, training accuracy 0.715334
# step 19160, cost 4185.41
# step 19160, change in cost 0.220703
# step 19170, training accuracy 0.715334
# step 19170, cost 4185.2
# step 19170, change in cost 0.21582
# step 19180, training accuracy 0.715334
# step 19180, cost 4184.98
# step 19180, change in cost 0.21875
# step 19190, training accuracy 0.715334
# step 19190, cost 4184.76
# step 19190, change in cost 0.216309
# step 19200, training accuracy 0.715334
# step 19200, cost 4184.54
# step 19200, change in cost 0.21875
# step 19210, training accuracy 0.715334
# step 19210, cost 4184.33
# step 19210, change in cost 0.215332
# step 19220, training accuracy 0.715398
# step 19220, cost 4184.11
# step 19220, change in cost 0.21582
# step 19230, training accuracy 0.715334
# step 19230, cost 4183.89
# step 19230, change in cost 0.218262
# step 19240, training accuracy 0.715334
# step 19240, cost 4183.68
# step 19240, change in cost 0.216309
# step 19250, training accuracy 0.715334
# step 19250, cost 4183.46
# step 19250, change in cost 0.216797
# step 19260, training accuracy 0.715334
# step 19260, cost 4183.24
# step 19260, change in cost 0.217773
# step 19270, training accuracy 0.715334
# step 19270, cost 4183.02
# step 19270, change in cost 0.217773
# step 19280, training accuracy 0.715334
# step 19280, cost 4182.81
# step 19280, change in cost 0.21582
# step 19290, training accuracy 0.715334
# step 19290, cost 4182.59
# step 19290, change in cost 0.21875
# step 19300, training accuracy 0.715334
# step 19300, cost 4182.37
# step 19300, change in cost 0.218262
# step 19310, training accuracy 0.715334
# step 19310, cost 4182.16
# step 19310, change in cost 0.216309
# step 19320, training accuracy 0.715334
# step 19320, cost 4181.93
# step 19320, change in cost 0.22168
# step 19330, training accuracy 0.715334
# step 19330, cost 4181.72
# step 19330, change in cost 0.218262
# step 19340, training accuracy 0.715334
# step 19340, cost 4181.5
# step 19340, change in cost 0.219238
# step 19350, training accuracy 0.715334
# step 19350, cost 4181.27
# step 19350, change in cost 0.223633
# step 19360, training accuracy 0.715334
# step 19360, cost 4181.05
# step 19360, change in cost 0.22168
# step 19370, training accuracy 0.715334
# step 19370, cost 4180.83
# step 19370, change in cost 0.221191
# step 19380, training accuracy 0.715334
# step 19380, cost 4180.6
# step 19380, change in cost 0.225098
# step 19390, training accuracy 0.715334
# step 19390, cost 4180.38
# step 19390, change in cost 0.223633
# step 19400, training accuracy 0.715334
# step 19400, cost 4180.15
# step 19400, change in cost 0.228516
# step 19410, training accuracy 0.715334
# step 19410, cost 4179.93
# step 19410, change in cost 0.226562
# step 19420, training accuracy 0.715334
# step 19420, cost 4179.7
# step 19420, change in cost 0.228516
# step 19430, training accuracy 0.715334
# step 19430, cost 4179.47
# step 19430, change in cost 0.227539
# step 19440, training accuracy 0.715334
# step 19440, cost 4179.24
# step 19440, change in cost 0.232422
# step 19450, training accuracy 0.715334
# step 19450, cost 4179.01
# step 19450, change in cost 0.229492
# step 19460, training accuracy 0.715334
# step 19460, cost 4178.77
# step 19460, change in cost 0.23291
# step 19470, training accuracy 0.715334
# step 19470, cost 4178.54
# step 19470, change in cost 0.230957
# step 19480, training accuracy 0.715334
# step 19480, cost 4178.31
# step 19480, change in cost 0.230957
# step 19490, training accuracy 0.715334
# step 19490, cost 4178.08
# step 19490, change in cost 0.233887
# step 19500, training accuracy 0.715334
# step 19500, cost 4177.85
# step 19500, change in cost 0.23291
# step 19510, training accuracy 0.715334
# step 19510, cost 4177.62
# step 19510, change in cost 0.22998
# step 19520, training accuracy 0.715334
# step 19520, cost 4177.38
# step 19520, change in cost 0.23291
# step 19530, training accuracy 0.715334
# step 19530, cost 4177.15
# step 19530, change in cost 0.23584
# step 19540, training accuracy 0.715334
# step 19540, cost 4176.91
# step 19540, change in cost 0.234863
# step 19550, training accuracy 0.715334
# step 19550, cost 4176.67
# step 19550, change in cost 0.241211
# step 19560, training accuracy 0.715334
# step 19560, cost 4176.42
# step 19560, change in cost 0.249512
# step 19570, training accuracy 0.715334
# step 19570, cost 4176.17
# step 19570, change in cost 0.255371
# step 19580, training accuracy 0.715334
# step 19580, cost 4175.9
# step 19580, change in cost 0.262207
# step 19590, training accuracy 0.715334
# step 19590, cost 4175.64
# step 19590, change in cost 0.266113
# step 19600, training accuracy 0.715334
# step 19600, cost 4175.38
# step 19600, change in cost 0.26123
# step 19610, training accuracy 0.715334
# step 19610, cost 4175.12
# step 19610, change in cost 0.256836
# step 19620, training accuracy 0.715334
# step 19620, cost 4174.87
# step 19620, change in cost 0.248047
# step 19630, training accuracy 0.715334
# step 19630, cost 4174.63
# step 19630, change in cost 0.242188
# step 19640, training accuracy 0.715334
# step 19640, cost 4174.39
# step 19640, change in cost 0.239746
# step 19650, training accuracy 0.715269
# step 19650, cost 4174.15
# step 19650, change in cost 0.237793
# step 19660, training accuracy 0.715269
# step 19660, cost 4173.91
# step 19660, change in cost 0.240234
# step 19670, training accuracy 0.715269
# step 19670, cost 4173.67
# step 19670, change in cost 0.23877
# step 19680, training accuracy 0.715269
# step 19680, cost 4173.44
# step 19680, change in cost 0.238281
# step 19690, training accuracy 0.715269
# step 19690, cost 4173.2
# step 19690, change in cost 0.239258
# step 19700, training accuracy 0.715269
# step 19700, cost 4172.95
# step 19700, change in cost 0.245605
# step 19710, training accuracy 0.715269
# step 19710, cost 4172.71
# step 19710, change in cost 0.242188
# step 19720, training accuracy 0.715269
# step 19720, cost 4172.46
# step 19720, change in cost 0.244141
# step 19730, training accuracy 0.715269
# step 19730, cost 4172.22
# step 19730, change in cost 0.248047
# step 19740, training accuracy 0.715269
# step 19740, cost 4171.97
# step 19740, change in cost 0.249023
# step 19750, training accuracy 0.715269
# step 19750, cost 4171.71
# step 19750, change in cost 0.25293
# step 19760, training accuracy 0.715269
# step 19760, cost 4171.46
# step 19760, change in cost 0.254883
# step 19770, training accuracy 0.715269
# step 19770, cost 4171.2
# step 19770, change in cost 0.259277
# step 19780, training accuracy 0.715269
# step 19780, cost 4170.94
# step 19780, change in cost 0.260742
# step 19790, training accuracy 0.715269
# step 19790, cost 4170.68
# step 19790, change in cost 0.262695
# step 19800, training accuracy 0.715269
# step 19800, cost 4170.41
# step 19800, change in cost 0.263184
# step 19810, training accuracy 0.715269
# step 19810, cost 4170.15
# step 19810, change in cost 0.260742
# step 19820, training accuracy 0.715269
# step 19820, cost 4169.89
# step 19820, change in cost 0.261719
# step 19830, training accuracy 0.715269
# step 19830, cost 4169.63
# step 19830, change in cost 0.261719
# step 19840, training accuracy 0.715269
# step 19840, cost 4169.37
# step 19840, change in cost 0.258789
# step 19850, training accuracy 0.715205
# step 19850, cost 4169.11
# step 19850, change in cost 0.260254
# step 19860, training accuracy 0.715205
# step 19860, cost 4168.85
# step 19860, change in cost 0.261719
# step 19870, training accuracy 0.715205
# step 19870, cost 4168.58
# step 19870, change in cost 0.266113
# step 19880, training accuracy 0.715205
# step 19880, cost 4168.32
# step 19880, change in cost 0.266113
# step 19890, training accuracy 0.715205
# step 19890, cost 4168.04
# step 19890, change in cost 0.273926
# step 19900, training accuracy 0.715269
# step 19900, cost 4167.76
# step 19900, change in cost 0.279297
# step 19910, training accuracy 0.715269
# step 19910, cost 4167.48
# step 19910, change in cost 0.280273
# step 19920, training accuracy 0.715269
# step 19920, cost 4167.2
# step 19920, change in cost 0.287109
# step 19930, training accuracy 0.715269
# step 19930, cost 4166.9
# step 19930, change in cost 0.294922
# step 19940, training accuracy 0.715269
# step 19940, cost 4166.61
# step 19940, change in cost 0.294922
# step 19950, training accuracy 0.715269
# step 19950, cost 4166.31
# step 19950, change in cost 0.296875
# step 19960, training accuracy 0.715334
# step 19960, cost 4166.01
# step 19960, change in cost 0.301758
# step 19970, training accuracy 0.715398
# step 19970, cost 4165.71
# step 19970, change in cost 0.29541
# step 19980, training accuracy 0.715398
# step 19980, cost 4165.41
# step 19980, change in cost 0.297363
# step 19990, training accuracy 0.715398
# step 19990, cost 4165.12
# step 19990, change in cost 0.296875
# final accuracy on test set: 0.71106

# %% [markdown]
# # Import new set
# Now we'll bring in the 1000 most recent recipes published to Cookpad and return those which are identified by the algorithm as 'dinner' so that we can subject them to human analysis.

# %%
otherData = rec_parse.parse_chicken_recipes() 
print("data shape =", otherData.shape)
print(otherData[1])
# Out:
# data shape = (902, 3937)
# [0 2 7 ..., 0 0 0]

# %%
import csv
with tf.Session() as lolo:
    saver.restore(lolo, '/tmp/chicken-model')
    print("Model restored.")
    print("Checking ", len(otherData), "recipes.")
    
    predictions = lolo.run(activation_OP, feed_dict={X: otherData})

    
    id_set = []
    
    for index, i in enumerate(predictions):
        if i[0] > .8:
            id_set.append(index)
    
    for n in id_set:  
        print(n)
        
    print(len(id_set), "clickable recipes detected")
# Out:
# Model restored.
# Checking  902 recipes.
# 7
# 213
# 228
# 293
# 341
# 403
# 411
# 447
# 469
# 512
# 660
# 690
# 12 clickable recipes detected

# %%
1817305
487131
1450913
1260487
1134431
942992
938034
874184
880982
844374
739843
724373
